# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("paper")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time   latitude  longitude       depth   mag  \
# 0      2022-01-06T01:42:39.855Z  37.384000 -117.10750    1.100000  1.30
# 1      2022-01-06T01:31:33.698Z  38.181000 -117.81800    7.300000  1.40
# 2      2022-01-06T01:24:20.083Z  61.340700 -149.88520   30.000000  1.50
# 3      2022-01-06T01:15:15.851Z  62.870300 -150.76250  111.300000  2.10
# 4      2022-01-06T01:10:44.629Z  64.014500 -148.76570    1.900000  1.50
# ...                         ...        ...        ...         ...   ...
# 28330  2022-01-30T03:46:53.207Z  63.278200 -151.25170    7.400000  1.00
# 28331  2022-01-30T03:44:08.272Z  67.671500 -160.82990    6.200000  2.90
# 28332  2022-01-30T03:37:46.570Z  19.221167 -155.38916   31.940001  1.83
# 28333  2022-01-30T03:32:41.102Z   2.757300  128.23460   53.450000  4.50
# 28334  2022-01-30T03:31:21.676Z  54.594200 -159.78450   19.200000  2.30
#
#       magType   nst     gap   dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.875  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.119  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN    NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN    NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN    NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...    ...     ...  ...                       ...
# 28330      ml   NaN     NaN    NaN  0.6600  ...  2022-02-25T00:07:27.831Z
# 28331      ml   NaN     NaN    NaN  0.5700  ...  2022-02-25T03:00:49.040Z
# 28332      md  43.0  152.00    NaN  0.1300  ...  2022-01-30T03:40:57.760Z
# 28333      mb   NaN  194.00  2.154  1.0300  ...  2022-02-05T01:40:12.040Z
# 28334      ml   NaN     NaN    NaN  0.5800  ...  2022-02-25T00:07:27.644Z
#
#                                           place        type horizontalError  \
# 0                37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                      34 km SE of Mina, Nevada  earthquake             NaN
# 2           5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3                41 km N of Petersville, Alaska  earthquake             NaN
# 4                      17 km E of Ferry, Alaska  earthquake             NaN
# ...                                         ...         ...             ...
# 28330  37 km SE of Denali National Park, Alaska  earthquake             NaN
# 28331                79 km NNW of Kiana, Alaska  earthquake             NaN
# 28332                9 km ENE of Pāhala, Hawaii  earthquake            0.59
# 28333                      Halmahera, Indonesia  earthquake           12.30
# 28334           94 km SSE of Sand Point, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0          39.10     0.290     4.0  automatic              nn        nn
# 1           2.00     0.460     5.0  automatic              nn        nn
# 2           0.20       NaN     NaN  automatic              ak        ak
# 3           0.80       NaN     NaN  automatic              ak        ak
# 4           0.60       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 28330       0.20       NaN     NaN   reviewed              ak        ak
# 28331       0.60       NaN     NaN   reviewed              ak        ak
# 28332       1.16     0.620     5.0  automatic              hv        hv
# 28333      10.40     0.272     5.0   reviewed              us        us
# 28334       1.20       NaN     NaN   reviewed              ak        ak
#
# [28335 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time   latitude  longitude       depth  \
# 0     2022-01-06 01:42:39.855000+00:00  37.384000 -117.10750    1.100000
# 1     2022-01-06 01:31:33.698000+00:00  38.181000 -117.81800    7.300000
# 2     2022-01-06 01:24:20.083000+00:00  61.340700 -149.88520   30.000000
# 3     2022-01-06 01:15:15.851000+00:00  62.870300 -150.76250  111.300000
# 4     2022-01-06 01:10:44.629000+00:00  64.014500 -148.76570    1.900000
# ...                                ...        ...        ...         ...
# 28330 2022-01-30 03:46:53.207000+00:00  63.278200 -151.25170    7.400000
# 28331 2022-01-30 03:44:08.272000+00:00  67.671500 -160.82990    6.200000
# 28332 2022-01-30 03:37:46.570000+00:00  19.221167 -155.38916   31.940001
# 28333 2022-01-30 03:32:41.102000+00:00   2.757300  128.23460   53.450000
# 28334 2022-01-30 03:31:21.676000+00:00  54.594200 -159.78450   19.200000
#
#         mag magType   nst     gap   dmin     rms  ...  \
# 0      1.30      ml   8.0  149.46  0.875  0.2175  ...
# 1      1.40      ml  11.0  154.64  0.119  0.1017  ...
# 2      1.50      ml   NaN     NaN    NaN  0.7500  ...
# 3      2.10      ml   NaN     NaN    NaN  0.3200  ...
# 4      1.50      ml   NaN     NaN    NaN  0.7200  ...
# ...     ...     ...   ...     ...    ...     ...  ...
# 28330  1.00      ml   NaN     NaN    NaN  0.6600  ...
# 28331  2.90      ml   NaN     NaN    NaN  0.5700  ...
# 28332  1.83      md  43.0  152.00    NaN  0.1300  ...
# 28333  4.50      mb   NaN  194.00  2.154  1.0300  ...
# 28334  2.30      ml   NaN     NaN    NaN  0.5800  ...
#
#                         updated                                     place  \
# 0      2022-01-06T01:47:19.317Z            37 km SSE of Goldfield, Nevada
# 1      2022-01-06T01:47:40.245Z                  34 km SE of Mina, Nevada
# 2      2022-01-06T01:29:22.015Z       5 km ESE of Point MacKenzie, Alaska
# 3      2022-01-06T01:29:21.875Z            41 km N of Petersville, Alaska
# 4      2022-01-06T01:15:56.292Z                  17 km E of Ferry, Alaska
# ...                         ...                                       ...
# 28330  2022-02-25T00:07:27.831Z  37 km SE of Denali National Park, Alaska
# 28331  2022-02-25T03:00:49.040Z                79 km NNW of Kiana, Alaska
# 28332  2022-01-30T03:40:57.760Z                9 km ENE of Pāhala, Hawaii
# 28333  2022-02-05T01:40:12.040Z                      Halmahera, Indonesia
# 28334  2022-02-25T00:07:27.644Z           94 km SSE of Sand Point, Alaska
#
#              type horizontalError depthError  magError  magNst     status  \
# 0      earthquake             NaN      39.10     0.290     4.0  automatic
# 1      earthquake             NaN       2.00     0.460     5.0  automatic
# 2      earthquake             NaN       0.20       NaN     NaN  automatic
# 3      earthquake             NaN       0.80       NaN     NaN  automatic
# 4      earthquake             NaN       0.60       NaN     NaN  automatic
# ...           ...             ...        ...       ...     ...        ...
# 28330  earthquake             NaN       0.20       NaN     NaN   reviewed
# 28331  earthquake             NaN       0.60       NaN     NaN   reviewed
# 28332  earthquake            0.59       1.16     0.620     5.0  automatic
# 28333  earthquake           12.30      10.40     0.272     5.0   reviewed
# 28334  earthquake             NaN       1.20       NaN     NaN   reviewed
#
#        locationSource magSource
# 0                  nn        nn
# 1                  nn        nn
# 2                  ak        ak
# 3                  ak        ak
# 4                  ak        ak
# ...               ...       ...
# 28330              ak        ak
# 28331              ak        ak
# 28332              hv        hv
# 28333              us        us
# 28334              ak        ak
#
# [28335 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#         latitude  longitude       depth   mag     Unix Time
# 0      37.384000 -117.10750    1.100000  1.30  1.641433e+09
# 1      38.181000 -117.81800    7.300000  1.40  1.641433e+09
# 2      61.340700 -149.88520   30.000000  1.50  1.641432e+09
# 3      62.870300 -150.76250  111.300000  2.10  1.641432e+09
# 4      64.014500 -148.76570    1.900000  1.50  1.641431e+09
# ...          ...        ...         ...   ...           ...
# 28330  63.278200 -151.25170    7.400000  1.00  1.643514e+09
# 28331  67.671500 -160.82990    6.200000  2.90  1.643514e+09
# 28332  19.221167 -155.38916   31.940001  1.83  1.643514e+09
# 28333   2.757300  128.23460   53.450000  4.50  1.643514e+09
# 28334  54.594200 -159.78450   19.200000  2.30  1.643513e+09
#
# [28335 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['mag'], axis = 1)

y = cleaned_df_dropped[['mag']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((28329, 4), (28329, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb Cell 13' in <module>
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000012?line=0'>1</a> #scale and transform the data
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000012?line=1'>2</a> # sc_X = StandardScaler()
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000012?line=2'>3</a> # sc_y = StandardScaler()
# ----> <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000012?line=3'>4</a> X = X.fit_transform(X)
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000012?line=4'>5</a> y = y.fit_transform(y)
#
# File ~/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5482'>5483</a>     and name not in self._accessors
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5483'>5484</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5484'>5485</a> ):
#    <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5485'>5486</a>     return self[name]
# -> <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/pandas/core/generic.py?line=5486'>5487</a> return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'fit_transform'

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 0.3485246149265779, 	R2 score: 0.786277682918816, 	Model score: 0.786277682918816
# n_estimators=3:
# 	Mean Squared Error: 0.3075829785438729, 	R2 score: 0.8113839193740241, 	Model score: 0.8113839193740241
# n_estimators=4:
# 	Mean Squared Error: 0.2871925921127662, 	R2 score: 0.8238877152254446, 	Model score: 0.8238877152254446
# n_estimators=5:
# 	Mean Squared Error: 0.27801182198537705, 	R2 score: 0.8295175484715946, 	Model score: 0.8295175484715946
# n_estimators=6:
# 	Mean Squared Error: 0.2714510137491725, 	R2 score: 0.8335407682905516, 	Model score: 0.8335407682905516
# n_estimators=7:
# 	Mean Squared Error: 0.26477698255918847, 	R2 score: 0.8376334187063508, 	Model score: 0.8376334187063508
# n_estimators=8:
# 	Mean Squared Error: 0.2602313124702261, 	R2 score: 0.8404209152058573, 	Model score: 0.8404209152058573
# n_estimators=9:
# 	Mean Squared Error: 0.25768644772261506, 	R2 score: 0.8419814775513095, 	Model score: 0.8419814775513095
# n_estimators=10:
# 	Mean Squared Error: 0.2559822468518069, 	R2 score: 0.8430265278670743, 	Model score: 0.8430265278670743
# n_estimators=11:
# 	Mean Squared Error: 0.25409257354930215, 	R2 score: 0.8441853136154579, 	Model score: 0.8441853136154579
# n_estimators=12:
# 	Mean Squared Error: 0.2512379203417272, 	R2 score: 0.8459358444871861, 	Model score: 0.8459358444871861
# n_estimators=13:
# 	Mean Squared Error: 0.24946112237415366, 	R2 score: 0.8470254128056102, 	Model score: 0.8470254128056102
# n_estimators=14:
# 	Mean Squared Error: 0.24850541998098738, 	R2 score: 0.8476114687717019, 	Model score: 0.8476114687717019
# n_estimators=15:
# 	Mean Squared Error: 0.2478999785200025, 	R2 score: 0.8479827376759828, 	Model score: 0.8479827376759828
# n_estimators=16:
# 	Mean Squared Error: 0.24749747960611598, 	R2 score: 0.848229558120836, 	Model score: 0.848229558120836
# n_estimators=17:
# 	Mean Squared Error: 0.24653428755383003, 	R2 score: 0.8488202068968259, 	Model score: 0.8488202068968259
# n_estimators=18:
# 	Mean Squared Error: 0.2461844936568114, 	R2 score: 0.8490347075632636, 	Model score: 0.8490347075632636
# n_estimators=19:
# 	Mean Squared Error: 0.24454684746909353, 	R2 score: 0.8500389452061973, 	Model score: 0.8500389452061973
# n_estimators=20:
# 	Mean Squared Error: 0.2440411589703974, 	R2 score: 0.8503490435838553, 	Model score: 0.8503490435838553
# n_estimators=21:
# 	Mean Squared Error: 0.2439264064519037, 	R2 score: 0.8504194121406029, 	Model score: 0.8504194121406029
# n_estimators=22:
# 	Mean Squared Error: 0.24364192837334672, 	R2 score: 0.8505938598309641, 	Model score: 0.8505938598309641
# n_estimators=23:
# 	Mean Squared Error: 0.24346414005766512, 	R2 score: 0.8507028832087977, 	Model score: 0.8507028832087977
# n_estimators=24:
# 	Mean Squared Error: 0.2430048825744994, 	R2 score: 0.8509845091520893, 	Model score: 0.8509845091520893
# n_estimators=25:
# 	Mean Squared Error: 0.24240207298629562, 	R2 score: 0.8513541641389453, 	Model score: 0.8513541641389453
# n_estimators=26:
# 	Mean Squared Error: 0.24218529297894, 	R2 score: 0.8514870980078448, 	Model score: 0.8514870980078448
# n_estimators=27:
# 	Mean Squared Error: 0.2422271417190998, 	R2 score: 0.8514614355170743, 	Model score: 0.8514614355170743
# n_estimators=28:
# 	Mean Squared Error: 0.24202960680895227, 	R2 score: 0.851582567904553, 	Model score: 0.851582567904553
# n_estimators=29:
# 	Mean Squared Error: 0.24191378134768193, 	R2 score: 0.8516535944114323, 	Model score: 0.8516535944114323
# n_estimators=30:
# 	Mean Squared Error: 0.24086620429877512, 	R2 score: 0.8522959897678136, 	Model score: 0.8522959897678136
# n_estimators=31:
# 	Mean Squared Error: 0.24042410458625213, 	R2 score: 0.8525670942203966, 	Model score: 0.8525670942203966
# n_estimators=32:
# 	Mean Squared Error: 0.24002204670552177, 	R2 score: 0.8528136442148311, 	Model score: 0.8528136442148311
# n_estimators=33:
# 	Mean Squared Error: 0.23994480043851177, 	R2 score: 0.8528610131823708, 	Model score: 0.8528610131823708
# n_estimators=34:
# 	Mean Squared Error: 0.23998156193364914, 	R2 score: 0.8528384702927623, 	Model score: 0.8528384702927623
# n_estimators=35:
# 	Mean Squared Error: 0.2402036522718128, 	R2 score: 0.8527022800220014, 	Model score: 0.8527022800220014
# n_estimators=36:
# 	Mean Squared Error: 0.24000590033811467, 	R2 score: 0.8528235454926947, 	Model score: 0.8528235454926947
# n_estimators=37:
# 	Mean Squared Error: 0.24012425848584448, 	R2 score: 0.8527509658914416, 	Model score: 0.8527509658914416
# n_estimators=38:
# 	Mean Squared Error: 0.23994562132231545, 	R2 score: 0.8528605097998805, 	Model score: 0.8528605097998805
# n_estimators=39:
# 	Mean Squared Error: 0.23992437439682032, 	R2 score: 0.8528735388427464, 	Model score: 0.8528735388427464
# n_estimators=40:
# 	Mean Squared Error: 0.23989506694304227, 	R2 score: 0.852891510763985, 	Model score: 0.852891510763985
# n_estimators=41:
# 	Mean Squared Error: 0.23988931621790655, 	R2 score: 0.8528950372245225, 	Model score: 0.8528950372245225
# n_estimators=42:
# 	Mean Squared Error: 0.23960020986313454, 	R2 score: 0.8530723230671244, 	Model score: 0.8530723230671244
# n_estimators=43:
# 	Mean Squared Error: 0.239355627894099, 	R2 score: 0.8532223056591706, 	Model score: 0.8532223056591706
# n_estimators=44:
# 	Mean Squared Error: 0.23939696497201765, 	R2 score: 0.8531969569299969, 	Model score: 0.8531969569299969
# n_estimators=45:
# 	Mean Squared Error: 0.2393953669224115, 	R2 score: 0.8531979368862181, 	Model score: 0.8531979368862181
# n_estimators=46:
# 	Mean Squared Error: 0.23916439860555444, 	R2 score: 0.8533395713124161, 	Model score: 0.8533395713124161
# n_estimators=47:
# 	Mean Squared Error: 0.2390449168504884, 	R2 score: 0.85341283993233, 	Model score: 0.85341283993233
# n_estimators=48:
# 	Mean Squared Error: 0.23895093088083186, 	R2 score: 0.8534704740228585, 	Model score: 0.8534704740228585
# n_estimators=49:
# 	Mean Squared Error: 0.2388773288549251, 	R2 score: 0.8535156082683176, 	Model score: 0.8535156082683176
# n_estimators=50:
# 	Mean Squared Error: 0.238791159570983, 	R2 score: 0.8535684490096501, 	Model score: 0.8535684490096501
# Max score: 0.8535684490096501
# Best model score:  0.8535684490096501

# %%
#create and run model: Now with 200 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,200):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 50:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 0.3485246149265779, 	R2: 0.786277682918816, 	Model score: 0.786277682918816
# n_estimators=3:
# 	Mean Squared Error: 0.3075829785438729, 	R2: 0.8113839193740241, 	Model score: 0.8113839193740241
# n_estimators=4:
# 	Mean Squared Error: 0.2871925921127662, 	R2: 0.8238877152254446, 	Model score: 0.8238877152254446
# n_estimators=5:
# 	Mean Squared Error: 0.27801182198537705, 	R2: 0.8295175484715946, 	Model score: 0.8295175484715946
# n_estimators=6:
# 	Mean Squared Error: 0.2714510137491725, 	R2: 0.8335407682905516, 	Model score: 0.8335407682905516
# n_estimators=7:
# 	Mean Squared Error: 0.26477698255918847, 	R2: 0.8376334187063508, 	Model score: 0.8376334187063508
# n_estimators=8:
# 	Mean Squared Error: 0.2602313124702261, 	R2: 0.8404209152058573, 	Model score: 0.8404209152058573
# n_estimators=9:
# 	Mean Squared Error: 0.25768644772261506, 	R2: 0.8419814775513095, 	Model score: 0.8419814775513095
# n_estimators=10:
# 	Mean Squared Error: 0.2559822468518069, 	R2: 0.8430265278670743, 	Model score: 0.8430265278670743
# n_estimators=11:
# 	Mean Squared Error: 0.25409257354930215, 	R2: 0.8441853136154579, 	Model score: 0.8441853136154579
# n_estimators=12:
# 	Mean Squared Error: 0.2512379203417272, 	R2: 0.8459358444871861, 	Model score: 0.8459358444871861
# n_estimators=13:
# 	Mean Squared Error: 0.24946112237415366, 	R2: 0.8470254128056102, 	Model score: 0.8470254128056102
# n_estimators=14:
# 	Mean Squared Error: 0.24850541998098738, 	R2: 0.8476114687717019, 	Model score: 0.8476114687717019
# n_estimators=15:
# 	Mean Squared Error: 0.2478999785200025, 	R2: 0.8479827376759828, 	Model score: 0.8479827376759828
# n_estimators=16:
# 	Mean Squared Error: 0.24749747960611598, 	R2: 0.848229558120836, 	Model score: 0.848229558120836
# n_estimators=17:
# 	Mean Squared Error: 0.24653428755383003, 	R2: 0.8488202068968259, 	Model score: 0.8488202068968259
# n_estimators=18:
# 	Mean Squared Error: 0.2461844936568114, 	R2: 0.8490347075632636, 	Model score: 0.8490347075632636
# n_estimators=19:
# 	Mean Squared Error: 0.24454684746909353, 	R2: 0.8500389452061973, 	Model score: 0.8500389452061973
# n_estimators=20:
# 	Mean Squared Error: 0.2440411589703974, 	R2: 0.8503490435838553, 	Model score: 0.8503490435838553
# n_estimators=21:
# 	Mean Squared Error: 0.2439264064519037, 	R2: 0.8504194121406029, 	Model score: 0.8504194121406029
# n_estimators=22:
# 	Mean Squared Error: 0.24364192837334672, 	R2: 0.8505938598309641, 	Model score: 0.8505938598309641
# n_estimators=23:
# 	Mean Squared Error: 0.24346414005766512, 	R2: 0.8507028832087977, 	Model score: 0.8507028832087977
# n_estimators=24:
# 	Mean Squared Error: 0.2430048825744994, 	R2: 0.8509845091520893, 	Model score: 0.8509845091520893
# n_estimators=25:
# 	Mean Squared Error: 0.24240207298629562, 	R2: 0.8513541641389453, 	Model score: 0.8513541641389453
# n_estimators=26:
# 	Mean Squared Error: 0.24218529297894, 	R2: 0.8514870980078448, 	Model score: 0.8514870980078448
# n_estimators=27:
# 	Mean Squared Error: 0.2422271417190998, 	R2: 0.8514614355170743, 	Model score: 0.8514614355170743
# n_estimators=28:
# 	Mean Squared Error: 0.24202960680895227, 	R2: 0.851582567904553, 	Model score: 0.851582567904553
# n_estimators=29:
# 	Mean Squared Error: 0.24191378134768193, 	R2: 0.8516535944114323, 	Model score: 0.8516535944114323
# n_estimators=30:
# 	Mean Squared Error: 0.24086620429877512, 	R2: 0.8522959897678136, 	Model score: 0.8522959897678136
# n_estimators=31:
# 	Mean Squared Error: 0.24042410458625213, 	R2: 0.8525670942203966, 	Model score: 0.8525670942203966
# n_estimators=32:
# 	Mean Squared Error: 0.24002204670552177, 	R2: 0.8528136442148311, 	Model score: 0.8528136442148311
# n_estimators=33:
# 	Mean Squared Error: 0.23994480043851177, 	R2: 0.8528610131823708, 	Model score: 0.8528610131823708
# n_estimators=34:
# 	Mean Squared Error: 0.23998156193364914, 	R2: 0.8528384702927623, 	Model score: 0.8528384702927623
# n_estimators=35:
# 	Mean Squared Error: 0.2402036522718128, 	R2: 0.8527022800220014, 	Model score: 0.8527022800220014
# n_estimators=36:
# 	Mean Squared Error: 0.24000590033811467, 	R2: 0.8528235454926947, 	Model score: 0.8528235454926947
# n_estimators=37:
# 	Mean Squared Error: 0.24012425848584448, 	R2: 0.8527509658914416, 	Model score: 0.8527509658914416
# n_estimators=38:
# 	Mean Squared Error: 0.23994562132231545, 	R2: 0.8528605097998805, 	Model score: 0.8528605097998805
# n_estimators=39:
# 	Mean Squared Error: 0.23992437439682032, 	R2: 0.8528735388427464, 	Model score: 0.8528735388427464
# n_estimators=40:
# 	Mean Squared Error: 0.23989506694304227, 	R2: 0.852891510763985, 	Model score: 0.852891510763985
# n_estimators=41:
# 	Mean Squared Error: 0.23988931621790655, 	R2: 0.8528950372245225, 	Model score: 0.8528950372245225
# n_estimators=42:
# 	Mean Squared Error: 0.23960020986313454, 	R2: 0.8530723230671244, 	Model score: 0.8530723230671244
# n_estimators=43:
# 	Mean Squared Error: 0.239355627894099, 	R2: 0.8532223056591706, 	Model score: 0.8532223056591706
# n_estimators=44:
# 	Mean Squared Error: 0.23939696497201765, 	R2: 0.8531969569299969, 	Model score: 0.8531969569299969
# n_estimators=45:
# 	Mean Squared Error: 0.2393953669224115, 	R2: 0.8531979368862181, 	Model score: 0.8531979368862181
# n_estimators=46:
# 	Mean Squared Error: 0.23916439860555444, 	R2: 0.8533395713124161, 	Model score: 0.8533395713124161
# n_estimators=47:
# 	Mean Squared Error: 0.2390449168504884, 	R2: 0.85341283993233, 	Model score: 0.85341283993233
# n_estimators=48:
# 	Mean Squared Error: 0.23895093088083186, 	R2: 0.8534704740228585, 	Model score: 0.8534704740228585
# n_estimators=49:
# 	Mean Squared Error: 0.2388773288549251, 	R2: 0.8535156082683176, 	Model score: 0.8535156082683176
# n_estimators=50:
# 	Mean Squared Error: 0.238791159570983, 	R2: 0.8535684490096501, 	Model score: 0.8535684490096501
# n_estimators=51:
# 	Mean Squared Error: 0.23863140402370253, 	R2: 0.8536664143305173, 	Model score: 0.8536664143305173
# Improvement found!
# n_estimators=52:
# 	Mean Squared Error: 0.23867719447655114, 	R2: 0.8536383347020954, 	Model score: 0.8536383347020954
# n_estimators=53:
# 	Mean Squared Error: 0.23860342386663427, 	R2: 0.8536835723266667, 	Model score: 0.8536835723266667
# Improvement found!
# n_estimators=54:
# 	Mean Squared Error: 0.23859941171738025, 	R2: 0.8536860326574391, 	Model score: 0.8536860326574391
# Improvement found!
# n_estimators=55:
# 	Mean Squared Error: 0.23863983735817304, 	R2: 0.8536612428398777, 	Model score: 0.8536612428398777
# n_estimators=56:
# 	Mean Squared Error: 0.23840718460430382, 	R2: 0.8538039101967951, 	Model score: 0.8538039101967951
# Improvement found!
# n_estimators=57:
# 	Mean Squared Error: 0.23811125063232633, 	R2: 0.8539853828718524, 	Model score: 0.8539853828718524
# Improvement found!
# n_estimators=58:
# 	Mean Squared Error: 0.23802133927667396, 	R2: 0.854040518326965, 	Model score: 0.854040518326965
# Improvement found!
# n_estimators=59:
# 	Mean Squared Error: 0.2382694823353676, 	R2: 0.8538883520029802, 	Model score: 0.8538883520029802
# n_estimators=60:
# 	Mean Squared Error: 0.23841923262885328, 	R2: 0.8537965221053585, 	Model score: 0.8537965221053585
# n_estimators=61:
# 	Mean Squared Error: 0.23838645329257396, 	R2: 0.8538166230549098, 	Model score: 0.8538166230549098
# n_estimators=62:
# 	Mean Squared Error: 0.23829698016458833, 	R2: 0.8538714897799864, 	Model score: 0.8538714897799864
# n_estimators=63:
# 	Mean Squared Error: 0.23838331120426687, 	R2: 0.8538185498467767, 	Model score: 0.8538185498467767
# n_estimators=64:
# 	Mean Squared Error: 0.23834154034136845, 	R2: 0.8538441645816413, 	Model score: 0.8538441645816413
# n_estimators=65:
# 	Mean Squared Error: 0.23819501130235918, 	R2: 0.8539340191411058, 	Model score: 0.8539340191411058
# n_estimators=66:
# 	Mean Squared Error: 0.23789930940722578, 	R2: 0.8541153495019657, 	Model score: 0.8541153495019657
# Improvement found!
# n_estimators=67:
# 	Mean Squared Error: 0.23775303013477764, 	R2: 0.8542050508995417, 	Model score: 0.8542050508995417
# Improvement found!
# n_estimators=68:
# 	Mean Squared Error: 0.237638182580043, 	R2: 0.8542754777344272, 	Model score: 0.8542754777344272
# Improvement found!
# n_estimators=69:
# 	Mean Squared Error: 0.2375740049579038, 	R2: 0.8543148327455826, 	Model score: 0.8543148327455826
# Improvement found!
# n_estimators=70:
# 	Mean Squared Error: 0.23752488413062037, 	R2: 0.8543449546267191, 	Model score: 0.8543449546267191
# Improvement found!
# n_estimators=71:
# 	Mean Squared Error: 0.2375993464353228, 	R2: 0.8542992928409667, 	Model score: 0.8542992928409667
# n_estimators=72:
# 	Mean Squared Error: 0.23780392195354294, 	R2: 0.8541738430107408, 	Model score: 0.8541738430107408
# n_estimators=73:
# 	Mean Squared Error: 0.23758688506169995, 	R2: 0.8543069344063846, 	Model score: 0.8543069344063846
# n_estimators=74:
# 	Mean Squared Error: 0.23752234400872377, 	R2: 0.8543465122806528, 	Model score: 0.8543465122806528
# Improvement found!
# n_estimators=75:
# 	Mean Squared Error: 0.23737006598588545, 	R2: 0.8544398922328504, 	Model score: 0.8544398922328504
# Improvement found!
# n_estimators=76:
# 	Mean Squared Error: 0.2375323782990691, 	R2: 0.8543403590516094, 	Model score: 0.8543403590516094
# n_estimators=77:
# 	Mean Squared Error: 0.2374597434498103, 	R2: 0.8543849002048582, 	Model score: 0.8543849002048582
# n_estimators=78:
# 	Mean Squared Error: 0.23736703506375212, 	R2: 0.8544417508553794, 	Model score: 0.8544417508553794
# Improvement found!
# n_estimators=79:
# 	Mean Squared Error: 0.23732081839953847, 	R2: 0.8544700918451991, 	Model score: 0.8544700918451991
# Improvement found!
# n_estimators=80:
# 	Mean Squared Error: 0.2372706463314173, 	R2: 0.8545008583684011, 	Model score: 0.8545008583684011
# Improvement found!
# n_estimators=81:
# 	Mean Squared Error: 0.2371843233219519, 	R2: 0.8545537933773222, 	Model score: 0.8545537933773222
# Improvement found!
# n_estimators=82:
# 	Mean Squared Error: 0.23719529659334884, 	R2: 0.8545470643461763, 	Model score: 0.8545470643461763
# n_estimators=83:
# 	Mean Squared Error: 0.23708663557975257, 	R2: 0.8546136974693693, 	Model score: 0.8546136974693693
# Improvement found!
# n_estimators=84:
# 	Mean Squared Error: 0.23706799365467385, 	R2: 0.8546251290734858, 	Model score: 0.8546251290734858
# Improvement found!
# n_estimators=85:
# 	Mean Squared Error: 0.2370100648258209, 	R2: 0.854660652198677, 	Model score: 0.854660652198677
# Improvement found!
# n_estimators=86:
# 	Mean Squared Error: 0.23694442577908753, 	R2: 0.8547009033848431, 	Model score: 0.8547009033848431
# Improvement found!
# n_estimators=87:
# 	Mean Squared Error: 0.23691700556126724, 	R2: 0.8547177180149622, 	Model score: 0.8547177180149622
# Improvement found!
# n_estimators=88:
# 	Mean Squared Error: 0.2368815642413068, 	R2: 0.854739451346549, 	Model score: 0.854739451346549
# Improvement found!
# n_estimators=89:
# 	Mean Squared Error: 0.23688693292454813, 	R2: 0.8547361591617997, 	Model score: 0.8547361591617997
# n_estimators=90:
# 	Mean Squared Error: 0.2368572443644813, 	R2: 0.8547543647850945, 	Model score: 0.8547543647850945
# Improvement found!
# n_estimators=91:
# 	Mean Squared Error: 0.23691458916236036, 	R2: 0.8547191997994654, 	Model score: 0.8547191997994654
# n_estimators=92:
# 	Mean Squared Error: 0.23684233720510728, 	R2: 0.8547635061556206, 	Model score: 0.8547635061556206
# Improvement found!
# n_estimators=93:
# 	Mean Squared Error: 0.23691138237534515, 	R2: 0.8547211662658839, 	Model score: 0.8547211662658839
# n_estimators=94:
# 	Mean Squared Error: 0.23679767110157374, 	R2: 0.8547908963103854, 	Model score: 0.8547908963103854
# Improvement found!
# n_estimators=95:
# 	Mean Squared Error: 0.2368615973899644, 	R2: 0.8547516954221492, 	Model score: 0.8547516954221492
# n_estimators=96:
# 	Mean Squared Error: 0.2369338287958839, 	R2: 0.854707401668486, 	Model score: 0.854707401668486
# n_estimators=97:
# 	Mean Squared Error: 0.23689444809505, 	R2: 0.8547315507078079, 	Model score: 0.8547315507078079
# n_estimators=98:
# 	Mean Squared Error: 0.23671675125202285, 	R2: 0.8548405179927664, 	Model score: 0.8548405179927664
# Improvement found!
# n_estimators=99:
# 	Mean Squared Error: 0.23669605168626082, 	R2: 0.8548532113836139, 	Model score: 0.8548532113836139
# Improvement found!
# n_estimators=100:
# 	Mean Squared Error: 0.2366538652106578, 	R2: 0.8548790809805641, 	Model score: 0.8548790809805641
# Improvement found!
# n_estimators=101:
# 	Mean Squared Error: 0.23648974067350095, 	R2: 0.854979725454064, 	Model score: 0.854979725454064
# Improvement found!
# n_estimators=102:
# 	Mean Squared Error: 0.23641872479408493, 	R2: 0.855023273822381, 	Model score: 0.855023273822381
# Improvement found!
# n_estimators=103:
# 	Mean Squared Error: 0.23655133276020557, 	R2: 0.8549419559453388, 	Model score: 0.8549419559453388
# n_estimators=104:
# 	Mean Squared Error: 0.2364707261543174, 	R2: 0.8549913855403938, 	Model score: 0.8549913855403938
# n_estimators=105:
# 	Mean Squared Error: 0.23642067775272424, 	R2: 0.8550220762287888, 	Model score: 0.8550220762287888
# n_estimators=106:
# 	Mean Squared Error: 0.23647009265378546, 	R2: 0.8549917740156858, 	Model score: 0.8549917740156858
# n_estimators=107:
# 	Mean Squared Error: 0.23650365492159406, 	R2: 0.8549711929567437, 	Model score: 0.8549711929567437
# n_estimators=108:
# 	Mean Squared Error: 0.23649342001368998, 	R2: 0.8549774692085168, 	Model score: 0.8549774692085168
# n_estimators=109:
# 	Mean Squared Error: 0.23655865037401153, 	R2: 0.854937468637094, 	Model score: 0.854937468637094
# n_estimators=110:
# 	Mean Squared Error: 0.23647949683435404, 	R2: 0.854986007182655, 	Model score: 0.854986007182655
# n_estimators=111:
# 	Mean Squared Error: 0.23657552069879526, 	R2: 0.8549271234139784, 	Model score: 0.8549271234139784
# n_estimators=112:
# 	Mean Squared Error: 0.23666208124108587, 	R2: 0.8548740427451422, 	Model score: 0.8548740427451422
# n_estimators=113:
# 	Mean Squared Error: 0.2367215525985628, 	R2: 0.854837573710315, 	Model score: 0.854837573710315
# n_estimators=114:
# 	Mean Squared Error: 0.23665499395497713, 	R2: 0.8548783888118019, 	Model score: 0.8548783888118019
# n_estimators=115:
# 	Mean Squared Error: 0.23669163663750845, 	R2: 0.8548559187804776, 	Model score: 0.8548559187804776
# n_estimators=116:
# 	Mean Squared Error: 0.23670352785624224, 	R2: 0.8548486268455271, 	Model score: 0.8548486268455271
# n_estimators=117:
# 	Mean Squared Error: 0.23668453055525654, 	R2: 0.854860276373311, 	Model score: 0.854860276373311
# n_estimators=118:
# 	Mean Squared Error: 0.23667206125242896, 	R2: 0.8548679228010769, 	Model score: 0.8548679228010769
# n_estimators=119:
# 	Mean Squared Error: 0.23670919050086656, 	R2: 0.854845154397734, 	Model score: 0.854845154397734
# n_estimators=120:
# 	Mean Squared Error: 0.23673065974823537, 	R2: 0.8548319890226153, 	Model score: 0.8548319890226153
# n_estimators=121:
# 	Mean Squared Error: 0.23672002249224594, 	R2: 0.8548385120023421, 	Model score: 0.8548385120023421
# n_estimators=122:
# 	Mean Squared Error: 0.23675262519053447, 	R2: 0.8548185193707662, 	Model score: 0.8548185193707662
# n_estimators=123:
# 	Mean Squared Error: 0.23669343829624395, 	R2: 0.8548548139670353, 	Model score: 0.8548548139670353
# n_estimators=124:
# 	Mean Squared Error: 0.23663361172331718, 	R2: 0.8548915008271345, 	Model score: 0.8548915008271345
# n_estimators=125:
# 	Mean Squared Error: 0.23661059377373178, 	R2: 0.8549056158976609, 	Model score: 0.8549056158976609
# n_estimators=126:
# 	Mean Squared Error: 0.23658132307062374, 	R2: 0.8549235652826481, 	Model score: 0.8549235652826481
# n_estimators=127:
# 	Mean Squared Error: 0.23653072490872248, 	R2: 0.8549545930951423, 	Model score: 0.8549545930951423
# n_estimators=128:
# 	Mean Squared Error: 0.2364382826230085, 	R2: 0.8550112805675703, 	Model score: 0.8550112805675703
# n_estimators=129:
# 	Mean Squared Error: 0.23636556099903033, 	R2: 0.8550558749328256, 	Model score: 0.8550558749328256
# Improvement found!
# n_estimators=130:
# 	Mean Squared Error: 0.23639174677679967, 	R2: 0.8550398172862211, 	Model score: 0.8550398172862211
# n_estimators=131:
# 	Mean Squared Error: 0.236309865660992, 	R2: 0.8550900284364417, 	Model score: 0.8550900284364417
# Improvement found!
# n_estimators=132:
# 	Mean Squared Error: 0.23633973609072814, 	R2: 0.8550717112870008, 	Model score: 0.8550717112870008
# n_estimators=133:
# 	Mean Squared Error: 0.23632092881937938, 	R2: 0.855083244284782, 	Model score: 0.855083244284782
# n_estimators=134:
# 	Mean Squared Error: 0.23631553079326137, 	R2: 0.8550865544631745, 	Model score: 0.8550865544631745
# n_estimators=135:
# 	Mean Squared Error: 0.2362436744102104, 	R2: 0.8551306182452576, 	Model score: 0.8551306182452576
# Improvement found!
# n_estimators=136:
# 	Mean Squared Error: 0.2361722848909829, 	R2: 0.8551743957370364, 	Model score: 0.8551743957370364
# Improvement found!
# n_estimators=137:
# 	Mean Squared Error: 0.2362860168576222, 	R2: 0.8551046530032513, 	Model score: 0.8551046530032513
# n_estimators=138:
# 	Mean Squared Error: 0.23626725127184572, 	R2: 0.8551161604385995, 	Model score: 0.8551161604385995
# n_estimators=139:
# 	Mean Squared Error: 0.23630819672581546, 	R2: 0.855091051861123, 	Model score: 0.855091051861123
# n_estimators=140:
# 	Mean Squared Error: 0.23633514434843897, 	R2: 0.8550745270359019, 	Model score: 0.8550745270359019
# n_estimators=141:
# 	Mean Squared Error: 0.23622320185535134, 	R2: 0.8551431724284448, 	Model score: 0.8551431724284448
# n_estimators=142:
# 	Mean Squared Error: 0.2362116039869706, 	R2: 0.8551502844750476, 	Model score: 0.8551502844750476
# n_estimators=143:
# 	Mean Squared Error: 0.2361766341503481, 	R2: 0.8551717286835505, 	Model score: 0.8551717286835505
# n_estimators=144:
# 	Mean Squared Error: 0.23618723962301771, 	R2: 0.855165225193996, 	Model score: 0.855165225193996
# n_estimators=145:
# 	Mean Squared Error: 0.236237172680906, 	R2: 0.855134605236685, 	Model score: 0.855134605236685
# n_estimators=146:
# 	Mean Squared Error: 0.23617276732207568, 	R2: 0.8551740999005686, 	Model score: 0.8551740999005686
# n_estimators=147:
# 	Mean Squared Error: 0.23612037727679194, 	R2: 0.8552062265320618, 	Model score: 0.8552062265320618
# Improvement found!
# n_estimators=148:
# 	Mean Squared Error: 0.23608674693379808, 	R2: 0.8552268493360792, 	Model score: 0.8552268493360792
# Improvement found!
# n_estimators=149:
# 	Mean Squared Error: 0.2361084623154429, 	R2: 0.8552135330264624, 	Model score: 0.8552135330264624
# n_estimators=150:
# 	Mean Squared Error: 0.23613082531272728, 	R2: 0.8551998195858852, 	Model score: 0.8551998195858852
# n_estimators=151:
# 	Mean Squared Error: 0.2361311254525487, 	R2: 0.8551996355340985, 	Model score: 0.8551996355340985
# n_estimators=152:
# 	Mean Squared Error: 0.2361073547503752, 	R2: 0.8552142122076807, 	Model score: 0.8552142122076807
# n_estimators=153:
# 	Mean Squared Error: 0.23614714007958493, 	R2: 0.855189815042085, 	Model score: 0.855189815042085
# n_estimators=154:
# 	Mean Squared Error: 0.23607976416851134, 	R2: 0.8552311313084645, 	Model score: 0.8552311313084645
# Improvement found!
# n_estimators=155:
# 	Mean Squared Error: 0.2360720265987827, 	R2: 0.8552358761421438, 	Model score: 0.8552358761421438
# Improvement found!
# n_estimators=156:
# 	Mean Squared Error: 0.23608341712483677, 	R2: 0.855228891242034, 	Model score: 0.855228891242034
# n_estimators=157:
# 	Mean Squared Error: 0.23602113233604607, 	R2: 0.8552670855296371, 	Model score: 0.8552670855296371
# Improvement found!
# n_estimators=158:
# 	Mean Squared Error: 0.2360084052284553, 	R2: 0.855274890048479, 	Model score: 0.855274890048479
# Improvement found!
# n_estimators=159:
# 	Mean Squared Error: 0.23603753957123014, 	R2: 0.8552570242823959, 	Model score: 0.8552570242823959
# n_estimators=160:
# 	Mean Squared Error: 0.23605118542769185, 	R2: 0.8552486563682324, 	Model score: 0.8552486563682324
# n_estimators=161:
# 	Mean Squared Error: 0.23606013412815247, 	R2: 0.8552431688447825, 	Model score: 0.8552431688447825
# n_estimators=162:
# 	Mean Squared Error: 0.2360848291106921, 	R2: 0.8552280253838543, 	Model score: 0.8552280253838543
# n_estimators=163:
# 	Mean Squared Error: 0.2361776740522129, 	R2: 0.8551710909947717, 	Model score: 0.8551710909947717
# n_estimators=164:
# 	Mean Squared Error: 0.23607387914265968, 	R2: 0.8552347401249074, 	Model score: 0.8552347401249074
# n_estimators=165:
# 	Mean Squared Error: 0.23605489152616208, 	R2: 0.855246383713968, 	Model score: 0.855246383713968
# n_estimators=166:
# 	Mean Squared Error: 0.23601445785130273, 	R2: 0.855271178458181, 	Model score: 0.855271178458181
# n_estimators=167:
# 	Mean Squared Error: 0.23597641904474864, 	R2: 0.8552945046208897, 	Model score: 0.8552945046208897
# Improvement found!
# n_estimators=168:
# 	Mean Squared Error: 0.23591180188589944, 	R2: 0.8553341291648129, 	Model score: 0.8553341291648129
# Improvement found!
# n_estimators=169:
# 	Mean Squared Error: 0.23594020492910792, 	R2: 0.8553167118463605, 	Model score: 0.8553167118463605
# n_estimators=170:
# 	Mean Squared Error: 0.23592626321642676, 	R2: 0.8553252611855195, 	Model score: 0.8553252611855195
# n_estimators=171:
# 	Mean Squared Error: 0.23587849430856864, 	R2: 0.8553545540424216, 	Model score: 0.8553545540424216
# Improvement found!
# n_estimators=172:
# 	Mean Squared Error: 0.2359522646710702, 	R2: 0.8553093165695702, 	Model score: 0.8553093165695702
# n_estimators=173:
# 	Mean Squared Error: 0.23589673822222568, 	R2: 0.8553433665069292, 	Model score: 0.8553433665069292
# n_estimators=174:
# 	Mean Squared Error: 0.23592286614806873, 	R2: 0.8553273443362919, 	Model score: 0.8553273443362919
# n_estimators=175:
# 	Mean Squared Error: 0.2359204938064019, 	R2: 0.8553287991040076, 	Model score: 0.8553287991040076
# n_estimators=176:
# 	Mean Squared Error: 0.23588973025917576, 	R2: 0.8553476639310907, 	Model score: 0.8553476639310907
# n_estimators=177:
# 	Mean Squared Error: 0.23584756305278726, 	R2: 0.8553735217117703, 	Model score: 0.8553735217117703
# Improvement found!
# n_estimators=178:
# 	Mean Squared Error: 0.23579981240085104, 	R2: 0.8554028033737731, 	Model score: 0.8554028033737731
# Improvement found!
# n_estimators=179:
# 	Mean Squared Error: 0.23578674629299892, 	R2: 0.8554108157744065, 	Model score: 0.8554108157744065
# Improvement found!
# n_estimators=180:
# 	Mean Squared Error: 0.23575594069967057, 	R2: 0.8554297063850068, 	Model score: 0.8554297063850068
# Improvement found!
# n_estimators=181:
# 	Mean Squared Error: 0.23569781830395936, 	R2: 0.8554653482092961, 	Model score: 0.8554653482092961
# Improvement found!
# n_estimators=182:
# 	Mean Squared Error: 0.2357085321474618, 	R2: 0.8554587782645631, 	Model score: 0.8554587782645631
# n_estimators=183:
# 	Mean Squared Error: 0.23572003757544457, 	R2: 0.8554517229042752, 	Model score: 0.8554517229042752
# n_estimators=184:
# 	Mean Squared Error: 0.23575754059432333, 	R2: 0.8554287252973658, 	Model score: 0.8554287252973658
# n_estimators=185:
# 	Mean Squared Error: 0.23568326798517536, 	R2: 0.8554742707579817, 	Model score: 0.8554742707579817
# Improvement found!
# n_estimators=186:
# 	Mean Squared Error: 0.23565807229932148, 	R2: 0.8554897212602719, 	Model score: 0.8554897212602719
# Improvement found!
# n_estimators=187:
# 	Mean Squared Error: 0.23561087784607382, 	R2: 0.8555186618500308, 	Model score: 0.8555186618500308
# Improvement found!
# n_estimators=188:
# 	Mean Squared Error: 0.23563151862566198, 	R2: 0.8555060045080497, 	Model score: 0.8555060045080497
# n_estimators=189:
# 	Mean Squared Error: 0.23564846831049308, 	R2: 0.8554956106197539, 	Model score: 0.8554956106197539
# n_estimators=190:
# 	Mean Squared Error: 0.2356111869969801, 	R2: 0.8555184722724652, 	Model score: 0.8555184722724652
# n_estimators=191:
# 	Mean Squared Error: 0.23556709654373365, 	R2: 0.855545509426874, 	Model score: 0.855545509426874
# Improvement found!
# n_estimators=192:
# 	Mean Squared Error: 0.23556049241036325, 	R2: 0.8555495592145382, 	Model score: 0.8555495592145382
# Improvement found!
# n_estimators=193:
# 	Mean Squared Error: 0.23558676170504309, 	R2: 0.8555334503536813, 	Model score: 0.8555334503536813
# n_estimators=194:
# 	Mean Squared Error: 0.23557100971879918, 	R2: 0.8555431097890683, 	Model score: 0.8555431097890683
# n_estimators=195:
# 	Mean Squared Error: 0.23554599260235085, 	R2: 0.8555584507890008, 	Model score: 0.8555584507890008
# Improvement found!
# n_estimators=196:
# 	Mean Squared Error: 0.23543579994046765, 	R2: 0.8556260231497879, 	Model score: 0.8556260231497879
# Improvement found!
# n_estimators=197:
# 	Mean Squared Error: 0.2354528315671734, 	R2: 0.8556155790130833, 	Model score: 0.8556155790130833
# n_estimators=198:
# 	Mean Squared Error: 0.23550830793705504, 	R2: 0.8555815597851535, 	Model score: 0.8555815597851535
# n_estimators=199:
# 	Mean Squared Error: 0.235471673974896, 	R2: 0.8556040244689697, 	Model score: 0.8556040244689697
# n_estimators=200:
# 	Mean Squared Error: 0.23545855820051734, 	R2: 0.8556120673261179, 	Model score: 0.8556120673261179
# Best score found: 0.856.
# Number of estimators: 200.
# Code execution time: 619.007 seconds.

# %% [markdown]
# Cross-Validation

# %%
#define number of splits
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 2833  2834  2835 ... 28326 28327 28328] | test: [   0    1    2 ... 2830 2831 2832]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [2833 2834 2835 ... 5663 5664 5665]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [5666 5667 5668 ... 8496 8497 8498]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [ 8499  8500  8501 ... 11329 11330 11331]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [11332 11333 11334 ... 14162 14163 14164]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [14165 14166 14167 ... 16995 16996 16997]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [16998 16999 17000 ... 19828 19829 19830]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [19831 19832 19833 ... 22661 22662 22663]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [22664 22665 22666 ... 25494 25495 25496]
# Train: [    0     1     2 ... 25494 25495 25496] | test: [25497 25498 25499 ... 28326 28327 28328]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y, cv=k_fold, n_jobs=-1)
    print(cv_score)
# Out:
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [0.79412401 0.81870219 0.86332709 0.83485207 0.86850936 0.82346821
#  0.81502081 0.85778512 0.83769117 0.82561192]

# %%
reg_etrees = ExtraTreesRegressor(n_estimators=200, random_state=0)

# %%
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 200, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y,
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)
# Out:
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
testpred = best_model.predict(X_test)
actual_mag = y_test
testpredict = []
for item in testpred:
    testpredict.append(item)

test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %f' % rmse)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb Cell 24' in <module>
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000043?line=3'>4</a> for item in testpred:
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000043?line=4'>5</a>     testpredict.append(item)
# ----> <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000043?line=6'>7</a> test_mse = mean_squared_error(y_test, testpred)
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000043?line=7'>8</a> rmse = sqrt(test_mse)
#       <a href='vscode-notebook-cell:/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/noteboooks/ml_extratrees.ipynb#ch0000043?line=8'>9</a> print('RMSE: %f' % rmse)
#
# File ~/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py?line=66'>67</a>     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py?line=67'>68</a>                   "passing these as positional arguments will "
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py?line=68'>69</a>                   "result in an error".format(", ".join(args_msg)),
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py?line=69'>70</a>                   FutureWarning)
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py?line=70'>71</a> kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/utils/validation.py?line=71'>72</a> return f(**kwargs)
#
# File ~/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py:255, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=192'>193</a> @_deprecate_positional_args
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=193'>194</a> def mean_squared_error(y_true, y_pred, *,
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=194'>195</a>                        sample_weight=None,
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=195'>196</a>                        multioutput='uniform_average', squared=True):
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=196'>197</a>     """Mean squared error regression loss
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=197'>198</a>
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=198'>199</a>     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=252'>253</a>
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=253'>254</a>     """
# --> <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=254'>255</a>     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=255'>256</a>         y_true, y_pred, multioutput)
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=256'>257</a>     check_consistent_length(y_true, y_pred, sample_weight)
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=257'>258</a>     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=258'>259</a>                                weights=sample_weight)
#
# File ~/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py:95, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=91'>92</a>     y_pred = y_pred.reshape((-1, 1))
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=93'>94</a> if y_true.shape[1] != y_pred.shape[1]:
# ---> <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=94'>95</a>     raise ValueError("y_true and y_pred have different number of output "
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=95'>96</a>                      "({0}!={1})".format(y_true.shape[1], y_pred.shape[1]))
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=97'>98</a> n_outputs = y_true.shape[1]
#      <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=98'>99</a> allowed_multioutput_str = ('raw_values', 'uniform_average',
#     <a href='file:///Users/rosaicelaroman/opt/anaconda3/envs/MLenv/lib/python3.8/site-packages/sklearn/metrics/_regression.py?line=99'>100</a>                            'variance_weighted')
#
# ValueError: y_true and y_pred have different number of output (2!=1)

# %%
print(testpredict)

# %%
print(actual_mag)

# %%
mag_pred = actual_mag
mag_pred['Predicted'] = y_test

# %%
mag_pred = pd.DataFrame({"Prediction": [x for x in testpredict], "Actual": [n for n in y_test]})
mag_pred.head()

# %%
x_graph = np.array(actual_mag)
y_graph = np.array(testpredict)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Magnitude', fontsize=13)
plt.xlabel('Actual Magnitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Magnitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Magnitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(y_test, testpredict)), (0, 3.5),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 3.2), fontsize=12)

# fig.savefig('extratrees_mag_linear_sns.png', dpi=600)
plt.show()
