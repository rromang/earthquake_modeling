# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("paper")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 0      2022-01-06T01:42:39.855Z   37.3840  -117.1075    1.10  1.3      ml
# 1      2022-01-06T01:31:33.698Z   38.1810  -117.8180    7.30  1.4      ml
# 2      2022-01-06T01:24:20.083Z   61.3407  -149.8852   30.00  1.5      ml
# 3      2022-01-06T01:15:15.851Z   62.8703  -150.7625  111.30  2.1      ml
# 4      2022-01-06T01:10:44.629Z   64.0145  -148.7657    1.90  1.5      ml
# ...                         ...       ...        ...     ...  ...     ...
# 28330  2022-01-30T05:22:23.246Z   37.8445   144.8923   10.00  4.3      mb
# 28331  2022-01-30T05:08:20.279Z  -30.0533  -177.1517   10.00  4.3      mb
# 28332  2022-01-30T03:50:17.124Z   54.2336  -159.7370   22.54  3.0      ml
# 28333  2022-01-30T03:46:53.207Z   63.2782  -151.2517    7.40  1.0      ml
# 28334  2022-01-30T03:31:21.676Z   54.5942  -159.7845   19.20  2.3      ml
#
#         nst     gap   dmin     rms  ...                   updated  \
# 0       8.0  149.46  0.875  0.2175  ...  2022-01-06T01:47:19.317Z
# 1      11.0  154.64  0.119  0.1017  ...  2022-01-06T01:47:40.245Z
# 2       NaN     NaN    NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3       NaN     NaN    NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4       NaN     NaN    NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...     ...     ...    ...     ...  ...                       ...
# 28330   NaN  126.00  4.178  0.7000  ...  2022-02-26T10:52:54.040Z
# 28331   NaN  221.00  1.034  0.6800  ...  2022-02-26T10:21:50.040Z
# 28332   NaN  219.00  0.604  1.0300  ...  2022-02-25T00:07:12.426Z
# 28333   NaN     NaN    NaN  0.6600  ...  2022-02-25T00:07:27.831Z
# 28334   NaN     NaN    NaN  0.5800  ...  2022-02-25T00:07:27.644Z
#
#                                           place        type horizontalError  \
# 0                37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                      34 km SE of Mina, Nevada  earthquake             NaN
# 2           5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3                41 km N of Petersville, Alaska  earthquake             NaN
# 4                      17 km E of Ferry, Alaska  earthquake             NaN
# ...                                         ...         ...             ...
# 28330       off the east coast of Honshu, Japan  earthquake             8.0
# 28331             Kermadec Islands, New Zealand  earthquake            10.8
# 28332          132 km SSE of Sand Point, Alaska  earthquake             5.2
# 28333  37 km SE of Denali National Park, Alaska  earthquake             NaN
# 28334           94 km SSE of Sand Point, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           39.1     0.290     4.0  automatic              nn        nn
# 1            2.0     0.460     5.0  automatic              nn        nn
# 2            0.2       NaN     NaN  automatic              ak        ak
# 3            0.8       NaN     NaN  automatic              ak        ak
# 4            0.6       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 28330        1.8     0.137    16.0   reviewed              us        us
# 28331        2.0     0.160    12.0   reviewed              us        us
# 28332       14.1     0.088    17.0   reviewed              us        us
# 28333        0.2       NaN     NaN   reviewed              ak        ak
# 28334        1.2       NaN     NaN   reviewed              ak        ak
#
# [28335 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time  latitude  longitude   depth  mag  \
# 0     2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.10  1.3
# 1     2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.30  1.4
# 2     2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.00  1.5
# 3     2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.30  2.1
# 4     2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.90  1.5
# ...                                ...       ...        ...     ...  ...
# 28330 2022-01-30 05:22:23.246000+00:00   37.8445   144.8923   10.00  4.3
# 28331 2022-01-30 05:08:20.279000+00:00  -30.0533  -177.1517   10.00  4.3
# 28332 2022-01-30 03:50:17.124000+00:00   54.2336  -159.7370   22.54  3.0
# 28333 2022-01-30 03:46:53.207000+00:00   63.2782  -151.2517    7.40  1.0
# 28334 2022-01-30 03:31:21.676000+00:00   54.5942  -159.7845   19.20  2.3
#
#       magType   nst     gap   dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.875  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.119  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN    NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN    NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN    NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...    ...     ...  ...                       ...
# 28330      mb   NaN  126.00  4.178  0.7000  ...  2022-02-26T10:52:54.040Z
# 28331      mb   NaN  221.00  1.034  0.6800  ...  2022-02-26T10:21:50.040Z
# 28332      ml   NaN  219.00  0.604  1.0300  ...  2022-02-25T00:07:12.426Z
# 28333      ml   NaN     NaN    NaN  0.6600  ...  2022-02-25T00:07:27.831Z
# 28334      ml   NaN     NaN    NaN  0.5800  ...  2022-02-25T00:07:27.644Z
#
#                                           place        type horizontalError  \
# 0                37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                      34 km SE of Mina, Nevada  earthquake             NaN
# 2           5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3                41 km N of Petersville, Alaska  earthquake             NaN
# 4                      17 km E of Ferry, Alaska  earthquake             NaN
# ...                                         ...         ...             ...
# 28330       off the east coast of Honshu, Japan  earthquake             8.0
# 28331             Kermadec Islands, New Zealand  earthquake            10.8
# 28332          132 km SSE of Sand Point, Alaska  earthquake             5.2
# 28333  37 km SE of Denali National Park, Alaska  earthquake             NaN
# 28334           94 km SSE of Sand Point, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           39.1     0.290     4.0  automatic              nn        nn
# 1            2.0     0.460     5.0  automatic              nn        nn
# 2            0.2       NaN     NaN  automatic              ak        ak
# 3            0.8       NaN     NaN  automatic              ak        ak
# 4            0.6       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 28330        1.8     0.137    16.0   reviewed              us        us
# 28331        2.0     0.160    12.0   reviewed              us        us
# 28332       14.1     0.088    17.0   reviewed              us        us
# 28333        0.2       NaN     NaN   reviewed              ak        ak
# 28334        1.2       NaN     NaN   reviewed              ak        ak
#
# [28335 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#        latitude  longitude   depth  mag     Unix Time
# 0       37.3840  -117.1075    1.10  1.3  1.641433e+09
# 1       38.1810  -117.8180    7.30  1.4  1.641433e+09
# 2       61.3407  -149.8852   30.00  1.5  1.641432e+09
# 3       62.8703  -150.7625  111.30  2.1  1.641432e+09
# 4       64.0145  -148.7657    1.90  1.5  1.641431e+09
# ...         ...        ...     ...  ...           ...
# 28330   37.8445   144.8923   10.00  4.3  1.643520e+09
# 28331  -30.0533  -177.1517   10.00  4.3  1.643519e+09
# 28332   54.2336  -159.7370   22.54  3.0  1.643515e+09
# 28333   63.2782  -151.2517    7.40  1.0  1.643514e+09
# 28334   54.5942  -159.7845   19.20  2.3  1.643513e+09
#
# [28335 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['mag'], axis = 1)

y = cleaned_df_dropped[['mag']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((28329, 4), (28329, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 0.3387215102940209, 	R2 score: 0.793388297081684, 	Model score: 0.793388297081684
# n_estimators=3:
# 	Mean Squared Error: 0.30051660309548395, 	R2 score: 0.8166923409532234, 	Model score: 0.8166923409532234
# n_estimators=4:
# 	Mean Squared Error: 0.28456163492610587, 	R2 score: 0.8264244750022871, 	Model score: 0.8264244750022871
# n_estimators=5:
# 	Mean Squared Error: 0.27145184081249646, 	R2 score: 0.8344211235894117, 	Model score: 0.8344211235894117
# n_estimators=6:
# 	Mean Squared Error: 0.26287703821793884, 	R2 score: 0.839651540059603, 	Model score: 0.839651540059603
# n_estimators=7:
# 	Mean Squared Error: 0.25835440719372155, 	R2 score: 0.8424102325818866, 	Model score: 0.8424102325818866
# n_estimators=8:
# 	Mean Squared Error: 0.2548828569330145, 	R2 score: 0.8445277919612972, 	Model score: 0.8445277919612972
# n_estimators=9:
# 	Mean Squared Error: 0.2519677402318386, 	R2 score: 0.8463059406986264, 	Model score: 0.8463059406986264
# n_estimators=10:
# 	Mean Squared Error: 0.2500502344277334, 	R2 score: 0.8474755715827059, 	Model score: 0.8474755715827059
# n_estimators=11:
# 	Mean Squared Error: 0.24898291723549074, 	R2 score: 0.8481266085435764, 	Model score: 0.8481266085435764
# n_estimators=12:
# 	Mean Squared Error: 0.24678160155692858, 	R2 score: 0.8494693563974511, 	Model score: 0.8494693563974511
# n_estimators=13:
# 	Mean Squared Error: 0.2450462844073414, 	R2 score: 0.8505278567302712, 	Model score: 0.8505278567302712
# n_estimators=14:
# 	Mean Squared Error: 0.24456425056249972, 	R2 score: 0.8508218853954734, 	Model score: 0.8508218853954734
# n_estimators=15:
# 	Mean Squared Error: 0.24340132738509704, 	R2 score: 0.8515312396311633, 	Model score: 0.8515312396311633
# n_estimators=16:
# 	Mean Squared Error: 0.24245992769475316, 	R2 score: 0.852105470045346, 	Model score: 0.852105470045346
# n_estimators=17:
# 	Mean Squared Error: 0.24200428848626607, 	R2 score: 0.8523833986383667, 	Model score: 0.8523833986383667
# n_estimators=18:
# 	Mean Squared Error: 0.24143123252621673, 	R2 score: 0.8527329485316419, 	Model score: 0.8527329485316419
# n_estimators=19:
# 	Mean Squared Error: 0.2407859572028177, 	R2 score: 0.853126550441668, 	Model score: 0.853126550441668
# n_estimators=20:
# 	Mean Squared Error: 0.23953688402460008, 	R2 score: 0.8538884540367397, 	Model score: 0.8538884540367397
# n_estimators=21:
# 	Mean Squared Error: 0.23943660886166748, 	R2 score: 0.8539496193939558, 	Model score: 0.8539496193939558
# n_estimators=22:
# 	Mean Squared Error: 0.23853745473014112, 	R2 score: 0.854498081067203, 	Model score: 0.854498081067203
# n_estimators=23:
# 	Mean Squared Error: 0.23750998266919823, 	R2 score: 0.8551248134882652, 	Model score: 0.8551248134882652
# n_estimators=24:
# 	Mean Squared Error: 0.23705145484654463, 	R2 score: 0.8554045040641358, 	Model score: 0.8554045040641358
# n_estimators=25:
# 	Mean Squared Error: 0.2367211823718834, 	R2 score: 0.8556059620653049, 	Model score: 0.8556059620653049
# n_estimators=26:
# 	Mean Squared Error: 0.23603998036587814, 	R2 score: 0.8560214783588227, 	Model score: 0.8560214783588227
# n_estimators=27:
# 	Mean Squared Error: 0.23535423092784993, 	R2 score: 0.8564397684728555, 	Model score: 0.8564397684728555
# n_estimators=28:
# 	Mean Squared Error: 0.23509083150964097, 	R2 score: 0.8566004355716076, 	Model score: 0.8566004355716076
# n_estimators=29:
# 	Mean Squared Error: 0.23447814937260744, 	R2 score: 0.8569741564480002, 	Model score: 0.8569741564480002
# n_estimators=30:
# 	Mean Squared Error: 0.23443233007505826, 	R2 score: 0.8570021050807427, 	Model score: 0.8570021050807427
# n_estimators=31:
# 	Mean Squared Error: 0.2341869236374421, 	R2 score: 0.8571517969085187, 	Model score: 0.8571517969085187
# n_estimators=32:
# 	Mean Squared Error: 0.23394878804975383, 	R2 score: 0.8572970536985438, 	Model score: 0.8572970536985438
# n_estimators=33:
# 	Mean Squared Error: 0.23371471779028555, 	R2 score: 0.8574398307393916, 	Model score: 0.8574398307393916
# n_estimators=34:
# 	Mean Squared Error: 0.2336483134213658, 	R2 score: 0.8574803357540622, 	Model score: 0.8574803357540622
# n_estimators=35:
# 	Mean Squared Error: 0.2332747888082788, 	R2 score: 0.8577081764847109, 	Model score: 0.8577081764847109
# n_estimators=36:
# 	Mean Squared Error: 0.23327876435590605, 	R2 score: 0.8577057514994639, 	Model score: 0.8577057514994639
# n_estimators=37:
# 	Mean Squared Error: 0.2330934744253283, 	R2 score: 0.8578187737520426, 	Model score: 0.8578187737520426
# n_estimators=38:
# 	Mean Squared Error: 0.2328353615037231, 	R2 score: 0.8579762162192535, 	Model score: 0.8579762162192535
# n_estimators=39:
# 	Mean Squared Error: 0.23268124385872505, 	R2 score: 0.8580702241523639, 	Model score: 0.8580702241523639
# n_estimators=40:
# 	Mean Squared Error: 0.2325935628222232, 	R2 score: 0.8581237074054634, 	Model score: 0.8581237074054634
# n_estimators=41:
# 	Mean Squared Error: 0.2322656033075282, 	R2 score: 0.8583237545585378, 	Model score: 0.8583237545585378
# n_estimators=42:
# 	Mean Squared Error: 0.23232510429921713, 	R2 score: 0.858287460432406, 	Model score: 0.858287460432406
# n_estimators=43:
# 	Mean Squared Error: 0.23241933357002875, 	R2 score: 0.8582299829191231, 	Model score: 0.8582299829191231
# n_estimators=44:
# 	Mean Squared Error: 0.23230670607909792, 	R2 score: 0.8582986828894215, 	Model score: 0.8582986828894215
# n_estimators=45:
# 	Mean Squared Error: 0.23214956321399474, 	R2 score: 0.8583945361316093, 	Model score: 0.8583945361316093
# n_estimators=46:
# 	Mean Squared Error: 0.23194435560199866, 	R2 score: 0.8585197076748323, 	Model score: 0.8585197076748323
# n_estimators=47:
# 	Mean Squared Error: 0.23161679932007273, 	R2 score: 0.8587195088659393, 	Model score: 0.8587195088659393
# n_estimators=48:
# 	Mean Squared Error: 0.23153306734331, 	R2 score: 0.8587705832907452, 	Model score: 0.8587705832907452
# n_estimators=49:
# 	Mean Squared Error: 0.23126080939798804, 	R2 score: 0.8589366538708721, 	Model score: 0.8589366538708721
# n_estimators=50:
# 	Mean Squared Error: 0.23137861112759545, 	R2 score: 0.8588647977435782, 	Model score: 0.8588647977435782
# Max score: 0.8589366538708721
# Best model score:  0.8589366538708721

# %%
#create and run model: Now with 100 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,100):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 60:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 0.3387215102940209, 	R2: 0.793388297081684, 	Model score: 0.793388297081684
# n_estimators=3:
# 	Mean Squared Error: 0.30051660309548395, 	R2: 0.8166923409532234, 	Model score: 0.8166923409532234
# n_estimators=4:
# 	Mean Squared Error: 0.28456163492610587, 	R2: 0.8264244750022871, 	Model score: 0.8264244750022871
# n_estimators=5:
# 	Mean Squared Error: 0.27145184081249646, 	R2: 0.8344211235894117, 	Model score: 0.8344211235894117
# n_estimators=6:
# 	Mean Squared Error: 0.26287703821793884, 	R2: 0.839651540059603, 	Model score: 0.839651540059603
# n_estimators=7:
# 	Mean Squared Error: 0.25835440719372155, 	R2: 0.8424102325818866, 	Model score: 0.8424102325818866
# n_estimators=8:
# 	Mean Squared Error: 0.2548828569330145, 	R2: 0.8445277919612972, 	Model score: 0.8445277919612972
# n_estimators=9:
# 	Mean Squared Error: 0.2519677402318386, 	R2: 0.8463059406986264, 	Model score: 0.8463059406986264
# n_estimators=10:
# 	Mean Squared Error: 0.2500502344277334, 	R2: 0.8474755715827059, 	Model score: 0.8474755715827059
# n_estimators=11:
# 	Mean Squared Error: 0.24898291723549074, 	R2: 0.8481266085435764, 	Model score: 0.8481266085435764
# n_estimators=12:
# 	Mean Squared Error: 0.24678160155692858, 	R2: 0.8494693563974511, 	Model score: 0.8494693563974511
# n_estimators=13:
# 	Mean Squared Error: 0.2450462844073414, 	R2: 0.8505278567302712, 	Model score: 0.8505278567302712
# n_estimators=14:
# 	Mean Squared Error: 0.24456425056249972, 	R2: 0.8508218853954734, 	Model score: 0.8508218853954734
# n_estimators=15:
# 	Mean Squared Error: 0.24340132738509704, 	R2: 0.8515312396311633, 	Model score: 0.8515312396311633
# n_estimators=16:
# 	Mean Squared Error: 0.24245992769475316, 	R2: 0.852105470045346, 	Model score: 0.852105470045346
# n_estimators=17:
# 	Mean Squared Error: 0.24200428848626607, 	R2: 0.8523833986383667, 	Model score: 0.8523833986383667
# n_estimators=18:
# 	Mean Squared Error: 0.24143123252621673, 	R2: 0.8527329485316419, 	Model score: 0.8527329485316419
# n_estimators=19:
# 	Mean Squared Error: 0.2407859572028177, 	R2: 0.853126550441668, 	Model score: 0.853126550441668
# n_estimators=20:
# 	Mean Squared Error: 0.23953688402460008, 	R2: 0.8538884540367397, 	Model score: 0.8538884540367397
# n_estimators=21:
# 	Mean Squared Error: 0.23943660886166748, 	R2: 0.8539496193939558, 	Model score: 0.8539496193939558
# n_estimators=22:
# 	Mean Squared Error: 0.23853745473014112, 	R2: 0.854498081067203, 	Model score: 0.854498081067203
# n_estimators=23:
# 	Mean Squared Error: 0.23750998266919823, 	R2: 0.8551248134882652, 	Model score: 0.8551248134882652
# n_estimators=24:
# 	Mean Squared Error: 0.23705145484654463, 	R2: 0.8554045040641358, 	Model score: 0.8554045040641358
# n_estimators=25:
# 	Mean Squared Error: 0.2367211823718834, 	R2: 0.8556059620653049, 	Model score: 0.8556059620653049
# n_estimators=26:
# 	Mean Squared Error: 0.23603998036587814, 	R2: 0.8560214783588227, 	Model score: 0.8560214783588227
# n_estimators=27:
# 	Mean Squared Error: 0.23535423092784993, 	R2: 0.8564397684728555, 	Model score: 0.8564397684728555
# n_estimators=28:
# 	Mean Squared Error: 0.23509083150964097, 	R2: 0.8566004355716076, 	Model score: 0.8566004355716076
# n_estimators=29:
# 	Mean Squared Error: 0.23447814937260744, 	R2: 0.8569741564480002, 	Model score: 0.8569741564480002
# n_estimators=30:
# 	Mean Squared Error: 0.23443233007505826, 	R2: 0.8570021050807427, 	Model score: 0.8570021050807427
# n_estimators=31:
# 	Mean Squared Error: 0.2341869236374421, 	R2: 0.8571517969085187, 	Model score: 0.8571517969085187
# n_estimators=32:
# 	Mean Squared Error: 0.23394878804975383, 	R2: 0.8572970536985438, 	Model score: 0.8572970536985438
# n_estimators=33:
# 	Mean Squared Error: 0.23371471779028555, 	R2: 0.8574398307393916, 	Model score: 0.8574398307393916
# n_estimators=34:
# 	Mean Squared Error: 0.2336483134213658, 	R2: 0.8574803357540622, 	Model score: 0.8574803357540622
# n_estimators=35:
# 	Mean Squared Error: 0.2332747888082788, 	R2: 0.8577081764847109, 	Model score: 0.8577081764847109
# n_estimators=36:
# 	Mean Squared Error: 0.23327876435590605, 	R2: 0.8577057514994639, 	Model score: 0.8577057514994639
# n_estimators=37:
# 	Mean Squared Error: 0.2330934744253283, 	R2: 0.8578187737520426, 	Model score: 0.8578187737520426
# n_estimators=38:
# 	Mean Squared Error: 0.2328353615037231, 	R2: 0.8579762162192535, 	Model score: 0.8579762162192535
# n_estimators=39:
# 	Mean Squared Error: 0.23268124385872505, 	R2: 0.8580702241523639, 	Model score: 0.8580702241523639
# n_estimators=40:
# 	Mean Squared Error: 0.2325935628222232, 	R2: 0.8581237074054634, 	Model score: 0.8581237074054634
# n_estimators=41:
# 	Mean Squared Error: 0.2322656033075282, 	R2: 0.8583237545585378, 	Model score: 0.8583237545585378
# n_estimators=42:
# 	Mean Squared Error: 0.23232510429921713, 	R2: 0.858287460432406, 	Model score: 0.858287460432406
# n_estimators=43:
# 	Mean Squared Error: 0.23241933357002875, 	R2: 0.8582299829191231, 	Model score: 0.8582299829191231
# n_estimators=44:
# 	Mean Squared Error: 0.23230670607909792, 	R2: 0.8582986828894215, 	Model score: 0.8582986828894215
# n_estimators=45:
# 	Mean Squared Error: 0.23214956321399474, 	R2: 0.8583945361316093, 	Model score: 0.8583945361316093
# n_estimators=46:
# 	Mean Squared Error: 0.23194435560199866, 	R2: 0.8585197076748323, 	Model score: 0.8585197076748323
# n_estimators=47:
# 	Mean Squared Error: 0.23161679932007273, 	R2: 0.8587195088659393, 	Model score: 0.8587195088659393
# n_estimators=48:
# 	Mean Squared Error: 0.23153306734331, 	R2: 0.8587705832907452, 	Model score: 0.8587705832907452
# n_estimators=49:
# 	Mean Squared Error: 0.23126080939798804, 	R2: 0.8589366538708721, 	Model score: 0.8589366538708721
# n_estimators=50:
# 	Mean Squared Error: 0.23137861112759545, 	R2: 0.8588647977435782, 	Model score: 0.8588647977435782
# n_estimators=51:
# 	Mean Squared Error: 0.2311118010596667, 	R2: 0.8590275452538932, 	Model score: 0.8590275452538932
# Improvement found!
# n_estimators=52:
# 	Mean Squared Error: 0.23103805687631668, 	R2: 0.8590725273729474, 	Model score: 0.8590725273729474
# Improvement found!
# n_estimators=53:
# 	Mean Squared Error: 0.23088562067645366, 	R2: 0.8591655096663151, 	Model score: 0.8591655096663151
# Improvement found!
# n_estimators=54:
# 	Mean Squared Error: 0.23089504542556347, 	R2: 0.8591597608035946, 	Model score: 0.8591597608035946
# n_estimators=55:
# 	Mean Squared Error: 0.23087489033856817, 	R2: 0.8591720549057404, 	Model score: 0.8591720549057404
# Improvement found!
# n_estimators=56:
# 	Mean Squared Error: 0.23099971828766833, 	R2: 0.8590959129591809, 	Model score: 0.8590959129591809
# n_estimators=57:
# 	Mean Squared Error: 0.23090338419430426, 	R2: 0.859154674361909, 	Model score: 0.859154674361909
# n_estimators=58:
# 	Mean Squared Error: 0.23104909200563628, 	R2: 0.8590657962183224, 	Model score: 0.8590657962183224
# n_estimators=59:
# 	Mean Squared Error: 0.2308259430398634, 	R2: 0.8592019115414465, 	Model score: 0.8592019115414465
# Improvement found!
# n_estimators=60:
# 	Mean Squared Error: 0.2306272041584024, 	R2: 0.8593231373198127, 	Model score: 0.8593231373198127
# Improvement found!
# n_estimators=61:
# 	Mean Squared Error: 0.23065932247063312, 	R2: 0.8593035459475993, 	Model score: 0.8593035459475993
# n_estimators=62:
# 	Mean Squared Error: 0.23064605675026795, 	R2: 0.8593116377073245, 	Model score: 0.8593116377073245
# n_estimators=63:
# 	Mean Squared Error: 0.23054576434981752, 	R2: 0.8593728135789981, 	Model score: 0.8593728135789981
# Improvement found!
# n_estimators=64:
# 	Mean Squared Error: 0.23042920110962756, 	R2: 0.8594439142585281, 	Model score: 0.8594439142585281
# Improvement found!
# n_estimators=65:
# 	Mean Squared Error: 0.23015735051763134, 	R2: 0.8596097363632504, 	Model score: 0.8596097363632504
# Improvement found!
# n_estimators=66:
# 	Mean Squared Error: 0.23015360416486982, 	R2: 0.8596120215453256, 	Model score: 0.8596120215453256
# Improvement found!
# n_estimators=67:
# 	Mean Squared Error: 0.23002341550331595, 	R2: 0.8596914333932504, 	Model score: 0.8596914333932504
# Improvement found!
# n_estimators=68:
# 	Mean Squared Error: 0.2299548852325002, 	R2: 0.8597332351552418, 	Model score: 0.8597332351552418
# Improvement found!
# n_estimators=69:
# 	Mean Squared Error: 0.22975726943766267, 	R2: 0.85985377587868, 	Model score: 0.85985377587868
# Improvement found!
# n_estimators=70:
# 	Mean Squared Error: 0.22973541879759643, 	R2: 0.859867104226059, 	Model score: 0.859867104226059
# Improvement found!
# n_estimators=71:
# 	Mean Squared Error: 0.22979958831562172, 	R2: 0.8598279624148905, 	Model score: 0.8598279624148905
# n_estimators=72:
# 	Mean Squared Error: 0.22969778970832758, 	R2: 0.8598900570353045, 	Model score: 0.8598900570353045
# Improvement found!
# n_estimators=73:
# 	Mean Squared Error: 0.229643590305593, 	R2: 0.8599231173239363, 	Model score: 0.8599231173239363
# Improvement found!
# n_estimators=74:
# 	Mean Squared Error: 0.22953420404751892, 	R2: 0.8599898402227476, 	Model score: 0.8599898402227476
# Improvement found!
# n_estimators=75:
# 	Mean Squared Error: 0.22957460844303926, 	R2: 0.8599651945456643, 	Model score: 0.8599651945456643
# n_estimators=76:
# 	Mean Squared Error: 0.22942599797916, 	R2: 0.8600558432351643, 	Model score: 0.8600558432351643
# Improvement found!
# n_estimators=77:
# 	Mean Squared Error: 0.2294138068776631, 	R2: 0.8600632795040878, 	Model score: 0.8600632795040878
# Improvement found!
# n_estimators=78:
# 	Mean Squared Error: 0.22943140889621416, 	R2: 0.8600525427102406, 	Model score: 0.8600525427102406
# n_estimators=79:
# 	Mean Squared Error: 0.22925720685004314, 	R2: 0.8601588016289021, 	Model score: 0.8601588016289021
# Improvement found!
# n_estimators=80:
# 	Mean Squared Error: 0.22919438579756674, 	R2: 0.8601971209095998, 	Model score: 0.8601971209095998
# Improvement found!
# n_estimators=81:
# 	Mean Squared Error: 0.2290494769101331, 	R2: 0.8602855117294643, 	Model score: 0.8602855117294643
# Improvement found!
# n_estimators=82:
# 	Mean Squared Error: 0.2290373363518055, 	R2: 0.8602929171683107, 	Model score: 0.8602929171683107
# Improvement found!
# n_estimators=83:
# 	Mean Squared Error: 0.2290646140820793, 	R2: 0.8602762784307865, 	Model score: 0.8602762784307865
# n_estimators=84:
# 	Mean Squared Error: 0.22904634711023875, 	R2: 0.860287420829614, 	Model score: 0.860287420829614
# n_estimators=85:
# 	Mean Squared Error: 0.2290089779606323, 	R2: 0.8603102150821257, 	Model score: 0.8603102150821257
# Improvement found!
# n_estimators=86:
# 	Mean Squared Error: 0.22895643312150404, 	R2: 0.8603422661280791, 	Model score: 0.8603422661280791
# Improvement found!
# n_estimators=87:
# 	Mean Squared Error: 0.22888734277948652, 	R2: 0.8603844095195841, 	Model score: 0.8603844095195841
# Improvement found!
# n_estimators=88:
# 	Mean Squared Error: 0.22899559006602468, 	R2: 0.8603183813651024, 	Model score: 0.8603183813651024
# n_estimators=89:
# 	Mean Squared Error: 0.2289012742755444, 	R2: 0.8603759116532329, 	Model score: 0.8603759116532329
# n_estimators=90:
# 	Mean Squared Error: 0.22892675150085703, 	R2: 0.8603603711789863, 	Model score: 0.8603603711789863
# n_estimators=91:
# 	Mean Squared Error: 0.22873655778853005, 	R2: 0.8604763846165567, 	Model score: 0.8604763846165567
# Improvement found!
# n_estimators=92:
# 	Mean Squared Error: 0.22864129771931083, 	R2: 0.8605344908912496, 	Model score: 0.8605344908912496
# Improvement found!
# n_estimators=93:
# 	Mean Squared Error: 0.2287519632653552, 	R2: 0.8604669876585709, 	Model score: 0.8604669876585709
# n_estimators=94:
# 	Mean Squared Error: 0.22874917951501084, 	R2: 0.8604686856770956, 	Model score: 0.8604686856770956
# n_estimators=95:
# 	Mean Squared Error: 0.2285899660509037, 	R2: 0.8605658019332144, 	Model score: 0.8605658019332144
# Improvement found!
# n_estimators=96:
# 	Mean Squared Error: 0.22843603299905182, 	R2: 0.8606596972690935, 	Model score: 0.8606596972690935
# Improvement found!
# n_estimators=97:
# 	Mean Squared Error: 0.22839904589974327, 	R2: 0.8606822584804188, 	Model score: 0.8606822584804188
# Improvement found!
# n_estimators=98:
# 	Mean Squared Error: 0.2284122513463767, 	R2: 0.8606742034861719, 	Model score: 0.8606742034861719
# n_estimators=99:
# 	Mean Squared Error: 0.22839657723566903, 	R2: 0.8606837643041495, 	Model score: 0.8606837643041495
# Improvement found!
# n_estimators=100:
# 	Mean Squared Error: 0.2282700748373434, 	R2: 0.860760927623121, 	Model score: 0.860760927623121
# Improvement found!
# Best score found: 0.861.
# Number of estimators: 100.
# Code execution time: 151.198 seconds.

# %% [markdown]
# Cross-Validation

# %%
#define number of splits
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 2833  2834  2835 ... 28326 28327 28328] | test: [   0    1    2 ... 2830 2831 2832]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [2833 2834 2835 ... 5663 5664 5665]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [5666 5667 5668 ... 8496 8497 8498]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [ 8499  8500  8501 ... 11329 11330 11331]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [11332 11333 11334 ... 14162 14163 14164]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [14165 14166 14167 ... 16995 16996 16997]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [16998 16999 17000 ... 19828 19829 19830]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [19831 19832 19833 ... 22661 22662 22663]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [22664 22665 22666 ... 25494 25495 25496]
# Train: [    0     1     2 ... 25494 25495 25496] | test: [25497 25498 25499 ... 28326 28327 28328]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y.values.ravel(), cv=k_fold, n_jobs=-1)
    print(cv_score)
# Out:
# [0.79454239 0.81620423 0.86464131 0.8488487  0.84734486 0.81533188
#  0.85329633 0.83043526 0.84640396 0.79305413]

# %%
reg_etrees = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 100, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y.values.ravel(),
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
testpred = best_model.predict(X_test)
actual_mag = y_test
testpredict = []
for item in testpred:
    testpredict.append(item)

test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %f' % rmse)
# Out:
# RMSE: 0.477776

# %%
print(actual_mag)
# Out:
#         mag
# 8870   0.19
# 3587   1.95
# 6356   5.50
# 11228  4.70
# 2900   1.70
# ...     ...
# 5282   0.90
# 13082 -0.65
# 21509  0.29
# 25047  1.22
# 19987  2.40
#
# [9349 rows x 1 columns]

# %%
mag_pred = actual_mag
mag_pred['Predicted'] = testpredict

# %%
mag_pred_all = mag_pred.rename(columns={'mag': 'Actual'})
mag_pred_all
# Out:
#        Actual  Predicted
# 8870     0.19     0.8647
# 3587     1.95     1.5123
# 6356     5.50     4.3670
# 11228    4.70     4.9100
# 2900     1.70     1.7160
# ...       ...        ...
# 5282     0.90     1.4377
# 13082   -0.65     0.4936
# 21509    0.29     0.5442
# 25047    1.22     1.3661
# 19987    2.40     2.6131
#
# [9349 rows x 2 columns]

# %%
mag_pred_all = mag_pred.merge(model_df, how='inner', left_index=True, right_index=True)
mag_pred_all
# Out:
#        mag_x  Predicted                             time   latitude  \
# 8870    0.19     0.8647 2022-01-20 23:40:46.420000+00:00  44.371333
# 3587    1.95     1.5123        2021-12-22 13:12:47+00:00  38.230500
# 6356    5.50     4.3670 2021-12-14 04:23:55.138000+00:00 -28.686100
# 11228   4.70     4.9100 2022-01-13 10:01:22.570000+00:00   1.481900
# 2900    1.70     1.7160 2021-12-24 20:15:05.365000+00:00  62.446400
# ...      ...        ...                              ...        ...
# 5282    0.90     1.4377 2021-12-17 13:30:12.501000+00:00  38.556100
# 13082  -0.65     0.4936 2022-01-08 09:26:27.250000+00:00  36.024333
# 21509   0.29     0.5442 2022-02-24 17:41:27.130000+00:00  33.471333
# 25047   1.22     1.3661 2022-02-13 05:04:17.780000+00:00  36.570833
# 19987   2.40     2.6131 2022-01-09 17:05:48.225000+00:00  65.215800
#
#         longitude  depth  mag_y magType   nst     gap  ...  \
# 8870  -110.388333   8.00   0.19      md  11.0  129.00  ...
# 3587  -112.381000   8.81   1.95      ml  23.0  185.00  ...
# 6356   -71.555500  17.79   5.50     mwr   NaN   65.00  ...
# 11228  122.982900  28.19   4.70      mb   NaN   57.00  ...
# 2900  -148.337100  33.50   1.70      ml   NaN     NaN  ...
# ...           ...    ...    ...     ...   ...     ...  ...
# 5282  -119.467700   6.70   0.90      ml   6.0  150.19  ...
# 13082 -117.802500   0.49  -0.65      ml   7.0  112.00  ...
# 21509 -116.567667  10.08   0.29      ml  14.0  136.00  ...
# 25047 -121.159667   3.61   1.22      md  19.0  119.00  ...
# 19987 -165.899200  15.50   2.40      ml   NaN     NaN  ...
#
#                                         place         type horizontalError  \
# 8870   65 km ESE of West Yellowstone, Montana   earthquake            0.41
# 3587            11 km NW of Circleville, Utah   earthquake            0.59
# 6356               78 km W of Vallenar, Chile   earthquake            4.20
# 11228        104 km N of Gorontalo, Indonesia   earthquake            6.50
# 2900            72 km N of Chickaloon, Alaska   earthquake             NaN
# ...                                       ...          ...             ...
# 5282          California-Nevada border region   earthquake             NaN
# 13082             13km E of Coso Junction, CA   earthquake            0.26
# 21509                     14km SE of Anza, CA   earthquake            0.23
# 25047                5km NNW of Pinnacles, CA   earthquake            0.33
# 19987             22 km ESE of Teller, Alaska  other event             NaN
#
#       depthError magError magNst     status  locationSource  magSource  \
# 8870        0.62    0.183    5.0   reviewed              uu         uu
# 3587        0.74    0.116    8.0   reviewed              uu         uu
# 6356        3.30      NaN    NaN   reviewed              us        guc
# 11228       5.90    0.147   14.0   reviewed              us         us
# 2900        0.20      NaN    NaN  automatic              ak         ak
# ...          ...      ...    ...        ...             ...        ...
# 5282        2.90    0.370    2.0   reviewed              nn         nn
# 13082       0.94    0.119    3.0   reviewed              ci         ci
# 21509       0.42    0.116   11.0   reviewed              ci         ci
# 25047       0.23    0.286   14.0   reviewed              nc         nc
# 19987       0.40      NaN    NaN   reviewed              ak         ak
#
#           Unix Time
# 8870   1.642722e+09
# 3587   1.640179e+09
# 6356   1.639456e+09
# 11228  1.642068e+09
# 2900   1.640377e+09
# ...             ...
# 5282   1.639748e+09
# 13082  1.641634e+09
# 21509  1.645724e+09
# 25047  1.644729e+09
# 19987  1.641748e+09
#
# [9349 rows x 25 columns]

# %%
mag_pred_all = mag_pred_all.rename(columns={'mag_x': 'Actual', 'mag_y': 'mag'})
mag_pred_all
# Out:
#        Actual  Predicted                             time   latitude  \
# 8870     0.19     0.8647 2022-01-20 23:40:46.420000+00:00  44.371333
# 3587     1.95     1.5123        2021-12-22 13:12:47+00:00  38.230500
# 6356     5.50     4.3670 2021-12-14 04:23:55.138000+00:00 -28.686100
# 11228    4.70     4.9100 2022-01-13 10:01:22.570000+00:00   1.481900
# 2900     1.70     1.7160 2021-12-24 20:15:05.365000+00:00  62.446400
# ...       ...        ...                              ...        ...
# 5282     0.90     1.4377 2021-12-17 13:30:12.501000+00:00  38.556100
# 13082   -0.65     0.4936 2022-01-08 09:26:27.250000+00:00  36.024333
# 21509    0.29     0.5442 2022-02-24 17:41:27.130000+00:00  33.471333
# 25047    1.22     1.3661 2022-02-13 05:04:17.780000+00:00  36.570833
# 19987    2.40     2.6131 2022-01-09 17:05:48.225000+00:00  65.215800
#
#         longitude  depth   mag magType   nst     gap  ...  \
# 8870  -110.388333   8.00  0.19      md  11.0  129.00  ...
# 3587  -112.381000   8.81  1.95      ml  23.0  185.00  ...
# 6356   -71.555500  17.79  5.50     mwr   NaN   65.00  ...
# 11228  122.982900  28.19  4.70      mb   NaN   57.00  ...
# 2900  -148.337100  33.50  1.70      ml   NaN     NaN  ...
# ...           ...    ...   ...     ...   ...     ...  ...
# 5282  -119.467700   6.70  0.90      ml   6.0  150.19  ...
# 13082 -117.802500   0.49 -0.65      ml   7.0  112.00  ...
# 21509 -116.567667  10.08  0.29      ml  14.0  136.00  ...
# 25047 -121.159667   3.61  1.22      md  19.0  119.00  ...
# 19987 -165.899200  15.50  2.40      ml   NaN     NaN  ...
#
#                                         place         type horizontalError  \
# 8870   65 km ESE of West Yellowstone, Montana   earthquake            0.41
# 3587            11 km NW of Circleville, Utah   earthquake            0.59
# 6356               78 km W of Vallenar, Chile   earthquake            4.20
# 11228        104 km N of Gorontalo, Indonesia   earthquake            6.50
# 2900            72 km N of Chickaloon, Alaska   earthquake             NaN
# ...                                       ...          ...             ...
# 5282          California-Nevada border region   earthquake             NaN
# 13082             13km E of Coso Junction, CA   earthquake            0.26
# 21509                     14km SE of Anza, CA   earthquake            0.23
# 25047                5km NNW of Pinnacles, CA   earthquake            0.33
# 19987             22 km ESE of Teller, Alaska  other event             NaN
#
#       depthError magError magNst     status  locationSource  magSource  \
# 8870        0.62    0.183    5.0   reviewed              uu         uu
# 3587        0.74    0.116    8.0   reviewed              uu         uu
# 6356        3.30      NaN    NaN   reviewed              us        guc
# 11228       5.90    0.147   14.0   reviewed              us         us
# 2900        0.20      NaN    NaN  automatic              ak         ak
# ...          ...      ...    ...        ...             ...        ...
# 5282        2.90    0.370    2.0   reviewed              nn         nn
# 13082       0.94    0.119    3.0   reviewed              ci         ci
# 21509       0.42    0.116   11.0   reviewed              ci         ci
# 25047       0.23    0.286   14.0   reviewed              nc         nc
# 19987       0.40      NaN    NaN   reviewed              ak         ak
#
#           Unix Time
# 8870   1.642722e+09
# 3587   1.640179e+09
# 6356   1.639456e+09
# 11228  1.642068e+09
# 2900   1.640377e+09
# ...             ...
# 5282   1.639748e+09
# 13082  1.641634e+09
# 21509  1.645724e+09
# 25047  1.644729e+09
# 19987  1.641748e+09
#
# [9349 rows x 25 columns]

# %%
x = np.array(mag_pred_all['mag'])
y = np.array(testpredict)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Magnitude', fontsize=13)
plt.xlabel('Actual Magnitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Magnitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Magnitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(mag_pred_all['mag'], testpredict)), (0, 3.5),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 3.2), fontsize=12)

fig.savefig('../static/images/extratrees_mag_linear_sns.png', dpi=600)
plt.show()

# %% [markdown]
# Test with new data from USGS

# %%
page_url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.csv"

test_df = pd.read_csv(page_url)
test_df
# Out:
#                          time   latitude   longitude      depth   mag magType  \
# 0    2022-03-12T02:43:18.091Z  63.253700 -151.154500   7.900000  0.80      ml
# 1    2022-03-12T02:24:53.720Z  36.356667 -117.965833   4.160000  1.85      ml
# 2    2022-03-12T02:00:45.806Z  -7.998200  120.725100  10.000000  4.80      mb
# 3    2022-03-12T01:49:47.220Z  38.077667 -122.232330   9.950000  2.24      md
# 4    2022-03-12T01:44:13.050Z  41.029499 -121.745499   1.110000  2.17      md
# ..                        ...        ...         ...        ...   ...     ...
# 244  2022-03-11T03:40:26.490Z  37.461167 -118.817000   3.810000  0.69      md
# 245  2022-03-11T03:32:49.730Z  19.133833 -155.474167  30.530001  2.27      md
# 246  2022-03-11T03:27:19.180Z  38.182833 -111.247500   8.980000  1.57      ml
# 247  2022-03-11T03:25:27.783Z  61.605000 -150.402200  22.700000  1.50      ml
# 248  2022-03-11T03:10:21.920Z  38.820167 -122.765333   2.320000  0.31      md
#
#       nst    gap     dmin   rms  ...                   updated  \
# 0     NaN    NaN      NaN  0.57  ...  2022-03-12T02:45:49.817Z
# 1    22.0   82.0  0.12410  0.20  ...  2022-03-12T02:35:44.060Z
# 2     NaN   90.0  1.62500  0.66  ...  2022-03-12T02:22:47.040Z
# 3    52.0   38.0  0.02072  0.16  ...  2022-03-12T02:42:19.752Z
# 4    25.0   50.0  0.07271  0.08  ...  2022-03-12T01:51:10.852Z
# ..    ...    ...      ...   ...  ...                       ...
# 244   8.0  207.0  0.12900  0.03  ...  2022-03-11T05:15:11.165Z
# 245  30.0  173.0      NaN  0.14  ...  2022-03-11T03:36:02.870Z
# 246  17.0  109.0  0.46810  0.11  ...  2022-03-11T16:16:11.890Z
# 247   NaN    NaN      NaN  0.38  ...  2022-03-11T03:31:35.116Z
# 248   9.0  154.0  0.01089  0.03  ...  2022-03-11T10:17:23.049Z
#
#                                         place        type horizontalError  \
# 0    42 km SE of Denali National Park, Alaska  earthquake             NaN
# 1                      9km NNE of Olancha, CA  earthquake            0.39
# 2              73 km NNE of Ruteng, Indonesia  earthquake            2.80
# 3                     3km NNW of Crockett, CA  earthquake            0.24
# 4                      14km E of Big Bend, CA  earthquake            0.20
# ..                                        ...         ...             ...
# 244                 16km SW of Toms Place, CA  earthquake            1.55
# 245                  7 km S of Pāhala, Hawaii  earthquake            0.69
# 246                  19 km SE of Torrey, Utah  earthquake            0.44
# 247                9 km NE of Susitna, Alaska  earthquake             NaN
# 248                         4km W of Cobb, CA  earthquake            0.30
#
#     depthError  magError  magNst     status  locationSource magSource
# 0         0.40       NaN     NaN  automatic              ak        ak
# 1         3.42     0.220    27.0  automatic              ci        ci
# 2         1.90     0.127    21.0   reviewed              us        us
# 3         0.47     0.120    47.0  automatic              nc        nc
# 4         1.27     0.120    14.0  automatic              nc        nc
# ..         ...       ...     ...        ...             ...       ...
# 244       2.87     0.148     7.0   reviewed              nc        nc
# 245       0.93     1.130     3.0  automatic              hv        hv
# 246       1.67     0.227     3.0   reviewed              uu        uu
# 247       0.70       NaN     NaN  automatic              ak        ak
# 248       0.40     0.262     2.0   reviewed              nc        nc
#
# [249 rows x 22 columns]

# %%
test_df['Unix Time'] = pd.to_datetime(test_df['time']).astype(int)/10**9

# %%
cleaned_test_df = test_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_test_df
# Out:
#       latitude   longitude      depth   mag     Unix Time
# 0    63.253700 -151.154500   7.900000  0.80  1.647053e+09
# 1    36.356667 -117.965833   4.160000  1.85  1.647052e+09
# 2    -7.998200  120.725100  10.000000  4.80  1.647050e+09
# 3    38.077667 -122.232330   9.950000  2.24  1.647050e+09
# 4    41.029499 -121.745499   1.110000  2.17  1.647049e+09
# ..         ...         ...        ...   ...           ...
# 244  37.461167 -118.817000   3.810000  0.69  1.646970e+09
# 245  19.133833 -155.474167  30.530001  2.27  1.646970e+09
# 246  38.182833 -111.247500   8.980000  1.57  1.646969e+09
# 247  61.605000 -150.402200  22.700000  1.50  1.646969e+09
# 248  38.820167 -122.765333   2.320000  0.31  1.646968e+09
#
# [249 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_test_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X_test_data = cleaned_test_df.drop(['mag'], axis = 1)

y_test_data = cleaned_test_df[['mag']]

# %%
pred_data_y = best_model.predict(X_test_data)

# %%
test_pred_data = cleaned_test_df
test_pred_data['Predicted'] = pred_data_y
test_pred_data
# Out:
#       latitude   longitude      depth   mag     Unix Time  Predicted
# 0    63.253700 -151.154500   7.900000  0.80  1.647053e+09     1.4960
# 1    36.356667 -117.965833   4.160000  1.85  1.647052e+09     1.6466
# 2    -7.998200  120.725100  10.000000  4.80  1.647050e+09     4.5840
# 3    38.077667 -122.232330   9.950000  2.24  1.647050e+09     1.2060
# 4    41.029499 -121.745499   1.110000  2.17  1.647049e+09     0.9905
# ..         ...         ...        ...   ...           ...        ...
# 244  37.461167 -118.817000   3.810000  0.69  1.646970e+09     1.1499
# 245  19.133833 -155.474167  30.530001  2.27  1.646970e+09     1.8786
# 246  38.182833 -111.247500   8.980000  1.57  1.646969e+09     1.4917
# 247  61.605000 -150.402200  22.700000  1.50  1.646969e+09     1.4140
# 248  38.820167 -122.765333   2.320000  0.31  1.646968e+09     1.0306
#
# [249 rows x 6 columns]

# %%
from datetime import date
today = date.today()

x = np.array(test_pred_data['mag'])
y = np.array(pred_data_y)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'purple'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Magnitude', fontsize=13)
plt.xlabel('Actual Magnitude',  fontsize=13)
# Bigger title
plt.suptitle(f'Earthquake Magnitude Model Predictions Using Best Model and Daily Data ({today})', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Magnitude Values Using Best Model and Data Not Used For Testing Model Split', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(test_pred_data['mag'], pred_data_y)), (0, 3.5),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 3.2), fontsize=12)

fig.savefig('../static/images/extratrees_mag_linear_sns_daily.png', dpi=600)
plt.show()

# %%
#connection to a PostgreSQL local database
# ===========================================

# user_name_var = input('What is the username of your database? ')
host_var = input('What is the host address of your database?')
pw = input("Enter the database password: ")
# db_name = input("Enter the name of the database: ")

string_output = "postgresql://postgres"+':'+pw+'@'+host_var+":5432"+'/earthquake_db'
engine = create_engine(string_output)
connection = engine.connect()
print("Connected to database...")
#create new database with predicted values for both training and test databases
#=============
#PostgreSQL
mag_pred_all.to_sql('earthquake_etrees_mag', engine, if_exists='replace', index = False)
#=============
#SQLite
cur = conn.cursor()
mag_pred_all.to_sql('earthquake_etrees_mag', conn, if_exists='replace', index=False)
# Close connection to SQLite database
conn.close()
connection.close()
