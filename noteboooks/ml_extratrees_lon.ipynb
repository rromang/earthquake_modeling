# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("paper")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time   latitude  longitude       depth   mag  \
# 0      2022-01-06T01:42:39.855Z  37.384000 -117.10750    1.100000  1.30
# 1      2022-01-06T01:31:33.698Z  38.181000 -117.81800    7.300000  1.40
# 2      2022-01-06T01:24:20.083Z  61.340700 -149.88520   30.000000  1.50
# 3      2022-01-06T01:15:15.851Z  62.870300 -150.76250  111.300000  2.10
# 4      2022-01-06T01:10:44.629Z  64.014500 -148.76570    1.900000  1.50
# ...                         ...        ...        ...         ...   ...
# 28330  2022-01-30T03:46:53.207Z  63.278200 -151.25170    7.400000  1.00
# 28331  2022-01-30T03:44:08.272Z  67.671500 -160.82990    6.200000  2.90
# 28332  2022-01-30T03:37:46.570Z  19.221167 -155.38916   31.940001  1.83
# 28333  2022-01-30T03:32:41.102Z   2.757300  128.23460   53.450000  4.50
# 28334  2022-01-30T03:31:21.676Z  54.594200 -159.78450   19.200000  2.30
#
#       magType   nst     gap   dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.875  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.119  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN    NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN    NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN    NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...    ...     ...  ...                       ...
# 28330      ml   NaN     NaN    NaN  0.6600  ...  2022-02-25T00:07:27.831Z
# 28331      ml   NaN     NaN    NaN  0.5700  ...  2022-02-25T03:00:49.040Z
# 28332      md  43.0  152.00    NaN  0.1300  ...  2022-01-30T03:40:57.760Z
# 28333      mb   NaN  194.00  2.154  1.0300  ...  2022-02-05T01:40:12.040Z
# 28334      ml   NaN     NaN    NaN  0.5800  ...  2022-02-25T00:07:27.644Z
#
#                                           place        type horizontalError  \
# 0                37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                      34 km SE of Mina, Nevada  earthquake             NaN
# 2           5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3                41 km N of Petersville, Alaska  earthquake             NaN
# 4                      17 km E of Ferry, Alaska  earthquake             NaN
# ...                                         ...         ...             ...
# 28330  37 km SE of Denali National Park, Alaska  earthquake             NaN
# 28331                79 km NNW of Kiana, Alaska  earthquake             NaN
# 28332                9 km ENE of Pāhala, Hawaii  earthquake            0.59
# 28333                      Halmahera, Indonesia  earthquake           12.30
# 28334           94 km SSE of Sand Point, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0          39.10     0.290     4.0  automatic              nn        nn
# 1           2.00     0.460     5.0  automatic              nn        nn
# 2           0.20       NaN     NaN  automatic              ak        ak
# 3           0.80       NaN     NaN  automatic              ak        ak
# 4           0.60       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 28330       0.20       NaN     NaN   reviewed              ak        ak
# 28331       0.60       NaN     NaN   reviewed              ak        ak
# 28332       1.16     0.620     5.0  automatic              hv        hv
# 28333      10.40     0.272     5.0   reviewed              us        us
# 28334       1.20       NaN     NaN   reviewed              ak        ak
#
# [28335 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time   latitude  longitude       depth  \
# 0     2022-01-06 01:42:39.855000+00:00  37.384000 -117.10750    1.100000
# 1     2022-01-06 01:31:33.698000+00:00  38.181000 -117.81800    7.300000
# 2     2022-01-06 01:24:20.083000+00:00  61.340700 -149.88520   30.000000
# 3     2022-01-06 01:15:15.851000+00:00  62.870300 -150.76250  111.300000
# 4     2022-01-06 01:10:44.629000+00:00  64.014500 -148.76570    1.900000
# ...                                ...        ...        ...         ...
# 28330 2022-01-30 03:46:53.207000+00:00  63.278200 -151.25170    7.400000
# 28331 2022-01-30 03:44:08.272000+00:00  67.671500 -160.82990    6.200000
# 28332 2022-01-30 03:37:46.570000+00:00  19.221167 -155.38916   31.940001
# 28333 2022-01-30 03:32:41.102000+00:00   2.757300  128.23460   53.450000
# 28334 2022-01-30 03:31:21.676000+00:00  54.594200 -159.78450   19.200000
#
#         mag magType   nst     gap   dmin     rms  ...  \
# 0      1.30      ml   8.0  149.46  0.875  0.2175  ...
# 1      1.40      ml  11.0  154.64  0.119  0.1017  ...
# 2      1.50      ml   NaN     NaN    NaN  0.7500  ...
# 3      2.10      ml   NaN     NaN    NaN  0.3200  ...
# 4      1.50      ml   NaN     NaN    NaN  0.7200  ...
# ...     ...     ...   ...     ...    ...     ...  ...
# 28330  1.00      ml   NaN     NaN    NaN  0.6600  ...
# 28331  2.90      ml   NaN     NaN    NaN  0.5700  ...
# 28332  1.83      md  43.0  152.00    NaN  0.1300  ...
# 28333  4.50      mb   NaN  194.00  2.154  1.0300  ...
# 28334  2.30      ml   NaN     NaN    NaN  0.5800  ...
#
#                         updated                                     place  \
# 0      2022-01-06T01:47:19.317Z            37 km SSE of Goldfield, Nevada
# 1      2022-01-06T01:47:40.245Z                  34 km SE of Mina, Nevada
# 2      2022-01-06T01:29:22.015Z       5 km ESE of Point MacKenzie, Alaska
# 3      2022-01-06T01:29:21.875Z            41 km N of Petersville, Alaska
# 4      2022-01-06T01:15:56.292Z                  17 km E of Ferry, Alaska
# ...                         ...                                       ...
# 28330  2022-02-25T00:07:27.831Z  37 km SE of Denali National Park, Alaska
# 28331  2022-02-25T03:00:49.040Z                79 km NNW of Kiana, Alaska
# 28332  2022-01-30T03:40:57.760Z                9 km ENE of Pāhala, Hawaii
# 28333  2022-02-05T01:40:12.040Z                      Halmahera, Indonesia
# 28334  2022-02-25T00:07:27.644Z           94 km SSE of Sand Point, Alaska
#
#              type horizontalError depthError  magError  magNst     status  \
# 0      earthquake             NaN      39.10     0.290     4.0  automatic
# 1      earthquake             NaN       2.00     0.460     5.0  automatic
# 2      earthquake             NaN       0.20       NaN     NaN  automatic
# 3      earthquake             NaN       0.80       NaN     NaN  automatic
# 4      earthquake             NaN       0.60       NaN     NaN  automatic
# ...           ...             ...        ...       ...     ...        ...
# 28330  earthquake             NaN       0.20       NaN     NaN   reviewed
# 28331  earthquake             NaN       0.60       NaN     NaN   reviewed
# 28332  earthquake            0.59       1.16     0.620     5.0  automatic
# 28333  earthquake           12.30      10.40     0.272     5.0   reviewed
# 28334  earthquake             NaN       1.20       NaN     NaN   reviewed
#
#        locationSource magSource
# 0                  nn        nn
# 1                  nn        nn
# 2                  ak        ak
# 3                  ak        ak
# 4                  ak        ak
# ...               ...       ...
# 28330              ak        ak
# 28331              ak        ak
# 28332              hv        hv
# 28333              us        us
# 28334              ak        ak
#
# [28335 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#         latitude  longitude       depth   mag     Unix Time
# 0      37.384000 -117.10750    1.100000  1.30  1.641433e+09
# 1      38.181000 -117.81800    7.300000  1.40  1.641433e+09
# 2      61.340700 -149.88520   30.000000  1.50  1.641432e+09
# 3      62.870300 -150.76250  111.300000  2.10  1.641432e+09
# 4      64.014500 -148.76570    1.900000  1.50  1.641431e+09
# ...          ...        ...         ...   ...           ...
# 28330  63.278200 -151.25170    7.400000  1.00  1.643514e+09
# 28331  67.671500 -160.82990    6.200000  2.90  1.643514e+09
# 28332  19.221167 -155.38916   31.940001  1.83  1.643514e+09
# 28333   2.757300  128.23460   53.450000  4.50  1.643514e+09
# 28334  54.594200 -159.78450   19.200000  2.30  1.643513e+09
#
# [28335 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: longitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['longitude'], axis = 1)

y = cleaned_df_dropped[['longitude']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((28329, 4), (28329, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1468.206087793255, 	R2 score: 0.7176563235610756, 	Model score: 0.7176563235610756
# n_estimators=3:
# 	Mean Squared Error: 1315.4806201386173, 	R2 score: 0.747026226316537, 	Model score: 0.747026226316537
# n_estimators=4:
# 	Mean Squared Error: 1193.6739578434726, 	R2 score: 0.7704502817901501, 	Model score: 0.7704502817901501
# n_estimators=5:
# 	Mean Squared Error: 1174.737664166602, 	R2 score: 0.7740918296759042, 	Model score: 0.7740918296759042
# n_estimators=6:
# 	Mean Squared Error: 1110.3292403641422, 	R2 score: 0.78647790498319, 	Model score: 0.78647790498319
# n_estimators=7:
# 	Mean Squared Error: 1089.5475762355027, 	R2 score: 0.7904743272166778, 	Model score: 0.7904743272166778
# n_estimators=8:
# 	Mean Squared Error: 1101.4753031009338, 	R2 score: 0.788180563226224, 	Model score: 0.788180563226224
# n_estimators=9:
# 	Mean Squared Error: 1059.444717750955, 	R2 score: 0.7962632636653902, 	Model score: 0.7962632636653902
# n_estimators=10:
# 	Mean Squared Error: 1039.1504484414165, 	R2 score: 0.800165957337032, 	Model score: 0.800165957337032
# n_estimators=11:
# 	Mean Squared Error: 1036.2162661577495, 	R2 score: 0.8007302158700815, 	Model score: 0.8007302158700815
# n_estimators=12:
# 	Mean Squared Error: 1018.5968872602203, 	R2 score: 0.8041185141858689, 	Model score: 0.8041185141858689
# n_estimators=13:
# 	Mean Squared Error: 1014.3585488003631, 	R2 score: 0.804933568743058, 	Model score: 0.804933568743058
# n_estimators=14:
# 	Mean Squared Error: 1006.0626160920575, 	R2 score: 0.8065289198043477, 	Model score: 0.8065289198043477
# n_estimators=15:
# 	Mean Squared Error: 996.944891148436, 	R2 score: 0.8082823057920125, 	Model score: 0.8082823057920125
# n_estimators=16:
# 	Mean Squared Error: 999.9740159761482, 	R2 score: 0.8076997893133252, 	Model score: 0.8076997893133252
# n_estimators=17:
# 	Mean Squared Error: 1001.2770335781207, 	R2 score: 0.8074492122429369, 	Model score: 0.8074492122429369
# n_estimators=18:
# 	Mean Squared Error: 996.2807977699662, 	R2 score: 0.8084100144069917, 	Model score: 0.8084100144069917
# n_estimators=19:
# 	Mean Squared Error: 994.4224712762293, 	R2 score: 0.8087673802690649, 	Model score: 0.8087673802690649
# n_estimators=20:
# 	Mean Squared Error: 991.5391772104072, 	R2 score: 0.8093218527328199, 	Model score: 0.8093218527328199
# n_estimators=21:
# 	Mean Squared Error: 989.3256402983801, 	R2 score: 0.8097475274081063, 	Model score: 0.8097475274081063
# n_estimators=22:
# 	Mean Squared Error: 987.1403189791715, 	R2 score: 0.8101677760779598, 	Model score: 0.8101677760779598
# n_estimators=23:
# 	Mean Squared Error: 990.3112085208667, 	R2 score: 0.8095579975065266, 	Model score: 0.8095579975065266
# n_estimators=24:
# 	Mean Squared Error: 986.6261376872657, 	R2 score: 0.8102666558180178, 	Model score: 0.8102666558180178
# n_estimators=25:
# 	Mean Squared Error: 986.2069903818868, 	R2 score: 0.8103472600275726, 	Model score: 0.8103472600275726
# n_estimators=26:
# 	Mean Squared Error: 984.5644829760321, 	R2 score: 0.8106631227551576, 	Model score: 0.8106631227551576
# n_estimators=27:
# 	Mean Squared Error: 983.2115341364197, 	R2 score: 0.8109233018625635, 	Model score: 0.8109233018625635
# n_estimators=28:
# 	Mean Squared Error: 981.3847266608917, 	R2 score: 0.8112746064532984, 	Model score: 0.8112746064532984
# n_estimators=29:
# 	Mean Squared Error: 982.9633545825776, 	R2 score: 0.8109710280831747, 	Model score: 0.8109710280831747
# n_estimators=30:
# 	Mean Squared Error: 980.0345874745783, 	R2 score: 0.8115342452497435, 	Model score: 0.8115342452497435
# n_estimators=31:
# 	Mean Squared Error: 979.7291023599583, 	R2 score: 0.8115929916281138, 	Model score: 0.8115929916281138
# n_estimators=32:
# 	Mean Squared Error: 974.7750760910468, 	R2 score: 0.812545676677964, 	Model score: 0.812545676677964
# n_estimators=33:
# 	Mean Squared Error: 967.3229687229924, 	R2 score: 0.8139787557320608, 	Model score: 0.8139787557320608
# n_estimators=34:
# 	Mean Squared Error: 964.4776383369613, 	R2 score: 0.8145259275824942, 	Model score: 0.8145259275824942
# n_estimators=35:
# 	Mean Squared Error: 962.6811011176615, 	R2 score: 0.8148714110453226, 	Model score: 0.8148714110453226
# n_estimators=36:
# 	Mean Squared Error: 964.4917476436106, 	R2 score: 0.8145232142893506, 	Model score: 0.8145232142893506
# n_estimators=37:
# 	Mean Squared Error: 964.9987448599618, 	R2 score: 0.814425716084433, 	Model score: 0.814425716084433
# n_estimators=38:
# 	Mean Squared Error: 967.432031394074, 	R2 score: 0.8139577824124625, 	Model score: 0.8139577824124625
# n_estimators=39:
# 	Mean Squared Error: 964.318085206922, 	R2 score: 0.8145566104802816, 	Model score: 0.8145566104802816
# n_estimators=40:
# 	Mean Squared Error: 962.1768801730484, 	R2 score: 0.8149683753587273, 	Model score: 0.8149683753587273
# n_estimators=41:
# 	Mean Squared Error: 962.1229426289627, 	R2 score: 0.8149787478293374, 	Model score: 0.8149787478293374
# n_estimators=42:
# 	Mean Squared Error: 963.2455315252887, 	R2 score: 0.8147628681386364, 	Model score: 0.8147628681386364
# n_estimators=43:
# 	Mean Squared Error: 961.2116346659103, 	R2 score: 0.815153997096314, 	Model score: 0.815153997096314
# n_estimators=44:
# 	Mean Squared Error: 960.2684449988451, 	R2 score: 0.8153353773809977, 	Model score: 0.8153353773809977
# n_estimators=45:
# 	Mean Squared Error: 958.7398939830993, 	R2 score: 0.8156293257013312, 	Model score: 0.8156293257013312
# n_estimators=46:
# 	Mean Squared Error: 956.1275081272697, 	R2 score: 0.8161317011055366, 	Model score: 0.8161317011055366
# n_estimators=47:
# 	Mean Squared Error: 955.4152998428985, 	R2 score: 0.8162686624674812, 	Model score: 0.8162686624674812
# n_estimators=48:
# 	Mean Squared Error: 957.1073581341919, 	R2 score: 0.8159432708465877, 	Model score: 0.8159432708465877
# n_estimators=49:
# 	Mean Squared Error: 956.6796130624232, 	R2 score: 0.8160255284513926, 	Model score: 0.8160255284513926
# n_estimators=50:
# 	Mean Squared Error: 957.0601434959881, 	R2 score: 0.8159523504673869, 	Model score: 0.8159523504673869
# Max score: 0.8162686624674812
# Best model score:  0.8162686624674812

# %%
#create and run model: Now with 200 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,200):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 50:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1468.206087793255, 	R2: 0.7176563235610756, 	Model score: 0.7176563235610756
# n_estimators=3:
# 	Mean Squared Error: 1315.4806201386173, 	R2: 0.747026226316537, 	Model score: 0.747026226316537
# n_estimators=4:
# 	Mean Squared Error: 1193.6739578434726, 	R2: 0.7704502817901501, 	Model score: 0.7704502817901501
# n_estimators=5:
# 	Mean Squared Error: 1174.737664166602, 	R2: 0.7740918296759042, 	Model score: 0.7740918296759042
# n_estimators=6:
# 	Mean Squared Error: 1110.3292403641422, 	R2: 0.78647790498319, 	Model score: 0.78647790498319
# n_estimators=7:
# 	Mean Squared Error: 1089.5475762355027, 	R2: 0.7904743272166778, 	Model score: 0.7904743272166778
# n_estimators=8:
# 	Mean Squared Error: 1101.4753031009338, 	R2: 0.788180563226224, 	Model score: 0.788180563226224
# n_estimators=9:
# 	Mean Squared Error: 1059.444717750955, 	R2: 0.7962632636653902, 	Model score: 0.7962632636653902
# n_estimators=10:
# 	Mean Squared Error: 1039.1504484414165, 	R2: 0.800165957337032, 	Model score: 0.800165957337032
# n_estimators=11:
# 	Mean Squared Error: 1036.2162661577495, 	R2: 0.8007302158700815, 	Model score: 0.8007302158700815
# n_estimators=12:
# 	Mean Squared Error: 1018.5968872602203, 	R2: 0.8041185141858689, 	Model score: 0.8041185141858689
# n_estimators=13:
# 	Mean Squared Error: 1014.3585488003631, 	R2: 0.804933568743058, 	Model score: 0.804933568743058
# n_estimators=14:
# 	Mean Squared Error: 1006.0626160920575, 	R2: 0.8065289198043477, 	Model score: 0.8065289198043477
# n_estimators=15:
# 	Mean Squared Error: 996.944891148436, 	R2: 0.8082823057920125, 	Model score: 0.8082823057920125
# n_estimators=16:
# 	Mean Squared Error: 999.9740159761482, 	R2: 0.8076997893133252, 	Model score: 0.8076997893133252
# n_estimators=17:
# 	Mean Squared Error: 1001.2770335781207, 	R2: 0.8074492122429369, 	Model score: 0.8074492122429369
# n_estimators=18:
# 	Mean Squared Error: 996.2807977699662, 	R2: 0.8084100144069917, 	Model score: 0.8084100144069917
# n_estimators=19:
# 	Mean Squared Error: 994.4224712762293, 	R2: 0.8087673802690649, 	Model score: 0.8087673802690649
# n_estimators=20:
# 	Mean Squared Error: 991.5391772104072, 	R2: 0.8093218527328199, 	Model score: 0.8093218527328199
# n_estimators=21:
# 	Mean Squared Error: 989.3256402983801, 	R2: 0.8097475274081063, 	Model score: 0.8097475274081063
# n_estimators=22:
# 	Mean Squared Error: 987.1403189791715, 	R2: 0.8101677760779598, 	Model score: 0.8101677760779598
# n_estimators=23:
# 	Mean Squared Error: 990.3112085208667, 	R2: 0.8095579975065266, 	Model score: 0.8095579975065266
# n_estimators=24:
# 	Mean Squared Error: 986.6261376872657, 	R2: 0.8102666558180178, 	Model score: 0.8102666558180178
# n_estimators=25:
# 	Mean Squared Error: 986.2069903818868, 	R2: 0.8103472600275726, 	Model score: 0.8103472600275726
# n_estimators=26:
# 	Mean Squared Error: 984.5644829760321, 	R2: 0.8106631227551576, 	Model score: 0.8106631227551576
# n_estimators=27:
# 	Mean Squared Error: 983.2115341364197, 	R2: 0.8109233018625635, 	Model score: 0.8109233018625635
# n_estimators=28:
# 	Mean Squared Error: 981.3847266608917, 	R2: 0.8112746064532984, 	Model score: 0.8112746064532984
# n_estimators=29:
# 	Mean Squared Error: 982.9633545825776, 	R2: 0.8109710280831747, 	Model score: 0.8109710280831747
# n_estimators=30:
# 	Mean Squared Error: 980.0345874745783, 	R2: 0.8115342452497435, 	Model score: 0.8115342452497435
# n_estimators=31:
# 	Mean Squared Error: 979.7291023599583, 	R2: 0.8115929916281138, 	Model score: 0.8115929916281138
# n_estimators=32:
# 	Mean Squared Error: 974.7750760910468, 	R2: 0.812545676677964, 	Model score: 0.812545676677964
# n_estimators=33:
# 	Mean Squared Error: 967.3229687229924, 	R2: 0.8139787557320608, 	Model score: 0.8139787557320608
# n_estimators=34:
# 	Mean Squared Error: 964.4776383369613, 	R2: 0.8145259275824942, 	Model score: 0.8145259275824942
# n_estimators=35:
# 	Mean Squared Error: 962.6811011176615, 	R2: 0.8148714110453226, 	Model score: 0.8148714110453226
# n_estimators=36:
# 	Mean Squared Error: 964.4917476436106, 	R2: 0.8145232142893506, 	Model score: 0.8145232142893506
# n_estimators=37:
# 	Mean Squared Error: 964.9987448599618, 	R2: 0.814425716084433, 	Model score: 0.814425716084433
# n_estimators=38:
# 	Mean Squared Error: 967.432031394074, 	R2: 0.8139577824124625, 	Model score: 0.8139577824124625
# n_estimators=39:
# 	Mean Squared Error: 964.318085206922, 	R2: 0.8145566104802816, 	Model score: 0.8145566104802816
# n_estimators=40:
# 	Mean Squared Error: 962.1768801730484, 	R2: 0.8149683753587273, 	Model score: 0.8149683753587273
# n_estimators=41:
# 	Mean Squared Error: 962.1229426289627, 	R2: 0.8149787478293374, 	Model score: 0.8149787478293374
# n_estimators=42:
# 	Mean Squared Error: 963.2455315252887, 	R2: 0.8147628681386364, 	Model score: 0.8147628681386364
# n_estimators=43:
# 	Mean Squared Error: 961.2116346659103, 	R2: 0.815153997096314, 	Model score: 0.815153997096314
# n_estimators=44:
# 	Mean Squared Error: 960.2684449988451, 	R2: 0.8153353773809977, 	Model score: 0.8153353773809977
# n_estimators=45:
# 	Mean Squared Error: 958.7398939830993, 	R2: 0.8156293257013312, 	Model score: 0.8156293257013312
# n_estimators=46:
# 	Mean Squared Error: 956.1275081272697, 	R2: 0.8161317011055366, 	Model score: 0.8161317011055366
# n_estimators=47:
# 	Mean Squared Error: 955.4152998428985, 	R2: 0.8162686624674812, 	Model score: 0.8162686624674812
# n_estimators=48:
# 	Mean Squared Error: 957.1073581341919, 	R2: 0.8159432708465877, 	Model score: 0.8159432708465877
# n_estimators=49:
# 	Mean Squared Error: 956.6796130624232, 	R2: 0.8160255284513926, 	Model score: 0.8160255284513926
# n_estimators=50:
# 	Mean Squared Error: 957.0601434959881, 	R2: 0.8159523504673869, 	Model score: 0.8159523504673869
# n_estimators=51:
# 	Mean Squared Error: 954.9051835029962, 	R2: 0.8163667604961007, 	Model score: 0.8163667604961007
# Improvement found!
# n_estimators=52:
# 	Mean Squared Error: 954.7104151177995, 	R2: 0.8164042154708401, 	Model score: 0.8164042154708401
# Improvement found!
# n_estimators=53:
# 	Mean Squared Error: 951.8174035607944, 	R2: 0.8169605566587539, 	Model score: 0.8169605566587539
# Improvement found!
# n_estimators=54:
# 	Mean Squared Error: 951.0109205593832, 	R2: 0.8171156475397257, 	Model score: 0.8171156475397257
# Improvement found!
# n_estimators=55:
# 	Mean Squared Error: 952.6967988111224, 	R2: 0.8167914443726212, 	Model score: 0.8167914443726212
# n_estimators=56:
# 	Mean Squared Error: 952.0506169054244, 	R2: 0.8169157085181113, 	Model score: 0.8169157085181113
# n_estimators=57:
# 	Mean Squared Error: 951.4431185064452, 	R2: 0.8170325336238132, 	Model score: 0.8170325336238132
# n_estimators=58:
# 	Mean Squared Error: 950.6514545102647, 	R2: 0.8171847747329084, 	Model score: 0.8171847747329084
# Improvement found!
# n_estimators=59:
# 	Mean Squared Error: 951.1958072769463, 	R2: 0.8170800928611315, 	Model score: 0.8170800928611315
# n_estimators=60:
# 	Mean Squared Error: 950.1008488057611, 	R2: 0.8172906590771911, 	Model score: 0.8172906590771911
# Improvement found!
# n_estimators=61:
# 	Mean Squared Error: 949.6153939765637, 	R2: 0.817384014568876, 	Model score: 0.817384014568876
# Improvement found!
# n_estimators=62:
# 	Mean Squared Error: 950.6156824334339, 	R2: 0.8171916538895678, 	Model score: 0.8171916538895678
# n_estimators=63:
# 	Mean Squared Error: 951.0004261039783, 	R2: 0.8171176656781504, 	Model score: 0.8171176656781504
# n_estimators=64:
# 	Mean Squared Error: 948.963233314435, 	R2: 0.8175094284603623, 	Model score: 0.8175094284603623
# Improvement found!
# n_estimators=65:
# 	Mean Squared Error: 950.1609515017943, 	R2: 0.8172791010157561, 	Model score: 0.8172791010157561
# n_estimators=66:
# 	Mean Squared Error: 951.4632523179091, 	R2: 0.8170286617870209, 	Model score: 0.8170286617870209
# n_estimators=67:
# 	Mean Squared Error: 951.86821555776, 	R2: 0.8169507852471314, 	Model score: 0.8169507852471314
# n_estimators=68:
# 	Mean Squared Error: 952.0510955315335, 	R2: 0.8169156164758181, 	Model score: 0.8169156164758181
# n_estimators=69:
# 	Mean Squared Error: 951.3658855101905, 	R2: 0.8170473859311878, 	Model score: 0.8170473859311878
# n_estimators=70:
# 	Mean Squared Error: 951.6124695930403, 	R2: 0.8169999665279568, 	Model score: 0.8169999665279568
# n_estimators=71:
# 	Mean Squared Error: 952.3961933401941, 	R2: 0.8168492523700986, 	Model score: 0.8168492523700986
# n_estimators=72:
# 	Mean Squared Error: 952.8672419724794, 	R2: 0.816758667265101, 	Model score: 0.816758667265101
# n_estimators=73:
# 	Mean Squared Error: 953.8075592683662, 	R2: 0.8165778393523528, 	Model score: 0.8165778393523528
# n_estimators=74:
# 	Mean Squared Error: 954.7519960646744, 	R2: 0.8163962192382213, 	Model score: 0.8163962192382213
# n_estimators=75:
# 	Mean Squared Error: 955.053652088979, 	R2: 0.8163382092138587, 	Model score: 0.8163382092138587
# n_estimators=76:
# 	Mean Squared Error: 953.8857308645216, 	R2: 0.8165628065473297, 	Model score: 0.8165628065473297
# n_estimators=77:
# 	Mean Squared Error: 951.0470287876158, 	R2: 0.817108703739401, 	Model score: 0.817108703739401
# n_estimators=78:
# 	Mean Squared Error: 952.8042962187172, 	R2: 0.8167707720613426, 	Model score: 0.8167707720613426
# n_estimators=79:
# 	Mean Squared Error: 952.7949612699002, 	R2: 0.8167725672206123, 	Model score: 0.8167725672206123
# n_estimators=80:
# 	Mean Squared Error: 951.3311380001405, 	R2: 0.8170540680583197, 	Model score: 0.8170540680583197
# n_estimators=81:
# 	Mean Squared Error: 951.2387692677695, 	R2: 0.8170718310465694, 	Model score: 0.8170718310465694
# n_estimators=82:
# 	Mean Squared Error: 949.6768431340342, 	R2: 0.8173721975758947, 	Model score: 0.8173721975758947
# n_estimators=83:
# 	Mean Squared Error: 948.1570446559858, 	R2: 0.8176644627376497, 	Model score: 0.8176644627376497
# Improvement found!
# n_estimators=84:
# 	Mean Squared Error: 949.5231006385332, 	R2: 0.8174017630584014, 	Model score: 0.8174017630584014
# n_estimators=85:
# 	Mean Squared Error: 948.51282592703, 	R2: 0.8175960441464792, 	Model score: 0.8175960441464792
# n_estimators=86:
# 	Mean Squared Error: 949.4093372297382, 	R2: 0.8174236403543412, 	Model score: 0.8174236403543412
# n_estimators=87:
# 	Mean Squared Error: 950.624326903363, 	R2: 0.817189991512984, 	Model score: 0.817189991512984
# n_estimators=88:
# 	Mean Squared Error: 949.7219344909811, 	R2: 0.8173635262731385, 	Model score: 0.8173635262731385
# n_estimators=89:
# 	Mean Squared Error: 948.2860706399292, 	R2: 0.8176396503690282, 	Model score: 0.8176396503690282
# n_estimators=90:
# 	Mean Squared Error: 947.4488641681138, 	R2: 0.8178006495333526, 	Model score: 0.8178006495333526
# Improvement found!
# n_estimators=91:
# 	Mean Squared Error: 947.6282756763732, 	R2: 0.8177661477660201, 	Model score: 0.8177661477660201
# n_estimators=92:
# 	Mean Squared Error: 946.8972579437477, 	R2: 0.8179067262828151, 	Model score: 0.8179067262828151
# Improvement found!
# n_estimators=93:
# 	Mean Squared Error: 946.2095589413868, 	R2: 0.8180389743821959, 	Model score: 0.8180389743821959
# Improvement found!
# n_estimators=94:
# 	Mean Squared Error: 946.4994806720382, 	R2: 0.8179832209236098, 	Model score: 0.8179832209236098
# n_estimators=95:
# 	Mean Squared Error: 946.6906772256111, 	R2: 0.8179464528306921, 	Model score: 0.8179464528306921
# n_estimators=96:
# 	Mean Squared Error: 946.1910888064155, 	R2: 0.818042526285335, 	Model score: 0.818042526285335
# Improvement found!
# n_estimators=97:
# 	Mean Squared Error: 945.2905004360941, 	R2: 0.8182157141188067, 	Model score: 0.8182157141188067
# Improvement found!
# n_estimators=98:
# 	Mean Squared Error: 944.1478008618338, 	R2: 0.8184354611976018, 	Model score: 0.8184354611976018
# Improvement found!
# n_estimators=99:
# 	Mean Squared Error: 944.948331130171, 	R2: 0.8182815150581993, 	Model score: 0.8182815150581993
# n_estimators=100:
# 	Mean Squared Error: 945.7219623957112, 	R2: 0.8181327417371126, 	Model score: 0.8181327417371126
# n_estimators=101:
# 	Mean Squared Error: 946.4365563523393, 	R2: 0.8179953215979694, 	Model score: 0.8179953215979694
# n_estimators=102:
# 	Mean Squared Error: 945.870132468949, 	R2: 0.8181042478604259, 	Model score: 0.8181042478604259
# n_estimators=103:
# 	Mean Squared Error: 946.4508123899293, 	R2: 0.8179925800877018, 	Model score: 0.8179925800877018
# n_estimators=104:
# 	Mean Squared Error: 947.1991485706023, 	R2: 0.8178486711431605, 	Model score: 0.8178486711431605
# n_estimators=105:
# 	Mean Squared Error: 947.0011351607554, 	R2: 0.8178867501530388, 	Model score: 0.8178867501530388
# n_estimators=106:
# 	Mean Squared Error: 947.3242968999731, 	R2: 0.8178246044677063, 	Model score: 0.8178246044677063
# n_estimators=107:
# 	Mean Squared Error: 947.142949602565, 	R2: 0.8178594784973731, 	Model score: 0.8178594784973731
# n_estimators=108:
# 	Mean Squared Error: 947.4258924635086, 	R2: 0.8178050671117745, 	Model score: 0.8178050671117745
# n_estimators=109:
# 	Mean Squared Error: 947.378881005005, 	R2: 0.8178141076600592, 	Model score: 0.8178141076600592
# n_estimators=110:
# 	Mean Squared Error: 946.5531675446596, 	R2: 0.8179728966584277, 	Model score: 0.8179728966584277
# n_estimators=111:
# 	Mean Squared Error: 947.2028169107105, 	R2: 0.8178479657022547, 	Model score: 0.8178479657022547
# n_estimators=112:
# 	Mean Squared Error: 945.8708626064301, 	R2: 0.8181041074511861, 	Model score: 0.8181041074511861
# n_estimators=113:
# 	Mean Squared Error: 945.7463199228125, 	R2: 0.818128057657808, 	Model score: 0.818128057657808
# n_estimators=114:
# 	Mean Squared Error: 943.4652512299393, 	R2: 0.8185667190462262, 	Model score: 0.8185667190462262
# Improvement found!
# n_estimators=115:
# 	Mean Squared Error: 944.8644845418924, 	R2: 0.8182976391937606, 	Model score: 0.8182976391937606
# n_estimators=116:
# 	Mean Squared Error: 945.4761791238734, 	R2: 0.8181800071402157, 	Model score: 0.8181800071402157
# n_estimators=117:
# 	Mean Squared Error: 945.1270723928187, 	R2: 0.8182471421825881, 	Model score: 0.8182471421825881
# n_estimators=118:
# 	Mean Squared Error: 944.6214939917948, 	R2: 0.8183443675419297, 	Model score: 0.8183443675419297
# n_estimators=119:
# 	Mean Squared Error: 944.0380128226674, 	R2: 0.8184565740092602, 	Model score: 0.8184565740092602
# n_estimators=120:
# 	Mean Squared Error: 945.2854793342891, 	R2: 0.8182166797028314, 	Model score: 0.8182166797028314
# n_estimators=121:
# 	Mean Squared Error: 944.5189150537364, 	R2: 0.8183640940059033, 	Model score: 0.8183640940059033
# n_estimators=122:
# 	Mean Squared Error: 945.106437498138, 	R2: 0.8182511103802925, 	Model score: 0.8182511103802925
# n_estimators=123:
# 	Mean Squared Error: 945.4735898072025, 	R2: 0.8181805050792954, 	Model score: 0.8181805050792954
# n_estimators=124:
# 	Mean Squared Error: 943.7385236966728, 	R2: 0.8185141673277935, 	Model score: 0.8185141673277935
# n_estimators=125:
# 	Mean Squared Error: 943.4182975073749, 	R2: 0.8185757484915892, 	Model score: 0.8185757484915892
# Improvement found!
# n_estimators=126:
# 	Mean Squared Error: 943.2269658666355, 	R2: 0.8186125425624725, 	Model score: 0.8186125425624725
# Improvement found!
# n_estimators=127:
# 	Mean Squared Error: 941.524534990597, 	R2: 0.8189399288854282, 	Model score: 0.8189399288854282
# Improvement found!
# n_estimators=128:
# 	Mean Squared Error: 941.7293598016587, 	R2: 0.8189005400076257, 	Model score: 0.8189005400076257
# n_estimators=129:
# 	Mean Squared Error: 941.2809587717962, 	R2: 0.8189867698607389, 	Model score: 0.8189867698607389
# Improvement found!
# n_estimators=130:
# 	Mean Squared Error: 941.331365286736, 	R2: 0.8189770764254216, 	Model score: 0.8189770764254216
# n_estimators=131:
# 	Mean Squared Error: 941.6478805555357, 	R2: 0.8189162088909623, 	Model score: 0.8189162088909623
# n_estimators=132:
# 	Mean Squared Error: 942.6603665988375, 	R2: 0.818721502552264, 	Model score: 0.818721502552264
# n_estimators=133:
# 	Mean Squared Error: 942.4795277969955, 	R2: 0.8187562787955852, 	Model score: 0.8187562787955852
# n_estimators=134:
# 	Mean Squared Error: 941.9843659060745, 	R2: 0.8188515010057895, 	Model score: 0.8188515010057895
# n_estimators=135:
# 	Mean Squared Error: 941.846855039015, 	R2: 0.8188779450616197, 	Model score: 0.8188779450616197
# n_estimators=136:
# 	Mean Squared Error: 940.6351341699632, 	R2: 0.8191109652948352, 	Model score: 0.8191109652948352
# Improvement found!
# n_estimators=137:
# 	Mean Squared Error: 940.209804597049, 	R2: 0.8191927583866314, 	Model score: 0.8191927583866314
# Improvement found!
# n_estimators=138:
# 	Mean Squared Error: 940.8144908921319, 	R2: 0.8190764740631531, 	Model score: 0.8190764740631531
# n_estimators=139:
# 	Mean Squared Error: 941.1652383596946, 	R2: 0.8190090234986058, 	Model score: 0.8190090234986058
# n_estimators=140:
# 	Mean Squared Error: 940.2645626060456, 	R2: 0.8191822281363463, 	Model score: 0.8191822281363463
# n_estimators=141:
# 	Mean Squared Error: 939.5554325233223, 	R2: 0.8193185975440842, 	Model score: 0.8193185975440842
# Improvement found!
# n_estimators=142:
# 	Mean Squared Error: 939.6088131570616, 	R2: 0.8193083321702339, 	Model score: 0.8193083321702339
# n_estimators=143:
# 	Mean Squared Error: 939.9957107854508, 	R2: 0.819233929741506, 	Model score: 0.819233929741506
# n_estimators=144:
# 	Mean Squared Error: 939.6242017821173, 	R2: 0.8193053728574986, 	Model score: 0.8193053728574986
# n_estimators=145:
# 	Mean Squared Error: 938.9458016727893, 	R2: 0.8194358327313247, 	Model score: 0.8194358327313247
# Improvement found!
# n_estimators=146:
# 	Mean Squared Error: 939.5586986840417, 	R2: 0.8193179694443692, 	Model score: 0.8193179694443692
# n_estimators=147:
# 	Mean Squared Error: 938.9547489153018, 	R2: 0.8194341121299964, 	Model score: 0.8194341121299964
# n_estimators=148:
# 	Mean Squared Error: 940.0449553872469, 	R2: 0.8192244597481368, 	Model score: 0.8192244597481368
# n_estimators=149:
# 	Mean Squared Error: 940.8108000368946, 	R2: 0.8190771838338355, 	Model score: 0.8190771838338355
# n_estimators=150:
# 	Mean Squared Error: 940.5645728517019, 	R2: 0.8191245346037883, 	Model score: 0.8191245346037883
# n_estimators=151:
# 	Mean Squared Error: 941.47140828774, 	R2: 0.8189501454270476, 	Model score: 0.8189501454270476
# n_estimators=152:
# 	Mean Squared Error: 941.7903460113079, 	R2: 0.8188888120419214, 	Model score: 0.8188888120419214
# n_estimators=153:
# 	Mean Squared Error: 941.3520588592238, 	R2: 0.8189730969436693, 	Model score: 0.8189730969436693
# n_estimators=154:
# 	Mean Squared Error: 940.0957618369339, 	R2: 0.8192146894032849, 	Model score: 0.8192146894032849
# n_estimators=155:
# 	Mean Squared Error: 939.6961795960334, 	R2: 0.8192915311490545, 	Model score: 0.8192915311490545
# n_estimators=156:
# 	Mean Squared Error: 939.3444874385195, 	R2: 0.8193591633823989, 	Model score: 0.8193591633823989
# n_estimators=157:
# 	Mean Squared Error: 937.9854083694266, 	R2: 0.8196205213648573, 	Model score: 0.8196205213648573
# Improvement found!
# n_estimators=158:
# 	Mean Squared Error: 938.0984696335473, 	R2: 0.8195987790949948, 	Model score: 0.8195987790949948
# n_estimators=159:
# 	Mean Squared Error: 937.8017928254037, 	R2: 0.81965583159016, 	Model score: 0.81965583159016
# Improvement found!
# n_estimators=160:
# 	Mean Squared Error: 938.4049390203436, 	R2: 0.8195398434359592, 	Model score: 0.8195398434359592
# n_estimators=161:
# 	Mean Squared Error: 937.9457127523832, 	R2: 0.8196281550387317, 	Model score: 0.8196281550387317
# n_estimators=162:
# 	Mean Squared Error: 938.7417094087915, 	R2: 0.8194750807365121, 	Model score: 0.8194750807365121
# n_estimators=163:
# 	Mean Squared Error: 939.4394987370819, 	R2: 0.8193408922149092, 	Model score: 0.8193408922149092
# n_estimators=164:
# 	Mean Squared Error: 938.946382409174, 	R2: 0.8194357210526937, 	Model score: 0.8194357210526937
# n_estimators=165:
# 	Mean Squared Error: 939.313399856056, 	R2: 0.8193651416863967, 	Model score: 0.8193651416863967
# n_estimators=166:
# 	Mean Squared Error: 939.4842488081791, 	R2: 0.819332286543199, 	Model score: 0.819332286543199
# n_estimators=167:
# 	Mean Squared Error: 938.8100578300755, 	R2: 0.8194619369791715, 	Model score: 0.8194619369791715
# n_estimators=168:
# 	Mean Squared Error: 938.2032728248917, 	R2: 0.8195786248955315, 	Model score: 0.8195786248955315
# n_estimators=169:
# 	Mean Squared Error: 938.8092815068692, 	R2: 0.8194620862701667, 	Model score: 0.8194620862701667
# n_estimators=170:
# 	Mean Squared Error: 939.2142588190162, 	R2: 0.8193842070241013, 	Model score: 0.8193842070241013
# n_estimators=171:
# 	Mean Squared Error: 938.9145729205992, 	R2: 0.8194418381829962, 	Model score: 0.8194418381829962
# n_estimators=172:
# 	Mean Squared Error: 939.3856254364422, 	R2: 0.8193512523311701, 	Model score: 0.8193512523311701
# n_estimators=173:
# 	Mean Squared Error: 939.7140651753107, 	R2: 0.8192880916590195, 	Model score: 0.8192880916590195
# n_estimators=174:
# 	Mean Squared Error: 939.5662461637838, 	R2: 0.819316518024711, 	Model score: 0.819316518024711
# n_estimators=175:
# 	Mean Squared Error: 939.5309089478974, 	R2: 0.8193233135553462, 	Model score: 0.8193233135553462
# n_estimators=176:
# 	Mean Squared Error: 938.9528673300518, 	R2: 0.8194344739686383, 	Model score: 0.8194344739686383
# n_estimators=177:
# 	Mean Squared Error: 938.6140293727917, 	R2: 0.8194996342723351, 	Model score: 0.8194996342723351
# n_estimators=178:
# 	Mean Squared Error: 938.4252172850723, 	R2: 0.8195359438200518, 	Model score: 0.8195359438200518
# n_estimators=179:
# 	Mean Squared Error: 938.0961352910616, 	R2: 0.819599228001211, 	Model score: 0.819599228001211
# n_estimators=180:
# 	Mean Squared Error: 938.7181220554138, 	R2: 0.819479616707399, 	Model score: 0.819479616707399
# n_estimators=181:
# 	Mean Squared Error: 938.6230819681704, 	R2: 0.8194978934111019, 	Model score: 0.8194978934111019
# n_estimators=182:
# 	Mean Squared Error: 938.6226857844862, 	R2: 0.8194979695992874, 	Model score: 0.8194979695992874
# n_estimators=183:
# 	Mean Squared Error: 938.2819989614098, 	R2: 0.8195634854495086, 	Model score: 0.8195634854495086
# n_estimators=184:
# 	Mean Squared Error: 938.5297690673381, 	R2: 0.8195158379678635, 	Model score: 0.8195158379678635
# n_estimators=185:
# 	Mean Squared Error: 939.0435957389064, 	R2: 0.819417026423143, 	Model score: 0.819417026423143
# n_estimators=186:
# 	Mean Squared Error: 939.7523713815809, 	R2: 0.8192807251760722, 	Model score: 0.8192807251760722
# n_estimators=187:
# 	Mean Squared Error: 939.9062366719153, 	R2: 0.8192511360794797, 	Model score: 0.8192511360794797
# n_estimators=188:
# 	Mean Squared Error: 940.3584866102792, 	R2: 0.8191641660612183, 	Model score: 0.8191641660612183
# n_estimators=189:
# 	Mean Squared Error: 940.2272805233598, 	R2: 0.8191893976749951, 	Model score: 0.8191893976749951
# n_estimators=190:
# 	Mean Squared Error: 939.8401233158139, 	R2: 0.8192638500221466, 	Model score: 0.8192638500221466
# n_estimators=191:
# 	Mean Squared Error: 939.5354975100869, 	R2: 0.8193224311509419, 	Model score: 0.8193224311509419
# n_estimators=192:
# 	Mean Squared Error: 939.4099379508059, 	R2: 0.8193465769080494, 	Model score: 0.8193465769080494
# n_estimators=193:
# 	Mean Squared Error: 939.8297839995674, 	R2: 0.8192658383265033, 	Model score: 0.8192658383265033
# n_estimators=194:
# 	Mean Squared Error: 939.9470966032283, 	R2: 0.8192432785019081, 	Model score: 0.8192432785019081
# n_estimators=195:
# 	Mean Squared Error: 940.7788827712714, 	R2: 0.8190833216902256, 	Model score: 0.8190833216902256
# n_estimators=196:
# 	Mean Squared Error: 939.8438393994271, 	R2: 0.8192631353999161, 	Model score: 0.8192631353999161
# n_estimators=197:
# 	Mean Squared Error: 939.4755439069361, 	R2: 0.8193339605410392, 	Model score: 0.8193339605410392
# n_estimators=198:
# 	Mean Squared Error: 939.5769659276755, 	R2: 0.8193144565582908, 	Model score: 0.8193144565582908
# n_estimators=199:
# 	Mean Squared Error: 939.1977353399936, 	R2: 0.8193873845751642, 	Model score: 0.8193873845751642
# n_estimators=200:
# 	Mean Squared Error: 939.2272976120745, 	R2: 0.8193816995962961, 	Model score: 0.8193816995962961
# Best score found: 0.820.
# Number of estimators: 200.
# Code execution time: 571.228 seconds.

# %% [markdown]
# Cross-Validation

# %%
#define number of splits
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 2833  2834  2835 ... 28326 28327 28328] | test: [   0    1    2 ... 2830 2831 2832]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [2833 2834 2835 ... 5663 5664 5665]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [5666 5667 5668 ... 8496 8497 8498]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [ 8499  8500  8501 ... 11329 11330 11331]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [11332 11333 11334 ... 14162 14163 14164]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [14165 14166 14167 ... 16995 16996 16997]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [16998 16999 17000 ... 19828 19829 19830]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [19831 19832 19833 ... 22661 22662 22663]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [22664 22665 22666 ... 25494 25495 25496]
# Train: [    0     1     2 ... 25494 25495 25496] | test: [25497 25498 25499 ... 28326 28327 28328]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y.values.ravel(), cv=k_fold, n_jobs=-1)
    print(cv_score)
# Out:
# [0.77958224 0.80151717 0.67046914 0.85725894 0.81089505 0.73163068
#  0.77799892 0.7896092  0.7256031  0.74792458]

# %%
reg_etrees = ExtraTreesRegressor(n_estimators=200, random_state=0)

# %%
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 200, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y.values.ravel(),
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
testpred = best_model.predict(X_test)
actual_lon = y_test
testpredict = []
for item in testpred:
    testpredict.append(item)

test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %f' % rmse)
# Out:
# RMSE: 30.623550

# %%
print(actual_lon)
# Out:
#         longitude
# 8870  -122.734167
# 3587  -112.381000
# 6356   -71.555500
# 11229 -118.893500
# 2900  -148.337100
# ...           ...
# 5282  -119.467700
# 13083 -117.875700
# 21510 -122.202333
# 25047  -80.497000
# 19988 -140.494100
#
# [9349 rows x 1 columns]

# %%
lon_pred = actual_lon
lon_pred['Predicted'] = testpredict

# %%
lon_pred_all = lon_pred.rename(columns={'longitude': 'Actual'})

# %%
lon_pred_all
# Out:
#            Actual   Predicted
# 8870  -122.734167 -122.746096
# 3587  -112.381000 -118.022673
# 6356   -71.555500 -139.765896
# 11229 -118.893500 -118.864243
# 2900  -148.337100 -148.923462
# ...           ...         ...
# 5282  -119.467700 -119.945653
# 13083 -117.875700 -117.833149
# 21510 -122.202333 -121.999271
# 25047  -80.497000   66.635738
# 19988 -140.494100 -143.330206
#
# [9349 rows x 2 columns]

# %%
lon_pred_all = lon_pred.merge(cleaned_df, how='inner', left_index=True, right_index=True)
lon_pred_all = lon_pred_all.rename(columns={'longitude_x': 'Actual', 'longitude_y': 'longitude'})
lon_pred_all
# Out:
#            Actual   Predicted   latitude   longitude  depth   mag  \
# 8870  -122.734167 -122.746096  38.787000 -122.734167   1.72  0.12
# 3587  -112.381000 -118.022673  38.230500 -112.381000   8.81  1.95
# 6356   -71.555500 -139.765896 -28.686100  -71.555500  17.79  5.50
# 11229 -118.893500 -118.864243  37.627667 -118.893500   2.71  0.11
# 2900  -148.337100 -148.923462  62.446400 -148.337100  33.50  1.70
# ...           ...         ...        ...         ...    ...   ...
# 5282  -119.467700 -119.945653  38.556100 -119.467700   6.70  0.90
# 13083 -117.875700 -117.833149  38.167000 -117.875700  13.20  0.80
# 21510 -122.202333 -121.999271  46.192000 -122.202333   4.62 -0.20
# 25047  -80.497000   66.635738   7.367500  -80.497000  10.00  4.60
# 19988 -140.494100 -143.330206  61.482700 -140.494100   7.00  1.50
#
#           Unix Time
# 8870   1.641518e+09
# 3587   1.640179e+09
# 6356   1.639456e+09
# 11229  1.643183e+09
# 2900   1.640377e+09
# ...             ...
# 5282   1.639748e+09
# 13083  1.642671e+09
# 21510  1.645033e+09
# 25047  1.644172e+09
# 19988  1.645448e+09
#
# [9349 rows x 7 columns]

# %%
x = np.array(lon_pred_all['longitude'])
y = np.array(testpredict)
# r2_score(y_test, y_pred)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Longitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted longitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(lon_pred_all['longitude'], testpredict)), (0, 150),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 140), fontsize=12)

# fig.savefig('extratrees_mag_linear_sns.png', dpi=600)
plt.show()
