# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("paper")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 0      2022-01-06T01:42:39.855Z   37.3840  -117.1075    1.10  1.3      ml
# 1      2022-01-06T01:31:33.698Z   38.1810  -117.8180    7.30  1.4      ml
# 2      2022-01-06T01:24:20.083Z   61.3407  -149.8852   30.00  1.5      ml
# 3      2022-01-06T01:15:15.851Z   62.8703  -150.7625  111.30  2.1      ml
# 4      2022-01-06T01:10:44.629Z   64.0145  -148.7657    1.90  1.5      ml
# ...                         ...       ...        ...     ...  ...     ...
# 28330  2022-01-30T05:22:23.246Z   37.8445   144.8923   10.00  4.3      mb
# 28331  2022-01-30T05:08:20.279Z  -30.0533  -177.1517   10.00  4.3      mb
# 28332  2022-01-30T03:50:17.124Z   54.2336  -159.7370   22.54  3.0      ml
# 28333  2022-01-30T03:46:53.207Z   63.2782  -151.2517    7.40  1.0      ml
# 28334  2022-01-30T03:31:21.676Z   54.5942  -159.7845   19.20  2.3      ml
#
#         nst     gap   dmin     rms  ...                   updated  \
# 0       8.0  149.46  0.875  0.2175  ...  2022-01-06T01:47:19.317Z
# 1      11.0  154.64  0.119  0.1017  ...  2022-01-06T01:47:40.245Z
# 2       NaN     NaN    NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3       NaN     NaN    NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4       NaN     NaN    NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...     ...     ...    ...     ...  ...                       ...
# 28330   NaN  126.00  4.178  0.7000  ...  2022-02-26T10:52:54.040Z
# 28331   NaN  221.00  1.034  0.6800  ...  2022-02-26T10:21:50.040Z
# 28332   NaN  219.00  0.604  1.0300  ...  2022-02-25T00:07:12.426Z
# 28333   NaN     NaN    NaN  0.6600  ...  2022-02-25T00:07:27.831Z
# 28334   NaN     NaN    NaN  0.5800  ...  2022-02-25T00:07:27.644Z
#
#                                           place        type horizontalError  \
# 0                37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                      34 km SE of Mina, Nevada  earthquake             NaN
# 2           5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3                41 km N of Petersville, Alaska  earthquake             NaN
# 4                      17 km E of Ferry, Alaska  earthquake             NaN
# ...                                         ...         ...             ...
# 28330       off the east coast of Honshu, Japan  earthquake             8.0
# 28331             Kermadec Islands, New Zealand  earthquake            10.8
# 28332          132 km SSE of Sand Point, Alaska  earthquake             5.2
# 28333  37 km SE of Denali National Park, Alaska  earthquake             NaN
# 28334           94 km SSE of Sand Point, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           39.1     0.290     4.0  automatic              nn        nn
# 1            2.0     0.460     5.0  automatic              nn        nn
# 2            0.2       NaN     NaN  automatic              ak        ak
# 3            0.8       NaN     NaN  automatic              ak        ak
# 4            0.6       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 28330        1.8     0.137    16.0   reviewed              us        us
# 28331        2.0     0.160    12.0   reviewed              us        us
# 28332       14.1     0.088    17.0   reviewed              us        us
# 28333        0.2       NaN     NaN   reviewed              ak        ak
# 28334        1.2       NaN     NaN   reviewed              ak        ak
#
# [28335 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time  latitude  longitude   depth  mag  \
# 0     2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.10  1.3
# 1     2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.30  1.4
# 2     2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.00  1.5
# 3     2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.30  2.1
# 4     2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.90  1.5
# ...                                ...       ...        ...     ...  ...
# 28330 2022-01-30 05:22:23.246000+00:00   37.8445   144.8923   10.00  4.3
# 28331 2022-01-30 05:08:20.279000+00:00  -30.0533  -177.1517   10.00  4.3
# 28332 2022-01-30 03:50:17.124000+00:00   54.2336  -159.7370   22.54  3.0
# 28333 2022-01-30 03:46:53.207000+00:00   63.2782  -151.2517    7.40  1.0
# 28334 2022-01-30 03:31:21.676000+00:00   54.5942  -159.7845   19.20  2.3
#
#       magType   nst     gap   dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.875  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.119  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN    NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN    NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN    NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...    ...     ...  ...                       ...
# 28330      mb   NaN  126.00  4.178  0.7000  ...  2022-02-26T10:52:54.040Z
# 28331      mb   NaN  221.00  1.034  0.6800  ...  2022-02-26T10:21:50.040Z
# 28332      ml   NaN  219.00  0.604  1.0300  ...  2022-02-25T00:07:12.426Z
# 28333      ml   NaN     NaN    NaN  0.6600  ...  2022-02-25T00:07:27.831Z
# 28334      ml   NaN     NaN    NaN  0.5800  ...  2022-02-25T00:07:27.644Z
#
#                                           place        type horizontalError  \
# 0                37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                      34 km SE of Mina, Nevada  earthquake             NaN
# 2           5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3                41 km N of Petersville, Alaska  earthquake             NaN
# 4                      17 km E of Ferry, Alaska  earthquake             NaN
# ...                                         ...         ...             ...
# 28330       off the east coast of Honshu, Japan  earthquake             8.0
# 28331             Kermadec Islands, New Zealand  earthquake            10.8
# 28332          132 km SSE of Sand Point, Alaska  earthquake             5.2
# 28333  37 km SE of Denali National Park, Alaska  earthquake             NaN
# 28334           94 km SSE of Sand Point, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           39.1     0.290     4.0  automatic              nn        nn
# 1            2.0     0.460     5.0  automatic              nn        nn
# 2            0.2       NaN     NaN  automatic              ak        ak
# 3            0.8       NaN     NaN  automatic              ak        ak
# 4            0.6       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 28330        1.8     0.137    16.0   reviewed              us        us
# 28331        2.0     0.160    12.0   reviewed              us        us
# 28332       14.1     0.088    17.0   reviewed              us        us
# 28333        0.2       NaN     NaN   reviewed              ak        ak
# 28334        1.2       NaN     NaN   reviewed              ak        ak
#
# [28335 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#        latitude  longitude   depth  mag     Unix Time
# 0       37.3840  -117.1075    1.10  1.3  1.641433e+09
# 1       38.1810  -117.8180    7.30  1.4  1.641433e+09
# 2       61.3407  -149.8852   30.00  1.5  1.641432e+09
# 3       62.8703  -150.7625  111.30  2.1  1.641432e+09
# 4       64.0145  -148.7657    1.90  1.5  1.641431e+09
# ...         ...        ...     ...  ...           ...
# 28330   37.8445   144.8923   10.00  4.3  1.643520e+09
# 28331  -30.0533  -177.1517   10.00  4.3  1.643519e+09
# 28332   54.2336  -159.7370   22.54  3.0  1.643515e+09
# 28333   63.2782  -151.2517    7.40  1.0  1.643514e+09
# 28334   54.5942  -159.7845   19.20  2.3  1.643513e+09
#
# [28335 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: longitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['longitude'], axis = 1)

y = cleaned_df_dropped[['longitude']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((28329, 4), (28329, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1413.2369550580495, 	R2 score: 0.7296622736602851, 	Model score: 0.7296622736602851
# n_estimators=3:
# 	Mean Squared Error: 1150.5297438036207, 	R2 score: 0.7799154671742152, 	Model score: 0.7799154671742152
# n_estimators=4:
# 	Mean Squared Error: 1093.9221500074739, 	R2 score: 0.7907439189392513, 	Model score: 0.7907439189392513
# n_estimators=5:
# 	Mean Squared Error: 1037.5177974984922, 	R2 score: 0.8015334927317902, 	Model score: 0.8015334927317902
# n_estimators=6:
# 	Mean Squared Error: 996.7995877765178, 	R2 score: 0.809322468386202, 	Model score: 0.809322468386202
# n_estimators=7:
# 	Mean Squared Error: 973.6762997735191, 	R2 score: 0.8137457160814, 	Model score: 0.8137457160814
# n_estimators=8:
# 	Mean Squared Error: 934.1206265504443, 	R2 score: 0.8213123104339539, 	Model score: 0.8213123104339539
# n_estimators=9:
# 	Mean Squared Error: 932.4344064378527, 	R2 score: 0.8216348670368752, 	Model score: 0.8216348670368752
# n_estimators=10:
# 	Mean Squared Error: 932.356202483981, 	R2 score: 0.8216498266506929, 	Model score: 0.8216498266506929
# n_estimators=11:
# 	Mean Squared Error: 927.7566712383473, 	R2 score: 0.8225296697758834, 	Model score: 0.8225296697758834
# n_estimators=12:
# 	Mean Squared Error: 930.2675290658922, 	R2 score: 0.8220493684408303, 	Model score: 0.8220493684408303
# n_estimators=13:
# 	Mean Squared Error: 929.0660155221323, 	R2 score: 0.822279205651373, 	Model score: 0.822279205651373
# n_estimators=14:
# 	Mean Squared Error: 931.9669700700805, 	R2 score: 0.8217242828170244, 	Model score: 0.8217242828170244
# n_estimators=15:
# 	Mean Squared Error: 921.5732157922995, 	R2 score: 0.8237125013457943, 	Model score: 0.8237125013457943
# n_estimators=16:
# 	Mean Squared Error: 926.6193231194621, 	R2 score: 0.822747232799137, 	Model score: 0.822747232799137
# n_estimators=17:
# 	Mean Squared Error: 932.7366764145704, 	R2 score: 0.8215770458923359, 	Model score: 0.8215770458923359
# n_estimators=18:
# 	Mean Squared Error: 925.1740322951825, 	R2 score: 0.8230237021017102, 	Model score: 0.8230237021017102
# n_estimators=19:
# 	Mean Squared Error: 926.8294714244905, 	R2 score: 0.8227070335850051, 	Model score: 0.8227070335850051
# n_estimators=20:
# 	Mean Squared Error: 928.1236117215288, 	R2 score: 0.8224594778271304, 	Model score: 0.8224594778271304
# n_estimators=21:
# 	Mean Squared Error: 925.9628264121566, 	R2 score: 0.8228728138820314, 	Model score: 0.8228728138820314
# n_estimators=22:
# 	Mean Squared Error: 920.9790143245796, 	R2 score: 0.8238261659886529, 	Model score: 0.8238261659886529
# n_estimators=23:
# 	Mean Squared Error: 920.6731292921492, 	R2 score: 0.8238846786562509, 	Model score: 0.8238846786562509
# n_estimators=24:
# 	Mean Squared Error: 922.8584457774316, 	R2 score: 0.8234666500391463, 	Model score: 0.8234666500391463
# n_estimators=25:
# 	Mean Squared Error: 920.0827031183588, 	R2 score: 0.8239976211241242, 	Model score: 0.8239976211241242
# n_estimators=26:
# 	Mean Squared Error: 913.1797960571052, 	R2 score: 0.8253180764047441, 	Model score: 0.8253180764047441
# n_estimators=27:
# 	Mean Squared Error: 914.6058593125136, 	R2 score: 0.8250452851387756, 	Model score: 0.8250452851387756
# n_estimators=28:
# 	Mean Squared Error: 919.7049686128045, 	R2 score: 0.8240698778585849, 	Model score: 0.8240698778585849
# n_estimators=29:
# 	Mean Squared Error: 919.5637549045701, 	R2 score: 0.8240968905917825, 	Model score: 0.8240968905917825
# n_estimators=30:
# 	Mean Squared Error: 916.2861223693203, 	R2 score: 0.8247238680594925, 	Model score: 0.8247238680594925
# n_estimators=31:
# 	Mean Squared Error: 911.7322353156042, 	R2 score: 0.825594979919187, 	Model score: 0.825594979919187
# n_estimators=32:
# 	Mean Squared Error: 912.2829259365324, 	R2 score: 0.8254896384547952, 	Model score: 0.8254896384547952
# n_estimators=33:
# 	Mean Squared Error: 909.5337528760084, 	R2 score: 0.8260155270482377, 	Model score: 0.8260155270482377
# n_estimators=34:
# 	Mean Squared Error: 904.6304724090334, 	R2 score: 0.8269534742822835, 	Model score: 0.8269534742822835
# n_estimators=35:
# 	Mean Squared Error: 900.44286177106, 	R2 score: 0.827754521222511, 	Model score: 0.827754521222511
# n_estimators=36:
# 	Mean Squared Error: 897.4320713655111, 	R2 score: 0.8283304545292424, 	Model score: 0.8283304545292424
# n_estimators=37:
# 	Mean Squared Error: 895.8335338215388, 	R2 score: 0.8286362383566178, 	Model score: 0.8286362383566178
# n_estimators=38:
# 	Mean Squared Error: 896.544322169097, 	R2 score: 0.8285002718401042, 	Model score: 0.8285002718401042
# n_estimators=39:
# 	Mean Squared Error: 895.8549273017592, 	R2 score: 0.8286321460033995, 	Model score: 0.8286321460033995
# n_estimators=40:
# 	Mean Squared Error: 896.315929740541, 	R2 score: 0.8285439609678389, 	Model score: 0.8285439609678389
# n_estimators=41:
# 	Mean Squared Error: 893.3715593951927, 	R2 score: 0.8291071887986813, 	Model score: 0.8291071887986813
# n_estimators=42:
# 	Mean Squared Error: 896.7241904126105, 	R2 score: 0.8284658648909948, 	Model score: 0.8284658648909948
# n_estimators=43:
# 	Mean Squared Error: 896.4338144953927, 	R2 score: 0.828521410824013, 	Model score: 0.828521410824013
# n_estimators=44:
# 	Mean Squared Error: 898.6175588130927, 	R2 score: 0.8281036829464328, 	Model score: 0.8281036829464328
# n_estimators=45:
# 	Mean Squared Error: 899.5332690395121, 	R2 score: 0.8279285169774774, 	Model score: 0.8279285169774774
# n_estimators=46:
# 	Mean Squared Error: 901.9170854517267, 	R2 score: 0.8274725173614308, 	Model score: 0.8274725173614308
# n_estimators=47:
# 	Mean Squared Error: 902.518135955194, 	R2 score: 0.8273575425683212, 	Model score: 0.8273575425683212
# n_estimators=48:
# 	Mean Squared Error: 905.415532750818, 	R2 score: 0.8268033002954811, 	Model score: 0.8268033002954811
# n_estimators=49:
# 	Mean Squared Error: 905.490890072902, 	R2 score: 0.8267888852131112, 	Model score: 0.8267888852131112
# n_estimators=50:
# 	Mean Squared Error: 902.1334166906274, 	R2 score: 0.8274311354155006, 	Model score: 0.8274311354155006
# Max score: 0.8291071887986813
# Best model score:  0.8291071887986813

# %%
#create and run model: Now with 200 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,100):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 60:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1413.2369550580495, 	R2: 0.7296622736602851, 	Model score: 0.7296622736602851
# n_estimators=3:
# 	Mean Squared Error: 1150.5297438036207, 	R2: 0.7799154671742152, 	Model score: 0.7799154671742152
# n_estimators=4:
# 	Mean Squared Error: 1093.9221500074739, 	R2: 0.7907439189392513, 	Model score: 0.7907439189392513
# n_estimators=5:
# 	Mean Squared Error: 1037.5177974984922, 	R2: 0.8015334927317902, 	Model score: 0.8015334927317902
# n_estimators=6:
# 	Mean Squared Error: 996.7995877765178, 	R2: 0.809322468386202, 	Model score: 0.809322468386202
# n_estimators=7:
# 	Mean Squared Error: 973.6762997735191, 	R2: 0.8137457160814, 	Model score: 0.8137457160814
# n_estimators=8:
# 	Mean Squared Error: 934.1206265504443, 	R2: 0.8213123104339539, 	Model score: 0.8213123104339539
# n_estimators=9:
# 	Mean Squared Error: 932.4344064378527, 	R2: 0.8216348670368752, 	Model score: 0.8216348670368752
# n_estimators=10:
# 	Mean Squared Error: 932.356202483981, 	R2: 0.8216498266506929, 	Model score: 0.8216498266506929
# n_estimators=11:
# 	Mean Squared Error: 927.7566712383473, 	R2: 0.8225296697758834, 	Model score: 0.8225296697758834
# n_estimators=12:
# 	Mean Squared Error: 930.2675290658922, 	R2: 0.8220493684408303, 	Model score: 0.8220493684408303
# n_estimators=13:
# 	Mean Squared Error: 929.0660155221323, 	R2: 0.822279205651373, 	Model score: 0.822279205651373
# n_estimators=14:
# 	Mean Squared Error: 931.9669700700805, 	R2: 0.8217242828170244, 	Model score: 0.8217242828170244
# n_estimators=15:
# 	Mean Squared Error: 921.5732157922995, 	R2: 0.8237125013457943, 	Model score: 0.8237125013457943
# n_estimators=16:
# 	Mean Squared Error: 926.6193231194621, 	R2: 0.822747232799137, 	Model score: 0.822747232799137
# n_estimators=17:
# 	Mean Squared Error: 932.7366764145704, 	R2: 0.8215770458923359, 	Model score: 0.8215770458923359
# n_estimators=18:
# 	Mean Squared Error: 925.1740322951825, 	R2: 0.8230237021017102, 	Model score: 0.8230237021017102
# n_estimators=19:
# 	Mean Squared Error: 926.8294714244905, 	R2: 0.8227070335850051, 	Model score: 0.8227070335850051
# n_estimators=20:
# 	Mean Squared Error: 928.1236117215288, 	R2: 0.8224594778271304, 	Model score: 0.8224594778271304
# n_estimators=21:
# 	Mean Squared Error: 925.9628264121566, 	R2: 0.8228728138820314, 	Model score: 0.8228728138820314
# n_estimators=22:
# 	Mean Squared Error: 920.9790143245796, 	R2: 0.8238261659886529, 	Model score: 0.8238261659886529
# n_estimators=23:
# 	Mean Squared Error: 920.6731292921492, 	R2: 0.8238846786562509, 	Model score: 0.8238846786562509
# n_estimators=24:
# 	Mean Squared Error: 922.8584457774316, 	R2: 0.8234666500391463, 	Model score: 0.8234666500391463
# n_estimators=25:
# 	Mean Squared Error: 920.0827031183588, 	R2: 0.8239976211241242, 	Model score: 0.8239976211241242
# n_estimators=26:
# 	Mean Squared Error: 913.1797960571052, 	R2: 0.8253180764047441, 	Model score: 0.8253180764047441
# n_estimators=27:
# 	Mean Squared Error: 914.6058593125136, 	R2: 0.8250452851387756, 	Model score: 0.8250452851387756
# n_estimators=28:
# 	Mean Squared Error: 919.7049686128045, 	R2: 0.8240698778585849, 	Model score: 0.8240698778585849
# n_estimators=29:
# 	Mean Squared Error: 919.5637549045701, 	R2: 0.8240968905917825, 	Model score: 0.8240968905917825
# n_estimators=30:
# 	Mean Squared Error: 916.2861223693203, 	R2: 0.8247238680594925, 	Model score: 0.8247238680594925
# n_estimators=31:
# 	Mean Squared Error: 911.7322353156042, 	R2: 0.825594979919187, 	Model score: 0.825594979919187
# n_estimators=32:
# 	Mean Squared Error: 912.2829259365324, 	R2: 0.8254896384547952, 	Model score: 0.8254896384547952
# n_estimators=33:
# 	Mean Squared Error: 909.5337528760084, 	R2: 0.8260155270482377, 	Model score: 0.8260155270482377
# n_estimators=34:
# 	Mean Squared Error: 904.6304724090334, 	R2: 0.8269534742822835, 	Model score: 0.8269534742822835
# n_estimators=35:
# 	Mean Squared Error: 900.44286177106, 	R2: 0.827754521222511, 	Model score: 0.827754521222511
# n_estimators=36:
# 	Mean Squared Error: 897.4320713655111, 	R2: 0.8283304545292424, 	Model score: 0.8283304545292424
# n_estimators=37:
# 	Mean Squared Error: 895.8335338215388, 	R2: 0.8286362383566178, 	Model score: 0.8286362383566178
# n_estimators=38:
# 	Mean Squared Error: 896.544322169097, 	R2: 0.8285002718401042, 	Model score: 0.8285002718401042
# n_estimators=39:
# 	Mean Squared Error: 895.8549273017592, 	R2: 0.8286321460033995, 	Model score: 0.8286321460033995
# n_estimators=40:
# 	Mean Squared Error: 896.315929740541, 	R2: 0.8285439609678389, 	Model score: 0.8285439609678389
# n_estimators=41:
# 	Mean Squared Error: 893.3715593951927, 	R2: 0.8291071887986813, 	Model score: 0.8291071887986813
# n_estimators=42:
# 	Mean Squared Error: 896.7241904126105, 	R2: 0.8284658648909948, 	Model score: 0.8284658648909948
# n_estimators=43:
# 	Mean Squared Error: 896.4338144953927, 	R2: 0.828521410824013, 	Model score: 0.828521410824013
# n_estimators=44:
# 	Mean Squared Error: 898.6175588130927, 	R2: 0.8281036829464328, 	Model score: 0.8281036829464328
# n_estimators=45:
# 	Mean Squared Error: 899.5332690395121, 	R2: 0.8279285169774774, 	Model score: 0.8279285169774774
# n_estimators=46:
# 	Mean Squared Error: 901.9170854517267, 	R2: 0.8274725173614308, 	Model score: 0.8274725173614308
# n_estimators=47:
# 	Mean Squared Error: 902.518135955194, 	R2: 0.8273575425683212, 	Model score: 0.8273575425683212
# n_estimators=48:
# 	Mean Squared Error: 905.415532750818, 	R2: 0.8268033002954811, 	Model score: 0.8268033002954811
# n_estimators=49:
# 	Mean Squared Error: 905.490890072902, 	R2: 0.8267888852131112, 	Model score: 0.8267888852131112
# n_estimators=50:
# 	Mean Squared Error: 902.1334166906274, 	R2: 0.8274311354155006, 	Model score: 0.8274311354155006
# n_estimators=51:
# 	Mean Squared Error: 900.7164395328393, 	R2: 0.8277021886042393, 	Model score: 0.8277021886042393
# n_estimators=52:
# 	Mean Squared Error: 897.5405437585499, 	R2: 0.828309704873638, 	Model score: 0.828309704873638
# n_estimators=53:
# 	Mean Squared Error: 895.5517815236865, 	R2: 0.8286901346797502, 	Model score: 0.8286901346797502
# n_estimators=54:
# 	Mean Squared Error: 895.3023293567346, 	R2: 0.8287378523193172, 	Model score: 0.8287378523193172
# n_estimators=55:
# 	Mean Squared Error: 894.7381779336985, 	R2: 0.8288457686970124, 	Model score: 0.8288457686970124
# n_estimators=56:
# 	Mean Squared Error: 891.3611732534127, 	R2: 0.8294917550362739, 	Model score: 0.8294917550362739
# Improvement found!
# n_estimators=57:
# 	Mean Squared Error: 890.224105632544, 	R2: 0.8297092644031356, 	Model score: 0.8297092644031356
# Improvement found!
# n_estimators=58:
# 	Mean Squared Error: 890.9370277952203, 	R2: 0.8295728897096879, 	Model score: 0.8295728897096879
# n_estimators=59:
# 	Mean Squared Error: 892.5201878108934, 	R2: 0.829270047445666, 	Model score: 0.829270047445666
# n_estimators=60:
# 	Mean Squared Error: 893.3110643437251, 	R2: 0.8291187608812043, 	Model score: 0.8291187608812043
# n_estimators=61:
# 	Mean Squared Error: 892.4317227735252, 	R2: 0.8292869698994535, 	Model score: 0.8292869698994535
# n_estimators=62:
# 	Mean Squared Error: 893.264225241001, 	R2: 0.8291277207208751, 	Model score: 0.8291277207208751
# n_estimators=63:
# 	Mean Squared Error: 892.1801721466067, 	R2: 0.829335088952877, 	Model score: 0.829335088952877
# n_estimators=64:
# 	Mean Squared Error: 892.3396586245645, 	R2: 0.8293045808263532, 	Model score: 0.8293045808263532
# n_estimators=65:
# 	Mean Squared Error: 891.878351937376, 	R2: 0.8293928240615116, 	Model score: 0.8293928240615116
# n_estimators=66:
# 	Mean Squared Error: 891.967455611292, 	R2: 0.8293757794431065, 	Model score: 0.8293757794431065
# n_estimators=67:
# 	Mean Squared Error: 892.0662333222662, 	R2: 0.8293568842806908, 	Model score: 0.8293568842806908
# n_estimators=68:
# 	Mean Squared Error: 891.8157014359741, 	R2: 0.8294048084594872, 	Model score: 0.8294048084594872
# n_estimators=69:
# 	Mean Squared Error: 888.5371273429125, 	R2: 0.8300319660375439, 	Model score: 0.8300319660375439
# Improvement found!
# n_estimators=70:
# 	Mean Squared Error: 889.2799843534953, 	R2: 0.8298898651148942, 	Model score: 0.8298898651148942
# n_estimators=71:
# 	Mean Squared Error: 891.5177138763803, 	R2: 0.8294618104215783, 	Model score: 0.8294618104215783
# n_estimators=72:
# 	Mean Squared Error: 890.824627805217, 	R2: 0.829594390674285, 	Model score: 0.829594390674285
# n_estimators=73:
# 	Mean Squared Error: 891.7734552588112, 	R2: 0.8294128897196325, 	Model score: 0.8294128897196325
# n_estimators=74:
# 	Mean Squared Error: 891.8433586841026, 	R2: 0.829399517911749, 	Model score: 0.829399517911749
# n_estimators=75:
# 	Mean Squared Error: 891.46279092289, 	R2: 0.8294723166189413, 	Model score: 0.8294723166189413
# n_estimators=76:
# 	Mean Squared Error: 891.0944596787263, 	R2: 0.8295427746059977, 	Model score: 0.8295427746059977
# n_estimators=77:
# 	Mean Squared Error: 890.801181033427, 	R2: 0.8295988758011089, 	Model score: 0.8295988758011089
# n_estimators=78:
# 	Mean Squared Error: 890.0570155857288, 	R2: 0.8297412270143512, 	Model score: 0.8297412270143512
# n_estimators=79:
# 	Mean Squared Error: 889.5093617012051, 	R2: 0.8298459875822328, 	Model score: 0.8298459875822328
# n_estimators=80:
# 	Mean Squared Error: 890.2546487863847, 	R2: 0.8297034218112511, 	Model score: 0.8297034218112511
# n_estimators=81:
# 	Mean Squared Error: 892.873827415451, 	R2: 0.8292023998184952, 	Model score: 0.8292023998184952
# n_estimators=82:
# 	Mean Squared Error: 892.0895812987327, 	R2: 0.8293524180523983, 	Model score: 0.8293524180523983
# n_estimators=83:
# 	Mean Squared Error: 891.5875291922064, 	R2: 0.8294484554681315, 	Model score: 0.8294484554681315
# n_estimators=84:
# 	Mean Squared Error: 891.6035281068317, 	R2: 0.8294453950399505, 	Model score: 0.8294453950399505
# n_estimators=85:
# 	Mean Squared Error: 890.8980073148091, 	R2: 0.8295803539271478, 	Model score: 0.8295803539271478
# n_estimators=86:
# 	Mean Squared Error: 888.9059322147529, 	R2: 0.8299614174503736, 	Model score: 0.8299614174503736
# n_estimators=87:
# 	Mean Squared Error: 889.3643892934549, 	R2: 0.8298737193160748, 	Model score: 0.8298737193160748
# n_estimators=88:
# 	Mean Squared Error: 890.8666981277952, 	R2: 0.829586343053317, 	Model score: 0.829586343053317
# n_estimators=89:
# 	Mean Squared Error: 891.9926957950091, 	R2: 0.8293709512549856, 	Model score: 0.8293709512549856
# n_estimators=90:
# 	Mean Squared Error: 893.7355642041443, 	R2: 0.8290375584142814, 	Model score: 0.8290375584142814
# n_estimators=91:
# 	Mean Squared Error: 894.4156176475145, 	R2: 0.8289074711695259, 	Model score: 0.8289074711695259
# n_estimators=92:
# 	Mean Squared Error: 894.1564270206677, 	R2: 0.8289570516765312, 	Model score: 0.8289570516765312
# n_estimators=93:
# 	Mean Squared Error: 894.0247040319484, 	R2: 0.8289822489324828, 	Model score: 0.8289822489324828
# n_estimators=94:
# 	Mean Squared Error: 893.6193370165024, 	R2: 0.8290597914825107, 	Model score: 0.8290597914825107
# n_estimators=95:
# 	Mean Squared Error: 894.6929428865591, 	R2: 0.8288544216973114, 	Model score: 0.8288544216973114
# n_estimators=96:
# 	Mean Squared Error: 894.6225395107349, 	R2: 0.8288678891406009, 	Model score: 0.8288678891406009
# n_estimators=97:
# 	Mean Squared Error: 895.3477070788347, 	R2: 0.8287291720267626, 	Model score: 0.8287291720267626
# n_estimators=98:
# 	Mean Squared Error: 895.2048375270524, 	R2: 0.828756501505838, 	Model score: 0.828756501505838
# n_estimators=99:
# 	Mean Squared Error: 895.4658541083277, 	R2: 0.8287065717124893, 	Model score: 0.8287065717124893
# n_estimators=100:
# 	Mean Squared Error: 894.834187016537, 	R2: 0.8288274031447463, 	Model score: 0.8288274031447463
# Best score found: 0.830.
# Number of estimators: 100.
# Code execution time: 150.628 seconds.

# %% [markdown]
# Cross-Validation

# %%
#define number of splits
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 2833  2834  2835 ... 28326 28327 28328] | test: [   0    1    2 ... 2830 2831 2832]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [2833 2834 2835 ... 5663 5664 5665]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [5666 5667 5668 ... 8496 8497 8498]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [ 8499  8500  8501 ... 11329 11330 11331]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [11332 11333 11334 ... 14162 14163 14164]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [14165 14166 14167 ... 16995 16996 16997]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [16998 16999 17000 ... 19828 19829 19830]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [19831 19832 19833 ... 22661 22662 22663]
# Train: [    0     1     2 ... 28326 28327 28328] | test: [22664 22665 22666 ... 25494 25495 25496]
# Train: [    0     1     2 ... 25494 25495 25496] | test: [25497 25498 25499 ... 28326 28327 28328]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y.values.ravel(), cv=k_fold, n_jobs=-1)
    print(cv_score)
# Out:
# [0.77741638 0.80423982 0.66268247 0.82575164 0.8351116  0.79384521
#  0.83831924 0.8127175  0.79345761 0.71463089]

# %%
reg_etrees = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 100, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y.values.ravel(),
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
testpred = best_model.predict(X_test)
actual_lon = y_test
testpredict = []
for item in testpred:
    testpredict.append(item)

test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %f' % rmse)
# Out:
# RMSE: 29.808340

# %%
print(actual_lon)
# Out:
#         longitude
# 8870  -110.388333
# 3587  -112.381000
# 6356   -71.555500
# 11228  122.982900
# 2900  -148.337100
# ...           ...
# 5282  -119.467700
# 13082 -117.802500
# 21509 -116.567667
# 25047 -121.159667
# 19987 -165.899200
#
# [9349 rows x 1 columns]

# %%
lon_pred = actual_lon
lon_pred['Predicted'] = testpredict

# %%
lon_pred_all = lon_pred.rename(columns={'longitude': 'Actual'})

# %%
lon_pred_all
# Out:
#            Actual   Predicted
# 8870  -110.388333 -111.104952
# 3587  -112.381000 -117.925919
# 6356   -71.555500 -117.778252
# 11228  122.982900  110.423504
# 2900  -148.337100 -148.772000
# ...           ...         ...
# 5282  -119.467700 -119.752716
# 13082 -117.802500 -117.724029
# 21509 -116.567667 -116.516022
# 25047 -121.159667 -118.064471
# 19987 -165.899200 -151.337806
#
# [9349 rows x 2 columns]

# %%
lon_pred_all = lon_pred.merge(model_df, how='inner', left_index=True, right_index=True)
lon_pred_all = lon_pred_all.rename(columns={'longitude_x': 'Actual', 'longitude_y': 'longitude'})
lon_pred_all
# Out:
#            Actual   Predicted                             time   latitude  \
# 8870  -110.388333 -111.104952 2022-01-20 23:40:46.420000+00:00  44.371333
# 3587  -112.381000 -117.925919        2021-12-22 13:12:47+00:00  38.230500
# 6356   -71.555500 -117.778252 2021-12-14 04:23:55.138000+00:00 -28.686100
# 11228  122.982900  110.423504 2022-01-13 10:01:22.570000+00:00   1.481900
# 2900  -148.337100 -148.772000 2021-12-24 20:15:05.365000+00:00  62.446400
# ...           ...         ...                              ...        ...
# 5282  -119.467700 -119.752716 2021-12-17 13:30:12.501000+00:00  38.556100
# 13082 -117.802500 -117.724029 2022-01-08 09:26:27.250000+00:00  36.024333
# 21509 -116.567667 -116.516022 2022-02-24 17:41:27.130000+00:00  33.471333
# 25047 -121.159667 -118.064471 2022-02-13 05:04:17.780000+00:00  36.570833
# 19987 -165.899200 -151.337806 2022-01-09 17:05:48.225000+00:00  65.215800
#
#         longitude  depth   mag magType   nst     gap  ...  \
# 8870  -110.388333   8.00  0.19      md  11.0  129.00  ...
# 3587  -112.381000   8.81  1.95      ml  23.0  185.00  ...
# 6356   -71.555500  17.79  5.50     mwr   NaN   65.00  ...
# 11228  122.982900  28.19  4.70      mb   NaN   57.00  ...
# 2900  -148.337100  33.50  1.70      ml   NaN     NaN  ...
# ...           ...    ...   ...     ...   ...     ...  ...
# 5282  -119.467700   6.70  0.90      ml   6.0  150.19  ...
# 13082 -117.802500   0.49 -0.65      ml   7.0  112.00  ...
# 21509 -116.567667  10.08  0.29      ml  14.0  136.00  ...
# 25047 -121.159667   3.61  1.22      md  19.0  119.00  ...
# 19987 -165.899200  15.50  2.40      ml   NaN     NaN  ...
#
#                                         place         type horizontalError  \
# 8870   65 km ESE of West Yellowstone, Montana   earthquake            0.41
# 3587            11 km NW of Circleville, Utah   earthquake            0.59
# 6356               78 km W of Vallenar, Chile   earthquake            4.20
# 11228        104 km N of Gorontalo, Indonesia   earthquake            6.50
# 2900            72 km N of Chickaloon, Alaska   earthquake             NaN
# ...                                       ...          ...             ...
# 5282          California-Nevada border region   earthquake             NaN
# 13082             13km E of Coso Junction, CA   earthquake            0.26
# 21509                     14km SE of Anza, CA   earthquake            0.23
# 25047                5km NNW of Pinnacles, CA   earthquake            0.33
# 19987             22 km ESE of Teller, Alaska  other event             NaN
#
#       depthError magError magNst     status  locationSource  magSource  \
# 8870        0.62    0.183    5.0   reviewed              uu         uu
# 3587        0.74    0.116    8.0   reviewed              uu         uu
# 6356        3.30      NaN    NaN   reviewed              us        guc
# 11228       5.90    0.147   14.0   reviewed              us         us
# 2900        0.20      NaN    NaN  automatic              ak         ak
# ...          ...      ...    ...        ...             ...        ...
# 5282        2.90    0.370    2.0   reviewed              nn         nn
# 13082       0.94    0.119    3.0   reviewed              ci         ci
# 21509       0.42    0.116   11.0   reviewed              ci         ci
# 25047       0.23    0.286   14.0   reviewed              nc         nc
# 19987       0.40      NaN    NaN   reviewed              ak         ak
#
#           Unix Time
# 8870   1.642722e+09
# 3587   1.640179e+09
# 6356   1.639456e+09
# 11228  1.642068e+09
# 2900   1.640377e+09
# ...             ...
# 5282   1.639748e+09
# 13082  1.641634e+09
# 21509  1.645724e+09
# 25047  1.644729e+09
# 19987  1.641748e+09
#
# [9349 rows x 25 columns]

# %%
x = np.array(lon_pred_all['longitude'])
y = np.array(testpredict)
# r2_score(y_test, y_pred)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Longitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted longitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(lon_pred_all['longitude'], testpredict)), (0, 150),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 140), fontsize=12)

# fig.savefig('extratrees_mag_linear_sns.png', dpi=600)
plt.show()

# %% [markdown]
# Test with new data from USGS

# %%
page_url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.csv"

test_df = pd.read_csv(page_url)
test_df
# Out:
#                          time   latitude   longitude      depth   mag magType  \
# 0    2022-03-10T02:02:25.540Z  36.547832 -121.137833   6.060000  2.04      md
# 1    2022-03-10T02:00:53.590Z  38.820167 -122.764831   1.600000  1.53      md
# 2    2022-03-10T01:57:16.110Z  34.220833 -117.473667   5.280000  1.30      ml
# 3    2022-03-10T01:55:56.950Z  34.028500 -117.158000   9.130000  1.28      ml
# 4    2022-03-10T01:41:31.548Z  31.588245 -104.573230   8.111084  2.80      ml
# ..                        ...        ...         ...        ...   ...     ...
# 270  2022-03-09T02:49:38.250Z  38.801167 -122.820503   3.770000  0.35      md
# 271  2022-03-09T02:47:57.713Z  38.551800 -119.559800   5.200000  0.10      ml
# 272  2022-03-09T02:44:44.842Z -37.758000  177.336300  77.810000  5.10      mb
# 273  2022-03-09T02:29:20.930Z  44.283667 -115.186333   9.750000  1.98      ml
# 274  2022-03-09T02:20:55.670Z  35.610000 -117.417833   9.440000  0.99      ml
#
#       nst     gap      dmin     rms  ...                   updated  \
# 0    21.0   98.00  0.045100  0.0500  ...  2022-03-10T02:14:11.574Z
# 1    33.0   51.00  0.011030  0.0500  ...  2022-03-10T02:09:10.548Z
# 2    36.0   68.00  0.047550  0.2200  ...  2022-03-10T02:00:49.904Z
# 3    37.0  103.00  0.038490  0.1900  ...  2022-03-10T01:59:36.544Z
# 4     9.0   98.00  0.101483  0.2000  ...  2022-03-10T01:56:57.594Z
# ..    ...     ...       ...     ...  ...                       ...
# 270  10.0   64.00  0.010250  0.0100  ...  2022-03-09T04:40:18.798Z
# 271   3.0  237.06  0.046000  0.0806  ...  2022-03-09T22:47:48.005Z
# 272   NaN   53.00  0.794000  0.7800  ...  2022-03-09T04:48:32.516Z
# 273  10.0   83.00  0.912000  0.2500  ...  2022-03-09T21:37:12.450Z
# 274  24.0  100.00  0.043100  0.1200  ...  2022-03-09T16:49:47.130Z
#
#                                  place        type horizontalError depthError  \
# 0             2km NNE of Pinnacles, CA  earthquake        0.260000   0.700000
# 1                    4km W of Cobb, CA  earthquake        0.200000   0.310000
# 2           5km SSE of Lytle Creek, CA  earthquake        0.310000   1.260000
# 3               4km SE of Redlands, CA  earthquake        0.290000   0.690000
# 4         65 km NNE of Van Horn, Texas  earthquake        2.040824   2.386379
# ..                                 ...         ...             ...        ...
# 270         6km WNW of The Geysers, CA  earthquake        0.610000   1.840000
# 271  4 km WSW of Coleville, California  earthquake             NaN   8.400000
# 272    28 km N of Opotiki, New Zealand  earthquake        5.200000   6.000000
# 273        21 km WNW of Stanley, Idaho  earthquake        0.750000   1.940000
# 274              18km SSW of Trona, CA  earthquake        0.220000   0.370000
#
#      magError  magNst     status  locationSource magSource
# 0       0.200    20.0  automatic              nc        nc
# 1       0.130     9.0  automatic              nc        nc
# 2       0.121    27.0  automatic              ci        ci
# 3       0.142    27.0  automatic              ci        ci
# 4       0.100     7.0   reviewed              tx        tx
# ..        ...     ...        ...             ...       ...
# 270       NaN     1.0  automatic              nc        nc
# 271     0.170     2.0   reviewed              nn        nn
# 272     0.090    40.0   reviewed              us        us
# 273     0.184    10.0   reviewed              mb        mb
# 274     0.172     8.0   reviewed              ci        ci
#
# [275 rows x 22 columns]

# %%
test_df['Unix Time'] = pd.to_datetime(test_df['time']).astype(int)/10**9
cleaned_test_df = test_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_test_df
# Out:
#       latitude   longitude      depth   mag     Unix Time
# 0    36.547832 -121.137833   6.060000  2.04  1.646878e+09
# 1    38.820167 -122.764831   1.600000  1.53  1.646878e+09
# 2    34.220833 -117.473667   5.280000  1.30  1.646877e+09
# 3    34.028500 -117.158000   9.130000  1.28  1.646877e+09
# 4    31.588245 -104.573230   8.111084  2.80  1.646876e+09
# ..         ...         ...        ...   ...           ...
# 270  38.801167 -122.820503   3.770000  0.35  1.646794e+09
# 271  38.551800 -119.559800   5.200000  0.10  1.646794e+09
# 272 -37.758000  177.336300  77.810000  5.10  1.646794e+09
# 273  44.283667 -115.186333   9.750000  1.98  1.646793e+09
# 274  35.610000 -117.417833   9.440000  0.99  1.646792e+09
#
# [275 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_test_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X_test_data = cleaned_test_df.drop(['longitude'], axis = 1)

y_test_data = cleaned_test_df[['longitude']]

# %%
pred_data_y = best_model.predict(X_test_data)

# %%
test_pred_data = cleaned_test_df
test_pred_data['Predicted'] = pred_data_y
test_pred_data
# Out:
#       latitude   longitude      depth   mag     Unix Time   Predicted
# 0    36.547832 -121.137833   6.060000  2.04  1.646878e+09 -109.265381
# 1    38.820167 -122.764831   1.600000  1.53  1.646878e+09 -122.653331
# 2    34.220833 -117.473667   5.280000  1.30  1.646877e+09 -115.757725
# 3    34.028500 -117.158000   9.130000  1.28  1.646877e+09 -116.760819
# 4    31.588245 -104.573230   8.111084  2.80  1.646876e+09 -104.648663
# ..         ...         ...        ...   ...           ...         ...
# 270  38.801167 -122.820503   3.770000  0.35  1.646794e+09 -122.792831
# 271  38.551800 -119.559800   5.200000  0.10  1.646794e+09 -119.001412
# 272 -37.758000  177.336300  77.810000  5.10  1.646794e+09   34.337314
# 273  44.283667 -115.186333   9.750000  1.98  1.646793e+09 -114.542234
# 274  35.610000 -117.417833   9.440000  0.99  1.646792e+09 -116.171363
#
# [275 rows x 6 columns]

# %%
x = np.array(test_pred_data['longitude'])
y = np.array(test_pred_data['Predicted'])

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'purple'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Longitude Model Predictions Using Best Model and Daily Data (2022-03-03)', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Longitude Values Using Best Model and Data Not Used For Testing Model Split', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(x, y)), (0, 100),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 80), fontsize=12)

# fig.savefig('extratrees_mag_linear_sns.png', dpi=600)
plt.show()

# %%
#connection to a PostgreSQL local database
# ===========================================

# user_name_var = input('What is the username of your database? ')
host_var = input('What is the host address of your database?')
pw = input("Enter the database password: ")
# db_name = input("Enter the name of the database: ")

string_output = "postgresql://postgres"+':'+pw+'@'+host_var+":5432"+'/earthquake_db'
engine = create_engine(string_output)
connection = engine.connect()
print("Connected to database...")
#create new database with predicted values for both training and test databases
#=============
#PostgreSQL
lon_pred_all.to_sql('earthquake_etrees_lon', engine, if_exists='replace', index = False)
#=============
#SQLite
cur = conn.cursor()
lon_pred_all.to_sql('earthquake_etrees_lon', conn, if_exists='replace', index=False)
# Close connection to SQLite database
conn.close()
connection.close()
# Out:
# Connected to database...
