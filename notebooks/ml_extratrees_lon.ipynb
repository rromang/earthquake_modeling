# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("paper")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
#create dataframe reading all rows from sqlite database
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time  latitude   longitude   depth   mag magType  \
# 0      2022-01-06T01:42:39.855Z   37.3840 -117.107500    1.10  1.30      ml
# 1      2022-01-06T01:31:33.698Z   38.1810 -117.818000    7.30  1.40      ml
# 2      2022-01-06T01:24:20.083Z   61.3407 -149.885200   30.00  1.50      ml
# 3      2022-01-06T01:15:15.851Z   62.8703 -150.762500  111.30  2.10      ml
# 4      2022-01-06T01:10:44.629Z   64.0145 -148.765700    1.90  1.50      ml
# ...                         ...       ...         ...     ...   ...     ...
# 33889  2022-02-15T19:12:23.740Z   39.4215 -110.312333   -1.56  1.83      md
# 33890  2022-02-15T19:04:27.070Z   38.8250 -122.797167    2.68  0.41      md
# 33891  2022-02-15T19:00:38.627Z   38.5375 -119.382100    0.00  1.40      ml
# 33892  2022-02-15T18:52:46.384Z   55.3724 -159.286100   15.00  1.80      ml
# 33893  2022-02-15T18:48:53.076Z   61.8432 -147.521000   34.40  1.20      ml
#
#         nst     gap     dmin     rms  ...                   updated  \
# 0       8.0  149.46  0.87500  0.2175  ...  2022-01-06T01:47:19.317Z
# 1      11.0  154.64  0.11900  0.1017  ...  2022-01-06T01:47:40.245Z
# 2       NaN     NaN      NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3       NaN     NaN      NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4       NaN     NaN      NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...     ...     ...      ...     ...  ...                       ...
# 33889   9.0  194.00  0.01022  0.1200  ...  2022-02-15T19:51:17.520Z
# 33890  25.0   44.00  0.01021  0.0300  ...  2022-02-17T09:24:12.854Z
# 33891   6.0  179.74  0.05500  0.1995  ...  2022-02-16T02:37:07.010Z
# 33892   NaN     NaN      NaN  0.5500  ...  2022-03-05T17:45:05.111Z
# 33893   NaN     NaN      NaN  0.7200  ...  2022-03-05T17:44:55.267Z
#
#                                      place        type horizontalError  \
# 0           37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                 34 km SE of Mina, Nevada  earthquake             NaN
# 2      5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3           41 km N of Petersville, Alaska  earthquake             NaN
# 4                 17 km E of Ferry, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 33889         15 km SSE of Sunnyside, Utah  earthquake            0.63
# 33890           6km NNW of The Geysers, CA  earthquake            0.18
# 33891       8 km ENE of Walker, California  earthquake             NaN
# 33892      60 km SSE of Ivanof Bay, Alaska  earthquake             NaN
# 33893     8 km ENE of Glacier View, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0          39.10     0.290     4.0  automatic              nn        nn
# 1           2.00     0.460     5.0  automatic              nn        nn
# 2           0.20       NaN     NaN  automatic              ak        ak
# 3           0.80       NaN     NaN  automatic              ak        ak
# 4           0.60       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 33889       0.36     0.324     7.0   reviewed              uu        uu
# 33890       0.28     0.129     3.0   reviewed              nc        nc
# 33891       0.00     0.280     3.0   reviewed              nn        nn
# 33892       0.40       NaN     NaN   reviewed              ak        ak
# 33893       0.20       NaN     NaN   reviewed              ak        ak
#
# [33894 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time  latitude   longitude   depth   mag  \
# 0     2022-01-06 01:42:39.855000+00:00   37.3840 -117.107500    1.10  1.30
# 1     2022-01-06 01:31:33.698000+00:00   38.1810 -117.818000    7.30  1.40
# 2     2022-01-06 01:24:20.083000+00:00   61.3407 -149.885200   30.00  1.50
# 3     2022-01-06 01:15:15.851000+00:00   62.8703 -150.762500  111.30  2.10
# 4     2022-01-06 01:10:44.629000+00:00   64.0145 -148.765700    1.90  1.50
# ...                                ...       ...         ...     ...   ...
# 33889 2022-02-15 19:12:23.740000+00:00   39.4215 -110.312333   -1.56  1.83
# 33890 2022-02-15 19:04:27.070000+00:00   38.8250 -122.797167    2.68  0.41
# 33891 2022-02-15 19:00:38.627000+00:00   38.5375 -119.382100    0.00  1.40
# 33892 2022-02-15 18:52:46.384000+00:00   55.3724 -159.286100   15.00  1.80
# 33893 2022-02-15 18:48:53.076000+00:00   61.8432 -147.521000   34.40  1.20
#
#       magType   nst     gap     dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.87500  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.11900  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN      NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN      NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN      NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...      ...     ...  ...                       ...
# 33889      md   9.0  194.00  0.01022  0.1200  ...  2022-02-15T19:51:17.520Z
# 33890      md  25.0   44.00  0.01021  0.0300  ...  2022-02-17T09:24:12.854Z
# 33891      ml   6.0  179.74  0.05500  0.1995  ...  2022-02-16T02:37:07.010Z
# 33892      ml   NaN     NaN      NaN  0.5500  ...  2022-03-05T17:45:05.111Z
# 33893      ml   NaN     NaN      NaN  0.7200  ...  2022-03-05T17:44:55.267Z
#
#                                      place        type horizontalError  \
# 0           37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                 34 km SE of Mina, Nevada  earthquake             NaN
# 2      5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3           41 km N of Petersville, Alaska  earthquake             NaN
# 4                 17 km E of Ferry, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 33889         15 km SSE of Sunnyside, Utah  earthquake            0.63
# 33890           6km NNW of The Geysers, CA  earthquake            0.18
# 33891       8 km ENE of Walker, California  earthquake             NaN
# 33892      60 km SSE of Ivanof Bay, Alaska  earthquake             NaN
# 33893     8 km ENE of Glacier View, Alaska  earthquake             NaN
#
#       depthError  magError  magNst     status  locationSource magSource
# 0          39.10     0.290     4.0  automatic              nn        nn
# 1           2.00     0.460     5.0  automatic              nn        nn
# 2           0.20       NaN     NaN  automatic              ak        ak
# 3           0.80       NaN     NaN  automatic              ak        ak
# 4           0.60       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 33889       0.36     0.324     7.0   reviewed              uu        uu
# 33890       0.28     0.129     3.0   reviewed              nc        nc
# 33891       0.00     0.280     3.0   reviewed              nn        nn
# 33892       0.40       NaN     NaN   reviewed              ak        ak
# 33893       0.20       NaN     NaN   reviewed              ak        ak
#
# [33894 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
#review names of all columns (features)
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#        latitude   longitude   depth   mag     Unix Time
# 0       37.3840 -117.107500    1.10  1.30  1.641433e+09
# 1       38.1810 -117.818000    7.30  1.40  1.641433e+09
# 2       61.3407 -149.885200   30.00  1.50  1.641432e+09
# 3       62.8703 -150.762500  111.30  2.10  1.641432e+09
# 4       64.0145 -148.765700    1.90  1.50  1.641431e+09
# ...         ...         ...     ...   ...           ...
# 33889   39.4215 -110.312333   -1.56  1.83  1.644952e+09
# 33890   38.8250 -122.797167    2.68  0.41  1.644952e+09
# 33891   38.5375 -119.382100    0.00  1.40  1.644952e+09
# 33892   55.3724 -159.286100   15.00  1.80  1.644951e+09
# 33893   61.8432 -147.521000   34.40  1.20  1.644951e+09
#
# [33894 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: longitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['longitude'], axis = 1)

y = cleaned_df_dropped[['longitude']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((33888, 4), (33888, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)

# %%
#split dataset into training set and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1641.5538392306635, 	R2 score: 0.6880375073863574, 	Model score: 0.6880375073863574
# n_estimators=3:
# 	Mean Squared Error: 1363.199407532764, 	R2 score: 0.7409362550650979, 	Model score: 0.7409362550650979
# n_estimators=4:
# 	Mean Squared Error: 1281.9837806560215, 	R2 score: 0.7563705520062949, 	Model score: 0.7563705520062949
# n_estimators=5:
# 	Mean Squared Error: 1178.9516234825005, 	R2 score: 0.7759508836427377, 	Model score: 0.7759508836427377
# n_estimators=6:
# 	Mean Squared Error: 1126.720285272438, 	R2 score: 0.7858769780973636, 	Model score: 0.7858769780973636
# n_estimators=7:
# 	Mean Squared Error: 1104.185323051795, 	R2 score: 0.7901595442961066, 	Model score: 0.7901595442961066
# n_estimators=8:
# 	Mean Squared Error: 1075.4264785871765, 	R2 score: 0.7956249031466425, 	Model score: 0.7956249031466425
# n_estimators=9:
# 	Mean Squared Error: 1037.2021293187026, 	R2 score: 0.8028890957618029, 	Model score: 0.8028890957618029
# n_estimators=10:
# 	Mean Squared Error: 1008.5613341904764, 	R2 score: 0.8083320204013174, 	Model score: 0.8083320204013174
# n_estimators=11:
# 	Mean Squared Error: 1000.886703849558, 	R2 score: 0.8097905146363668, 	Model score: 0.8097905146363668
# n_estimators=12:
# 	Mean Squared Error: 989.6048752114865, 	R2 score: 0.811934524353905, 	Model score: 0.811934524353905
# n_estimators=13:
# 	Mean Squared Error: 987.8110553559501, 	R2 score: 0.8122754236287623, 	Model score: 0.8122754236287623
# n_estimators=14:
# 	Mean Squared Error: 986.7769143793438, 	R2 score: 0.8124719527885536, 	Model score: 0.8124719527885536
# n_estimators=15:
# 	Mean Squared Error: 981.1063352142177, 	R2 score: 0.8135495951836057, 	Model score: 0.8135495951836057
# n_estimators=16:
# 	Mean Squared Error: 978.4586876765985, 	R2 score: 0.8140527567039035, 	Model score: 0.8140527567039035
# n_estimators=17:
# 	Mean Squared Error: 978.1571650989794, 	R2 score: 0.814110058348629, 	Model score: 0.814110058348629
# n_estimators=18:
# 	Mean Squared Error: 970.9523221018405, 	R2 score: 0.8154792737386833, 	Model score: 0.8154792737386833
# n_estimators=19:
# 	Mean Squared Error: 972.2809829201803, 	R2 score: 0.8152267737409241, 	Model score: 0.8152267737409241
# n_estimators=20:
# 	Mean Squared Error: 966.8090667766872, 	R2 score: 0.8162666620215894, 	Model score: 0.8162666620215894
# n_estimators=21:
# 	Mean Squared Error: 966.6102605276014, 	R2 score: 0.8163044433550612, 	Model score: 0.8163044433550612
# n_estimators=22:
# 	Mean Squared Error: 960.0334086089326, 	R2 score: 0.8175543147080838, 	Model score: 0.8175543147080838
# n_estimators=23:
# 	Mean Squared Error: 966.716896056961, 	R2 score: 0.8162841782350602, 	Model score: 0.8162841782350602
# n_estimators=24:
# 	Mean Squared Error: 968.1187630486202, 	R2 score: 0.8160177660647254, 	Model score: 0.8160177660647254
# n_estimators=25:
# 	Mean Squared Error: 963.7805011406573, 	R2 score: 0.8168422135888183, 	Model score: 0.8168422135888183
# n_estimators=26:
# 	Mean Squared Error: 966.4851331779179, 	R2 score: 0.8163282226786317, 	Model score: 0.8163282226786317
# n_estimators=27:
# 	Mean Squared Error: 967.2549371564202, 	R2 score: 0.8161819283797679, 	Model score: 0.8161819283797679
# n_estimators=28:
# 	Mean Squared Error: 965.1414221170245, 	R2 score: 0.8165835828391643, 	Model score: 0.8165835828391643
# n_estimators=29:
# 	Mean Squared Error: 960.6372707817492, 	R2 score: 0.8174395561518155, 	Model score: 0.8174395561518155
# n_estimators=30:
# 	Mean Squared Error: 959.475163389912, 	R2 score: 0.8176604041739627, 	Model score: 0.8176604041739627
# n_estimators=31:
# 	Mean Squared Error: 959.8420219378864, 	R2 score: 0.8175906860177088, 	Model score: 0.8175906860177088
# n_estimators=32:
# 	Mean Squared Error: 956.1106981926436, 	R2 score: 0.818299790421412, 	Model score: 0.818299790421412
# n_estimators=33:
# 	Mean Squared Error: 956.0302658841042, 	R2 score: 0.8183150758557725, 	Model score: 0.8183150758557725
# n_estimators=34:
# 	Mean Squared Error: 956.3108610835797, 	R2 score: 0.8182617512703998, 	Model score: 0.8182617512703998
# n_estimators=35:
# 	Mean Squared Error: 956.4229044691999, 	R2 score: 0.8182404584361207, 	Model score: 0.8182404584361207
# n_estimators=36:
# 	Mean Squared Error: 951.4773202629, 	R2 score: 0.8191803220821106, 	Model score: 0.8191803220821106
# n_estimators=37:
# 	Mean Squared Error: 953.0336310143041, 	R2 score: 0.818884559269045, 	Model score: 0.818884559269045
# n_estimators=38:
# 	Mean Squared Error: 953.9763291774734, 	R2 score: 0.8187054079907035, 	Model score: 0.8187054079907035
# n_estimators=39:
# 	Mean Squared Error: 954.4055646225212, 	R2 score: 0.8186238356680936, 	Model score: 0.8186238356680936
# n_estimators=40:
# 	Mean Squared Error: 952.0449885390427, 	R2 score: 0.8190724418492659, 	Model score: 0.8190724418492659
# n_estimators=41:
# 	Mean Squared Error: 953.9676005028861, 	R2 score: 0.8187070667965352, 	Model score: 0.8187070667965352
# n_estimators=42:
# 	Mean Squared Error: 950.1759821855678, 	R2 score: 0.8194276296395209, 	Model score: 0.8194276296395209
# n_estimators=43:
# 	Mean Squared Error: 948.2735715594025, 	R2 score: 0.8197891656103369, 	Model score: 0.8197891656103369
# n_estimators=44:
# 	Mean Squared Error: 947.1048443101508, 	R2 score: 0.8200112716766436, 	Model score: 0.8200112716766436
# n_estimators=45:
# 	Mean Squared Error: 947.0100726250753, 	R2 score: 0.8200292821801061, 	Model score: 0.8200292821801061
# n_estimators=46:
# 	Mean Squared Error: 946.0920356172413, 	R2 score: 0.8202037468284357, 	Model score: 0.8202037468284357
# n_estimators=47:
# 	Mean Squared Error: 945.2438301796896, 	R2 score: 0.8203649406170421, 	Model score: 0.8203649406170421
# n_estimators=48:
# 	Mean Squared Error: 943.9143837797559, 	R2 score: 0.8206175899074937, 	Model score: 0.8206175899074937
# n_estimators=49:
# 	Mean Squared Error: 944.8089889368823, 	R2 score: 0.8204475782709255, 	Model score: 0.8204475782709255
# n_estimators=50:
# 	Mean Squared Error: 945.087937408662, 	R2 score: 0.8203945666312903, 	Model score: 0.8203945666312903
# Max score: 0.8206175899074937
# Best model score:  0.8206175899074937

# %%
#create and run model: Now with 100 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,100):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 60:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1641.5538392306635, 	R2: 0.6880375073863574, 	Model score: 0.6880375073863574
# n_estimators=3:
# 	Mean Squared Error: 1363.199407532764, 	R2: 0.7409362550650979, 	Model score: 0.7409362550650979
# n_estimators=4:
# 	Mean Squared Error: 1281.9837806560215, 	R2: 0.7563705520062949, 	Model score: 0.7563705520062949
# n_estimators=5:
# 	Mean Squared Error: 1178.9516234825005, 	R2: 0.7759508836427377, 	Model score: 0.7759508836427377
# n_estimators=6:
# 	Mean Squared Error: 1126.720285272438, 	R2: 0.7858769780973636, 	Model score: 0.7858769780973636
# n_estimators=7:
# 	Mean Squared Error: 1104.185323051795, 	R2: 0.7901595442961066, 	Model score: 0.7901595442961066
# n_estimators=8:
# 	Mean Squared Error: 1075.4264785871765, 	R2: 0.7956249031466425, 	Model score: 0.7956249031466425
# n_estimators=9:
# 	Mean Squared Error: 1037.2021293187026, 	R2: 0.8028890957618029, 	Model score: 0.8028890957618029
# n_estimators=10:
# 	Mean Squared Error: 1008.5613341904764, 	R2: 0.8083320204013174, 	Model score: 0.8083320204013174
# n_estimators=11:
# 	Mean Squared Error: 1000.886703849558, 	R2: 0.8097905146363668, 	Model score: 0.8097905146363668
# n_estimators=12:
# 	Mean Squared Error: 989.6048752114865, 	R2: 0.811934524353905, 	Model score: 0.811934524353905
# n_estimators=13:
# 	Mean Squared Error: 987.8110553559501, 	R2: 0.8122754236287623, 	Model score: 0.8122754236287623
# n_estimators=14:
# 	Mean Squared Error: 986.7769143793438, 	R2: 0.8124719527885536, 	Model score: 0.8124719527885536
# n_estimators=15:
# 	Mean Squared Error: 981.1063352142177, 	R2: 0.8135495951836057, 	Model score: 0.8135495951836057
# n_estimators=16:
# 	Mean Squared Error: 978.4586876765985, 	R2: 0.8140527567039035, 	Model score: 0.8140527567039035
# n_estimators=17:
# 	Mean Squared Error: 978.1571650989794, 	R2: 0.814110058348629, 	Model score: 0.814110058348629
# n_estimators=18:
# 	Mean Squared Error: 970.9523221018405, 	R2: 0.8154792737386833, 	Model score: 0.8154792737386833
# n_estimators=19:
# 	Mean Squared Error: 972.2809829201803, 	R2: 0.8152267737409241, 	Model score: 0.8152267737409241
# n_estimators=20:
# 	Mean Squared Error: 966.8090667766872, 	R2: 0.8162666620215894, 	Model score: 0.8162666620215894
# n_estimators=21:
# 	Mean Squared Error: 966.6102605276014, 	R2: 0.8163044433550612, 	Model score: 0.8163044433550612
# n_estimators=22:
# 	Mean Squared Error: 960.0334086089326, 	R2: 0.8175543147080838, 	Model score: 0.8175543147080838
# n_estimators=23:
# 	Mean Squared Error: 966.716896056961, 	R2: 0.8162841782350602, 	Model score: 0.8162841782350602
# n_estimators=24:
# 	Mean Squared Error: 968.1187630486202, 	R2: 0.8160177660647254, 	Model score: 0.8160177660647254
# n_estimators=25:
# 	Mean Squared Error: 963.7805011406573, 	R2: 0.8168422135888183, 	Model score: 0.8168422135888183
# n_estimators=26:
# 	Mean Squared Error: 966.4851331779179, 	R2: 0.8163282226786317, 	Model score: 0.8163282226786317
# n_estimators=27:
# 	Mean Squared Error: 967.2549371564202, 	R2: 0.8161819283797679, 	Model score: 0.8161819283797679
# n_estimators=28:
# 	Mean Squared Error: 965.1414221170245, 	R2: 0.8165835828391643, 	Model score: 0.8165835828391643
# n_estimators=29:
# 	Mean Squared Error: 960.6372707817492, 	R2: 0.8174395561518155, 	Model score: 0.8174395561518155
# n_estimators=30:
# 	Mean Squared Error: 959.475163389912, 	R2: 0.8176604041739627, 	Model score: 0.8176604041739627
# n_estimators=31:
# 	Mean Squared Error: 959.8420219378864, 	R2: 0.8175906860177088, 	Model score: 0.8175906860177088
# n_estimators=32:
# 	Mean Squared Error: 956.1106981926436, 	R2: 0.818299790421412, 	Model score: 0.818299790421412
# n_estimators=33:
# 	Mean Squared Error: 956.0302658841042, 	R2: 0.8183150758557725, 	Model score: 0.8183150758557725
# n_estimators=34:
# 	Mean Squared Error: 956.3108610835797, 	R2: 0.8182617512703998, 	Model score: 0.8182617512703998
# n_estimators=35:
# 	Mean Squared Error: 956.4229044691999, 	R2: 0.8182404584361207, 	Model score: 0.8182404584361207
# n_estimators=36:
# 	Mean Squared Error: 951.4773202629, 	R2: 0.8191803220821106, 	Model score: 0.8191803220821106
# n_estimators=37:
# 	Mean Squared Error: 953.0336310143041, 	R2: 0.818884559269045, 	Model score: 0.818884559269045
# n_estimators=38:
# 	Mean Squared Error: 953.9763291774734, 	R2: 0.8187054079907035, 	Model score: 0.8187054079907035
# n_estimators=39:
# 	Mean Squared Error: 954.4055646225212, 	R2: 0.8186238356680936, 	Model score: 0.8186238356680936
# n_estimators=40:
# 	Mean Squared Error: 952.0449885390427, 	R2: 0.8190724418492659, 	Model score: 0.8190724418492659
# n_estimators=41:
# 	Mean Squared Error: 953.9676005028861, 	R2: 0.8187070667965352, 	Model score: 0.8187070667965352
# n_estimators=42:
# 	Mean Squared Error: 950.1759821855678, 	R2: 0.8194276296395209, 	Model score: 0.8194276296395209
# n_estimators=43:
# 	Mean Squared Error: 948.2735715594025, 	R2: 0.8197891656103369, 	Model score: 0.8197891656103369
# n_estimators=44:
# 	Mean Squared Error: 947.1048443101508, 	R2: 0.8200112716766436, 	Model score: 0.8200112716766436
# n_estimators=45:
# 	Mean Squared Error: 947.0100726250753, 	R2: 0.8200292821801061, 	Model score: 0.8200292821801061
# n_estimators=46:
# 	Mean Squared Error: 946.0920356172413, 	R2: 0.8202037468284357, 	Model score: 0.8202037468284357
# n_estimators=47:
# 	Mean Squared Error: 945.2438301796896, 	R2: 0.8203649406170421, 	Model score: 0.8203649406170421
# n_estimators=48:
# 	Mean Squared Error: 943.9143837797559, 	R2: 0.8206175899074937, 	Model score: 0.8206175899074937
# n_estimators=49:
# 	Mean Squared Error: 944.8089889368823, 	R2: 0.8204475782709255, 	Model score: 0.8204475782709255
# n_estimators=50:
# 	Mean Squared Error: 945.087937408662, 	R2: 0.8203945666312903, 	Model score: 0.8203945666312903
# n_estimators=51:
# 	Mean Squared Error: 942.989590380602, 	R2: 0.8207933385470192, 	Model score: 0.8207933385470192
# Improvement found!
# n_estimators=52:
# 	Mean Squared Error: 941.1082357051259, 	R2: 0.8211508730244305, 	Model score: 0.8211508730244305
# Improvement found!
# n_estimators=53:
# 	Mean Squared Error: 939.4623142323134, 	R2: 0.8214636655463897, 	Model score: 0.8214636655463897
# Improvement found!
# n_estimators=54:
# 	Mean Squared Error: 939.5741063507579, 	R2: 0.8214424204631697, 	Model score: 0.8214424204631697
# n_estimators=55:
# 	Mean Squared Error: 938.1259833136317, 	R2: 0.8217176231774985, 	Model score: 0.8217176231774985
# Improvement found!
# n_estimators=56:
# 	Mean Squared Error: 937.1360653906759, 	R2: 0.8219057481450434, 	Model score: 0.8219057481450434
# Improvement found!
# n_estimators=57:
# 	Mean Squared Error: 935.4554769366633, 	R2: 0.8222251288139205, 	Model score: 0.8222251288139205
# Improvement found!
# n_estimators=58:
# 	Mean Squared Error: 933.6659630620153, 	R2: 0.8225652097759701, 	Model score: 0.8225652097759701
# Improvement found!
# n_estimators=59:
# 	Mean Squared Error: 932.4604269301217, 	R2: 0.8227943110382337, 	Model score: 0.8227943110382337
# Improvement found!
# n_estimators=60:
# 	Mean Squared Error: 932.0974729184187, 	R2: 0.8228632871726066, 	Model score: 0.8228632871726066
# Improvement found!
# n_estimators=61:
# 	Mean Squared Error: 933.2232296660625, 	R2: 0.8226493472623346, 	Model score: 0.8226493472623346
# n_estimators=62:
# 	Mean Squared Error: 933.7601928416289, 	R2: 0.8225473022567502, 	Model score: 0.8225473022567502
# n_estimators=63:
# 	Mean Squared Error: 933.621036044905, 	R2: 0.8225737477501192, 	Model score: 0.8225737477501192
# n_estimators=64:
# 	Mean Squared Error: 931.1194869789421, 	R2: 0.8230491445743737, 	Model score: 0.8230491445743737
# Improvement found!
# n_estimators=65:
# 	Mean Squared Error: 930.9340686978718, 	R2: 0.8230843816453466, 	Model score: 0.8230843816453466
# Improvement found!
# n_estimators=66:
# 	Mean Squared Error: 931.6592605505318, 	R2: 0.822946565478388, 	Model score: 0.822946565478388
# n_estimators=67:
# 	Mean Squared Error: 932.8465044859101, 	R2: 0.8227209404829906, 	Model score: 0.8227209404829906
# n_estimators=68:
# 	Mean Squared Error: 932.3236985295692, 	R2: 0.8228202950368259, 	Model score: 0.8228202950368259
# n_estimators=69:
# 	Mean Squared Error: 933.2621744948866, 	R2: 0.822641946149082, 	Model score: 0.822641946149082
# n_estimators=70:
# 	Mean Squared Error: 933.987607244865, 	R2: 0.8225040842017621, 	Model score: 0.8225040842017621
# n_estimators=71:
# 	Mean Squared Error: 933.4119233424327, 	R2: 0.8226134877320445, 	Model score: 0.8226134877320445
# n_estimators=72:
# 	Mean Squared Error: 932.1076071069333, 	R2: 0.8228613612615374, 	Model score: 0.8228613612615374
# n_estimators=73:
# 	Mean Squared Error: 931.726786357759, 	R2: 0.8229337328081247, 	Model score: 0.8229337328081247
# n_estimators=74:
# 	Mean Squared Error: 931.2769076009248, 	R2: 0.8230192282058398, 	Model score: 0.8230192282058398
# n_estimators=75:
# 	Mean Squared Error: 932.0363653788455, 	R2: 0.8228749001090252, 	Model score: 0.8228749001090252
# n_estimators=76:
# 	Mean Squared Error: 932.4146863138741, 	R2: 0.8228030036295563, 	Model score: 0.8228030036295563
# n_estimators=77:
# 	Mean Squared Error: 933.4984980699045, 	R2: 0.8225970349863994, 	Model score: 0.8225970349863994
# n_estimators=78:
# 	Mean Squared Error: 934.5326634230489, 	R2: 0.8224005011940672, 	Model score: 0.8224005011940672
# n_estimators=79:
# 	Mean Squared Error: 936.0799836283345, 	R2: 0.8221064469531545, 	Model score: 0.8221064469531545
# n_estimators=80:
# 	Mean Squared Error: 936.8737171327699, 	R2: 0.8219556050638438, 	Model score: 0.8219556050638438
# n_estimators=81:
# 	Mean Squared Error: 937.060014846772, 	R2: 0.8219202008645788, 	Model score: 0.8219202008645788
# n_estimators=82:
# 	Mean Squared Error: 936.8736848427186, 	R2: 0.8219556112002766, 	Model score: 0.8219556112002766
# n_estimators=83:
# 	Mean Squared Error: 938.0285883950177, 	R2: 0.8217361322028212, 	Model score: 0.8217361322028212
# n_estimators=84:
# 	Mean Squared Error: 937.4070914303168, 	R2: 0.8218542420921384, 	Model score: 0.8218542420921384
# n_estimators=85:
# 	Mean Squared Error: 936.7977688800328, 	R2: 0.8219700383438663, 	Model score: 0.8219700383438663
# n_estimators=86:
# 	Mean Squared Error: 937.1312744094563, 	R2: 0.8219066586277869, 	Model score: 0.8219066586277869
# n_estimators=87:
# 	Mean Squared Error: 937.07812452158, 	R2: 0.821916759284316, 	Model score: 0.821916759284316
# n_estimators=88:
# 	Mean Squared Error: 936.3919172208891, 	R2: 0.8220471667889968, 	Model score: 0.8220471667889968
# n_estimators=89:
# 	Mean Squared Error: 936.0431155567215, 	R2: 0.8221134533974411, 	Model score: 0.8221134533974411
# n_estimators=90:
# 	Mean Squared Error: 935.9459729053907, 	R2: 0.8221319144816432, 	Model score: 0.8221319144816432
# n_estimators=91:
# 	Mean Squared Error: 935.5853466258213, 	R2: 0.8222004482515312, 	Model score: 0.8222004482515312
# n_estimators=92:
# 	Mean Squared Error: 934.2827333413563, 	R2: 0.8224479981505486, 	Model score: 0.8224479981505486
# n_estimators=93:
# 	Mean Squared Error: 934.5295502578588, 	R2: 0.8224010928230161, 	Model score: 0.8224010928230161
# n_estimators=94:
# 	Mean Squared Error: 934.891931265017, 	R2: 0.8223322255829859, 	Model score: 0.8223322255829859
# n_estimators=95:
# 	Mean Squared Error: 932.7512565310025, 	R2: 0.8227390414972364, 	Model score: 0.8227390414972364
# n_estimators=96:
# 	Mean Squared Error: 932.2741651177354, 	R2: 0.8228297084147207, 	Model score: 0.8228297084147207
# n_estimators=97:
# 	Mean Squared Error: 933.1563422830993, 	R2: 0.8226620586058282, 	Model score: 0.8226620586058282
# n_estimators=98:
# 	Mean Squared Error: 934.6359990651247, 	R2: 0.8223808631878639, 	Model score: 0.8223808631878639
# n_estimators=99:
# 	Mean Squared Error: 933.6867809804146, 	R2: 0.8225612535184539, 	Model score: 0.8225612535184539
# n_estimators=100:
# 	Mean Squared Error: 932.8229389971383, 	R2: 0.8227254188914601, 	Model score: 0.8227254188914601
# Best score found: 0.823.
# Number of estimators: 100.
# Code execution time: 178.626 seconds.

# %%
#visualize gini importance
features_lst = []
gini_score_lst = []
for feature, score in zip(cleaned_df_dropped[['mag', 'latitude', 'depth', 'Unix Time']],best_model.feature_importances_):
    features_lst.append(feature)
    gini_score_lst.append(score)
feature_lst = [feature.capitalize() for feature in features_lst]
d = {'Names': feature_lst, 'Scores': gini_score_lst}
gini_df = pd.DataFrame(d)

sns.set()

p = sns.catplot(y='Names', x="Scores", data=gini_df, kind='bar', height=10, aspect=1, legend=False)
p.set_ylabels(fontsize=14)
p.set_yticklabels(fontsize=12)
p.set_xticklabels(fontsize=12)
p.set_xlabels(fontsize=14)
plt.show()

# %% [markdown]
# Cross-Validation

# %%
#define number of splits fro cross-validation
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 3389  3390  3391 ... 33885 33886 33887] | test: [   0    1    2 ... 3386 3387 3388]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [3389 3390 3391 ... 6775 6776 6777]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [ 6778  6779  6780 ... 10164 10165 10166]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [10167 10168 10169 ... 13553 13554 13555]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [13556 13557 13558 ... 16942 16943 16944]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [16945 16946 16947 ... 20331 20332 20333]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [20334 20335 20336 ... 23720 23721 23722]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [23723 23724 23725 ... 27109 27110 27111]
# Train: [    0     1     2 ... 33885 33886 33887] | test: [27112 27113 27114 ... 30497 30498 30499]
# Train: [    0     1     2 ... 30497 30498 30499] | test: [30500 30501 30502 ... 33885 33886 33887]

# %%
#calculate cross-validation score
from numpy import mean
from numpy import std

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y.values.ravel(), scoring='neg_mean_absolute_error', cv=k_fold, n_jobs=-1)
    print(cv_score)

# report performance
print('MAE: %.3f (%.3f)' % (mean(cv_score), std(cv_score)))
# Out:
# [ -7.5353609   -9.67515366 -12.8204702   -6.63606704  -9.9533601
#  -12.60653117 -11.26882554 -11.19616     -9.95747106  -9.40977653]
# MAE: -10.106 (1.885)

# %%
#define tree for plot validation curve
reg_etrees = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
#create elements for plot validation curve
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 100, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y.values.ravel(),
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
#plot validation curve
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
#use the best model to make predictions
testpred = best_model.predict(X_test)
actual_lon = y_test
lons = actual_lon['longitude'].tolist()
testpredict = []
abs_error = []
for item in testpred:
    testpredict.append(item)

maerr=mean_absolute_error(lons, testpredict)
test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %.3f' % rmse)
print('MAE: %.3f' % maerr)
# Out:
# RMSE: 30.511
# MAE: 8.804

# %%
#make dataframe with actual test values and ML predicted ones
lon_pred = actual_lon
lon_pred['Predicted'] = testpredict

# %%
lon_pred_all = lon_pred.rename(columns={'longitude': 'Actual'})

# %%
lon_pred_all.head(5)
# Out:
#            Actual   Predicted
# 8338  -121.142333 -114.509038
# 8426   161.043300   75.869071
# 3079  -119.622500 -119.664068
# 5192  -122.819336 -122.825543
# 32429 -175.527600  -94.185900

# %%
#join dataframes for actual and predicted with original dataframe
lon_pred_all = lon_pred.merge(model_df, how='inner', left_index=True, right_index=True)
lon_pred_all = lon_pred_all.rename(columns={'longitude_x': 'Actual', 'longitude_y': 'longitude'})
lon_pred_all.head(5)
# Out:
#            Actual   Predicted                             time   latitude  \
# 8338  -121.142333 -114.509038 2021-12-07 15:32:01.140000+00:00  36.562500
# 8426   161.043300   75.869071 2021-12-07 10:28:00.447000+00:00  -9.963400
# 3079  -119.622500 -119.664068 2021-12-24 04:06:37.017000+00:00  40.160500
# 5192  -122.819336 -122.825543 2021-12-17 20:17:55.100000+00:00  38.839832
# 32429 -175.527600  -94.185900 2022-02-19 14:45:11.512000+00:00 -23.717300
#
#         longitude   depth   mag magType   nst     gap  ...  \
# 8338  -121.142333    4.35  1.38      md  14.0  120.00  ...
# 8426   161.043300  170.33  5.40     mww   NaN   25.00  ...
# 3079  -119.622500    6.20  0.30      ml   3.0  241.35  ...
# 5192  -122.819336    1.36  0.65      md  22.0   56.00  ...
# 32429 -175.527600   10.00  5.10      mb   NaN  154.00  ...
#
#                                          place        type horizontalError  \
# 8338                    3km N of Pinnacles, CA  earthquake            0.28
# 8426   110 km WNW of Kirakira, Solomon Islands  earthquake            4.70
# 3079              23 km N of Sutcliffe, Nevada  earthquake             NaN
# 5192                       9km WNW of Cobb, CA  earthquake            0.22
# 32429             270 km SSW of ‘Ohonua, Tonga  earthquake            7.40
#
#       depthError magError magNst     status  locationSource  magSource  \
# 8338        1.49    0.327   13.0   reviewed              nc         nc
# 8426        5.80    0.098   10.0   reviewed              us         us
# 3079        8.30    0.000    1.0   reviewed              nn         nn
# 5192        0.51    0.270    4.0  automatic              nc         nc
# 32429       1.80    0.092   38.0   reviewed              us         us
#
#           Unix Time
# 8338   1.638891e+09
# 8426   1.638873e+09
# 3079   1.640319e+09
# 5192   1.639772e+09
# 32429  1.645282e+09
#
# [5 rows x 25 columns]

# %%
#plot actual vs predicted values
x = np.array(lon_pred_all['longitude'])
y = np.array(testpredict)
# r2_score(y_test, y_pred)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Longitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted longitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(lon_pred_all['longitude'], testpredict)), (0, 150),  fontsize=14)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 140), fontsize=14)

fig.savefig('../static/images/extratrees_lon_linear_sns.png', bbox_inches='tight',dpi=600)
plt.show()

# %%
# make a single prediction
from datetime import datetime
mag = float(input('Enter a magnitude: '))
lat = float(input('Enter a latitude (in decimal form; negative for south hemisphere): '))
depth = float(input('Enter a depth (in km, only numerical value): '))
date_input = input('Enter a date (yyyy/mm/dd): ')
time_input = input('Enter a time in UTC (HH:MM:SS): ')
datetime_str = date_input + ' '+ time_input
date_time_obj = datetime.strptime(datetime_str, '%Y/%m/%d %H:%M:%S')
date_time_unix = (time.mktime(date_time_obj.timetuple()))
single_features = [[mag,lat,depth,date_time_unix]]
y_pred = best_model.predict(single_features)
print('Predicted Latitude: %g' % y_pred)
# Out:
# Predicted Latitude: 45.0017

# %% [markdown]
# Test with new data from USGS

# %%
#obtain USGS data for the day
page_url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.csv"

test_df = pd.read_csv(page_url)
test_df
# Out:
#                          time   latitude   longitude      depth   mag magType  \
# 0    2022-03-18T23:17:29.390Z  36.564167 -121.095833   6.000000  1.78      md
# 1    2022-03-18T23:12:44.580Z  35.860833 -117.681167   7.860000  0.88      ml
# 2    2022-03-18T22:59:59.356Z  64.959600 -147.297700   5.500000  1.40      ml
# 3    2022-03-18T22:31:46.680Z  38.801834 -122.772499   1.640000  0.84      md
# 4    2022-03-18T22:25:25.619Z  37.058500 -117.355000   8.500000  1.30      ml
# ..                        ...        ...         ...        ...   ...     ...
# 291  2022-03-17T23:48:33.060Z  19.194166 -155.435165  31.850000  2.00      md
# 292  2022-03-17T23:47:11.504Z  62.749400 -148.899300   0.000000  2.20      ml
# 293  2022-03-17T23:46:17.450Z  34.437333 -119.134000  13.660000  1.19      ml
# 294  2022-03-17T23:44:25.260Z  60.032000 -153.096167  -1.170000  0.79      ml
# 295  2022-03-17T23:33:17.070Z  19.203333 -155.427673  32.889999  2.39      ml
#
#       nst     gap      dmin   rms  ...                   updated  \
# 0    11.0  121.00  0.047500  0.12  ...  2022-03-18T23:28:10.634Z
# 1    17.0   83.00  0.081520  0.07  ...  2022-03-18T23:30:08.604Z
# 2     NaN     NaN       NaN  0.30  ...  2022-03-18T23:02:29.973Z
# 3     8.0  231.00  0.010060  0.02  ...  2022-03-18T22:50:12.387Z
# 4     8.0  118.89  0.063000  0.19  ...  2022-03-18T22:45:42.858Z
# ..    ...     ...       ...   ...  ...                       ...
# 291  35.0  148.00       NaN  0.11  ...  2022-03-17T23:51:45.340Z
# 292   NaN     NaN       NaN  0.82  ...  2022-03-17T23:53:58.877Z
# 293  10.0  178.00  0.002922  0.16  ...  2022-03-17T23:54:48.366Z
# 294   5.0  162.00       NaN  0.04  ...  2022-03-18T20:56:39.870Z
# 295  41.0  147.00       NaN  0.12  ...  2022-03-18T00:07:29.040Z
#
#                               place        type horizontalError depthError  \
# 0           6km NE of Pinnacles, CA  earthquake            0.48       1.12
# 1       22km ESE of Little Lake, CA  earthquake            0.13       0.37
# 2            15 km E of Fox, Alaska  earthquake             NaN       0.50
# 3        3km NNW of The Geysers, CA  earthquake            1.38       0.73
# 4       55 km WNW of Beatty, Nevada  earthquake             NaN       2.60
# ..                              ...         ...             ...        ...
# 291      4 km ESE of Pāhala, Hawaii  earthquake            0.63       0.73
# 292      70 km ENE of Chase, Alaska  earthquake             NaN       0.20
# 293              10km E of Ojai, CA  earthquake            0.65       0.87
# 294  62 km ENE of Pedro Bay, Alaska  earthquake            0.28       0.78
# 295        5 km E of Pāhala, Hawaii  earthquake            0.58       0.75
#
#      magError  magNst     status  locationSource magSource
# 0    0.130000    11.0  automatic              nc        nc
# 1    0.117000     9.0   reviewed              ci        ci
# 2         NaN     NaN  automatic              ak        ak
# 3         NaN     1.0  automatic              nc        nc
# 4    1.040000     6.0   reviewed              nn        nn
# ..        ...     ...        ...             ...       ...
# 291  0.550000    12.0  automatic              hv        hv
# 292       NaN     NaN  automatic              ak        ak
# 293  0.136000     6.0   reviewed              ci        ci
# 294  0.323555     6.0   reviewed              av        av
# 295  0.320000     7.0  automatic              hv        hv
#
# [296 rows x 22 columns]

# %%
#create unix time column and drop columns not needed

test_df['Unix Time'] = pd.to_datetime(test_df['time']).astype(int)/10**9
cleaned_test_df = test_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_test_df
# Out:
#       latitude   longitude      depth   mag     Unix Time
# 0    36.564167 -121.095833   6.000000  1.78  1.647645e+09
# 1    35.860833 -117.681167   7.860000  0.88  1.647645e+09
# 2    64.959600 -147.297700   5.500000  1.40  1.647644e+09
# 3    38.801834 -122.772499   1.640000  0.84  1.647643e+09
# 4    37.058500 -117.355000   8.500000  1.30  1.647642e+09
# ..         ...         ...        ...   ...           ...
# 291  19.194166 -155.435165  31.850000  2.00  1.647561e+09
# 292  62.749400 -148.899300   0.000000  2.20  1.647561e+09
# 293  34.437333 -119.134000  13.660000  1.19  1.647561e+09
# 294  60.032000 -153.096167  -1.170000  0.79  1.647561e+09
# 295  19.203333 -155.427673  32.889999  2.39  1.647560e+09
#
# [296 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_test_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X_test_data = cleaned_test_df.drop(['longitude'], axis = 1)

y_test_data = cleaned_test_df[['longitude']]

# %%
#predict values with best model
pred_data_y = best_model.predict(X_test_data)

# %%
#create dataframe with values
test_pred_data = cleaned_test_df
test_pred_data['Predicted'] = pred_data_y
test_pred_data
# Out:
#       latitude   longitude      depth   mag     Unix Time   Predicted
# 0    36.564167 -121.095833   6.000000  1.78  1.647645e+09 -105.838630
# 1    35.860833 -117.681167   7.860000  0.88  1.647645e+09 -117.419428
# 2    64.959600 -147.297700   5.500000  1.40  1.647644e+09 -148.732732
# 3    38.801834 -122.772499   1.640000  0.84  1.647643e+09 -122.773126
# 4    37.058500 -117.355000   8.500000  1.30  1.647642e+09 -114.872897
# ..         ...         ...        ...   ...           ...         ...
# 291  19.194166 -155.435165  31.850000  2.00  1.647561e+09 -155.421251
# 292  62.749400 -148.899300   0.000000  2.20  1.647561e+09 -149.392855
# 293  34.437333 -119.134000  13.660000  1.19  1.647561e+09 -118.692987
# 294  60.032000 -153.096167  -1.170000  0.79  1.647561e+09 -152.012041
# 295  19.203333 -155.427673  32.889999  2.39  1.647560e+09 -155.409605
#
# [296 rows x 6 columns]

# %%
#create graph for actual vs predicted values
from datetime import date
today = date.today()

x = np.array(test_pred_data['longitude'])
y = np.array(test_pred_data['Predicted'])

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'purple'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle(f'Earthquake Longitude Model Predictions Using Best Model and Daily Data ({today})', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Longitude Values Using Best Model and Data Not Used For Testing Model Split', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(x, y)), (0, 100),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 80), fontsize=12)

fig.savefig('../static/images/extratrees_lon_linear_sns_daily.png', bbox_inches='tight', dpi=600)
plt.show()

# %%
#connection to a PostgreSQL local database
# ===========================================

# user_name_var = input('What is the username of your database? ')
host_var = input('What is the host address of your database?')
pw = input("Enter the database password: ")
# db_name = input("Enter the name of the database: ")

string_output = "postgresql://postgres"+':'+pw+'@'+host_var+":5432"+'/earthquake_db'
engine = create_engine(string_output)
connection = engine.connect()
print("Connected to database...")
#create new database with predicted values for both training and test databases
#=============
#PostgreSQL
lon_pred_all.to_sql('earthquake_etrees_lon', engine, if_exists='replace', index = False)
#=============
#SQLite
cur = conn.cursor()
lon_pred_all.to_sql('earthquake_etrees_lon', conn, if_exists='replace', index=False)
# Close connection to SQLite database
conn.close()
connection.close()
