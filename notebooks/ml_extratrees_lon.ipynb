# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("paper")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
#create dataframe reading all rows from sqlite database
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0      2022-01-06T01:42:39.855Z  37.384000 -117.107500    1.10  1.30      ml
# 1      2022-01-06T01:31:33.698Z  38.181000 -117.818000    7.30  1.40      ml
# 2      2022-01-06T01:24:20.083Z  61.340700 -149.885200   30.00  1.50      ml
# 3      2022-01-06T01:15:15.851Z  62.870300 -150.762500  111.30  2.10      ml
# 4      2022-01-06T01:10:44.629Z  64.014500 -148.765700    1.90  1.50      ml
# ...                         ...        ...         ...     ...   ...     ...
# 44892  2022-03-21T04:48:46.720Z  38.823833 -122.808000    3.90  0.43      md
# 44893  2022-03-21T04:46:01.380Z  38.821835 -122.760834    1.85  0.85      md
# 44894  2022-03-21T04:41:58.710Z  19.870000 -155.577000   20.18  1.63      md
# 44895  2022-03-21T04:39:20.420Z  38.801666 -122.815498    3.22  0.35      md
# 44896  2022-03-21T04:33:48.020Z  33.679500 -116.709333   16.00  0.69      ml
#
#         nst     gap      dmin     rms  ...                   updated  \
# 0       8.0  149.46  0.875000  0.2175  ...  2022-01-06T01:47:19.317Z
# 1      11.0  154.64  0.119000  0.1017  ...  2022-01-06T01:47:40.245Z
# 2       NaN     NaN       NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3       NaN     NaN       NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4       NaN     NaN       NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...     ...     ...       ...     ...  ...                       ...
# 44892  14.0   98.00  0.001678  0.0400  ...  2022-03-21T20:17:52.874Z
# 44893   7.0  127.00  0.011170  0.0100  ...  2022-03-21T05:29:21.342Z
# 44894  24.0  120.00       NaN  0.1500  ...  2022-03-22T00:38:03.450Z
# 44895   7.0  161.00  0.012880  0.0100  ...  2022-03-21T04:56:14.173Z
# 44896  23.0   99.00  0.031460  0.0800  ...  2022-03-21T16:40:48.625Z
#
#                                      place        type horizontalError  \
# 0           37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                 34 km SE of Mina, Nevada  earthquake             NaN
# 2      5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3           41 km N of Petersville, Alaska  earthquake             NaN
# 4                 17 km E of Ferry, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 44892            7km NW of The Geysers, CA  earthquake            0.39
# 44893                    3km W of Cobb, CA  earthquake            0.48
# 44894          19 km SSE of Waimea, Hawaii  earthquake            0.46
# 44895           6km WNW of The Geysers, CA  earthquake            0.59
# 44896               7km S of Idyllwild, CA  earthquake            0.18
#
#       depthError  magError  magNst     status  locationSource magSource
# 0          39.10  0.290000     4.0  automatic              nn        nn
# 1           2.00  0.460000     5.0  automatic              nn        nn
# 2           0.20       NaN     NaN  automatic              ak        ak
# 3           0.80       NaN     NaN  automatic              ak        ak
# 4           0.60       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 44892       0.28  0.151000     3.0   reviewed              nc        nc
# 44893       0.96       NaN     1.0  automatic              nc        nc
# 44894       0.99  0.124445    15.0   reviewed              hv        hv
# 44895       1.06       NaN     1.0  automatic              nc        nc
# 44896       0.27  0.087000     9.0   reviewed              ci        ci
#
# [44897 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time   latitude   longitude   depth   mag  \
# 0     2022-01-06 01:42:39.855000+00:00  37.384000 -117.107500    1.10  1.30
# 1     2022-01-06 01:31:33.698000+00:00  38.181000 -117.818000    7.30  1.40
# 2     2022-01-06 01:24:20.083000+00:00  61.340700 -149.885200   30.00  1.50
# 3     2022-01-06 01:15:15.851000+00:00  62.870300 -150.762500  111.30  2.10
# 4     2022-01-06 01:10:44.629000+00:00  64.014500 -148.765700    1.90  1.50
# ...                                ...        ...         ...     ...   ...
# 44892 2022-03-21 04:48:46.720000+00:00  38.823833 -122.808000    3.90  0.43
# 44893 2022-03-21 04:46:01.380000+00:00  38.821835 -122.760834    1.85  0.85
# 44894 2022-03-21 04:41:58.710000+00:00  19.870000 -155.577000   20.18  1.63
# 44895 2022-03-21 04:39:20.420000+00:00  38.801666 -122.815498    3.22  0.35
# 44896 2022-03-21 04:33:48.020000+00:00  33.679500 -116.709333   16.00  0.69
#
#       magType   nst     gap      dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.875000  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.119000  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN       NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN       NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN       NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...       ...     ...  ...                       ...
# 44892      md  14.0   98.00  0.001678  0.0400  ...  2022-03-21T20:17:52.874Z
# 44893      md   7.0  127.00  0.011170  0.0100  ...  2022-03-21T05:29:21.342Z
# 44894      md  24.0  120.00       NaN  0.1500  ...  2022-03-22T00:38:03.450Z
# 44895      md   7.0  161.00  0.012880  0.0100  ...  2022-03-21T04:56:14.173Z
# 44896      ml  23.0   99.00  0.031460  0.0800  ...  2022-03-21T16:40:48.625Z
#
#                                      place        type horizontalError  \
# 0           37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                 34 km SE of Mina, Nevada  earthquake             NaN
# 2      5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3           41 km N of Petersville, Alaska  earthquake             NaN
# 4                 17 km E of Ferry, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 44892            7km NW of The Geysers, CA  earthquake            0.39
# 44893                    3km W of Cobb, CA  earthquake            0.48
# 44894          19 km SSE of Waimea, Hawaii  earthquake            0.46
# 44895           6km WNW of The Geysers, CA  earthquake            0.59
# 44896               7km S of Idyllwild, CA  earthquake            0.18
#
#       depthError  magError  magNst     status  locationSource magSource
# 0          39.10  0.290000     4.0  automatic              nn        nn
# 1           2.00  0.460000     5.0  automatic              nn        nn
# 2           0.20       NaN     NaN  automatic              ak        ak
# 3           0.80       NaN     NaN  automatic              ak        ak
# 4           0.60       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 44892       0.28  0.151000     3.0   reviewed              nc        nc
# 44893       0.96       NaN     1.0  automatic              nc        nc
# 44894       0.99  0.124445    15.0   reviewed              hv        hv
# 44895       1.06       NaN     1.0  automatic              nc        nc
# 44896       0.27  0.087000     9.0   reviewed              ci        ci
#
# [44897 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
#review names of all columns (features)
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#         latitude   longitude   depth   mag     Unix Time
# 0      37.384000 -117.107500    1.10  1.30  1.641433e+09
# 1      38.181000 -117.818000    7.30  1.40  1.641433e+09
# 2      61.340700 -149.885200   30.00  1.50  1.641432e+09
# 3      62.870300 -150.762500  111.30  2.10  1.641432e+09
# 4      64.014500 -148.765700    1.90  1.50  1.641431e+09
# ...          ...         ...     ...   ...           ...
# 44892  38.823833 -122.808000    3.90  0.43  1.647838e+09
# 44893  38.821835 -122.760834    1.85  0.85  1.647838e+09
# 44894  19.870000 -155.577000   20.18  1.63  1.647838e+09
# 44895  38.801666 -122.815498    3.22  0.35  1.647838e+09
# 44896  33.679500 -116.709333   16.00  0.69  1.647837e+09
#
# [44897 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: longitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['longitude'], axis = 1)

y = cleaned_df_dropped[['longitude']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((44891, 4), (44891, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)

# %%
#split dataset into training set and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1539.2072776961331, 	R2 score: 0.7213204429344701, 	Model score: 0.7213204429344701
# n_estimators=3:
# 	Mean Squared Error: 1306.9920129044724, 	R2 score: 0.7633639338104081, 	Model score: 0.7633639338104081
# n_estimators=4:
# 	Mean Squared Error: 1278.831247780806, 	R2 score: 0.7684625515632011, 	Model score: 0.7684625515632011
# n_estimators=5:
# 	Mean Squared Error: 1225.311165737731, 	R2 score: 0.7781525738064687, 	Model score: 0.7781525738064687
# n_estimators=6:
# 	Mean Squared Error: 1185.1273967449172, 	R2 score: 0.7854280038972767, 	Model score: 0.7854280038972767
# n_estimators=7:
# 	Mean Squared Error: 1151.1202578429943, 	R2 score: 0.7915851307141658, 	Model score: 0.7915851307141658
# n_estimators=8:
# 	Mean Squared Error: 1127.3878055803898, 	R2 score: 0.7958819849328652, 	Model score: 0.7958819849328652
# n_estimators=9:
# 	Mean Squared Error: 1111.1175513181831, 	R2 score: 0.7988277787299957, 	Model score: 0.7988277787299957
# n_estimators=10:
# 	Mean Squared Error: 1101.571798209325, 	R2 score: 0.8005560750334119, 	Model score: 0.8005560750334119
# n_estimators=11:
# 	Mean Squared Error: 1104.6490144594836, 	R2 score: 0.7999989328771763, 	Model score: 0.7999989328771763
# n_estimators=12:
# 	Mean Squared Error: 1094.3503014101486, 	R2 score: 0.8018635555517972, 	Model score: 0.8018635555517972
# n_estimators=13:
# 	Mean Squared Error: 1088.8736759820658, 	R2 score: 0.8028551202166916, 	Model score: 0.8028551202166916
# n_estimators=14:
# 	Mean Squared Error: 1092.3590251622732, 	R2 score: 0.8022240839814598, 	Model score: 0.8022240839814598
# n_estimators=15:
# 	Mean Squared Error: 1076.6099724148442, 	R2 score: 0.8050755121857394, 	Model score: 0.8050755121857394
# n_estimators=16:
# 	Mean Squared Error: 1064.3352581450235, 	R2 score: 0.8072978976859818, 	Model score: 0.8072978976859818
# n_estimators=17:
# 	Mean Squared Error: 1057.1442445480416, 	R2 score: 0.8085998591002097, 	Model score: 0.8085998591002097
# n_estimators=18:
# 	Mean Squared Error: 1053.1724974466645, 	R2 score: 0.8093189596002053, 	Model score: 0.8093189596002053
# n_estimators=19:
# 	Mean Squared Error: 1047.2361851835083, 	R2 score: 0.8103937523822243, 	Model score: 0.8103937523822243
# n_estimators=20:
# 	Mean Squared Error: 1044.31094922217, 	R2 score: 0.8109233779068893, 	Model score: 0.8109233779068893
# n_estimators=21:
# 	Mean Squared Error: 1036.5140002144924, 	R2 score: 0.8123350463204992, 	Model score: 0.8123350463204992
# n_estimators=22:
# 	Mean Squared Error: 1030.0815086707112, 	R2 score: 0.813499674321045, 	Model score: 0.813499674321045
# n_estimators=23:
# 	Mean Squared Error: 1033.8036541482115, 	R2 score: 0.812825765180909, 	Model score: 0.812825765180909
# n_estimators=24:
# 	Mean Squared Error: 1031.344105566943, 	R2 score: 0.8132710761660773, 	Model score: 0.8132710761660773
# n_estimators=25:
# 	Mean Squared Error: 1032.4565045731465, 	R2 score: 0.8130696719323389, 	Model score: 0.8130696719323389
# n_estimators=26:
# 	Mean Squared Error: 1031.6819382801118, 	R2 score: 0.8132099102190132, 	Model score: 0.8132099102190132
# n_estimators=27:
# 	Mean Squared Error: 1029.7972444895315, 	R2 score: 0.8135511414738117, 	Model score: 0.8135511414738117
# n_estimators=28:
# 	Mean Squared Error: 1027.3605086116527, 	R2 score: 0.8139923221289274, 	Model score: 0.8139923221289274
# n_estimators=29:
# 	Mean Squared Error: 1026.2518328379842, 	R2 score: 0.8141930522567096, 	Model score: 0.8141930522567096
# n_estimators=30:
# 	Mean Squared Error: 1027.2428500853407, 	R2 score: 0.8140136246698345, 	Model score: 0.8140136246698345
# n_estimators=31:
# 	Mean Squared Error: 1028.6409812218958, 	R2 score: 0.8137604875053339, 	Model score: 0.8137604875053339
# n_estimators=32:
# 	Mean Squared Error: 1027.1286149180157, 	R2 score: 0.8140343073980757, 	Model score: 0.8140343073980757
# n_estimators=33:
# 	Mean Squared Error: 1026.8005573011524, 	R2 score: 0.8140937035253447, 	Model score: 0.8140937035253447
# n_estimators=34:
# 	Mean Squared Error: 1026.141873585545, 	R2 score: 0.814212960813672, 	Model score: 0.814212960813672
# n_estimators=35:
# 	Mean Squared Error: 1025.2380209691373, 	R2 score: 0.8143766068998379, 	Model score: 0.8143766068998379
# n_estimators=36:
# 	Mean Squared Error: 1024.8932229546992, 	R2 score: 0.8144390339422077, 	Model score: 0.8144390339422077
# n_estimators=37:
# 	Mean Squared Error: 1021.8011968967105, 	R2 score: 0.8149988574726454, 	Model score: 0.8149988574726454
# n_estimators=38:
# 	Mean Squared Error: 1017.6278857814672, 	R2 score: 0.8157544519334731, 	Model score: 0.8157544519334731
# n_estimators=39:
# 	Mean Squared Error: 1014.2761963094545, 	R2 score: 0.8163612885506178, 	Model score: 0.8163612885506178
# n_estimators=40:
# 	Mean Squared Error: 1013.3725694410803, 	R2 score: 0.8165248937642107, 	Model score: 0.8165248937642107
# n_estimators=41:
# 	Mean Squared Error: 1011.3897302873308, 	R2 score: 0.8168838946246575, 	Model score: 0.8168838946246575
# n_estimators=42:
# 	Mean Squared Error: 1009.6183676802967, 	R2 score: 0.8172046068210483, 	Model score: 0.8172046068210483
# n_estimators=43:
# 	Mean Squared Error: 1008.2769357183815, 	R2 score: 0.8174474783760346, 	Model score: 0.8174474783760346
# n_estimators=44:
# 	Mean Squared Error: 1007.5849280691075, 	R2 score: 0.8175727690941724, 	Model score: 0.8175727690941724
# n_estimators=45:
# 	Mean Squared Error: 1005.5187628154052, 	R2 score: 0.8179468564741307, 	Model score: 0.8179468564741307
# n_estimators=46:
# 	Mean Squared Error: 1004.5853404710112, 	R2 score: 0.8181158562763406, 	Model score: 0.8181158562763406
# n_estimators=47:
# 	Mean Squared Error: 1004.7910706324031, 	R2 score: 0.818078608018044, 	Model score: 0.818078608018044
# n_estimators=48:
# 	Mean Squared Error: 1007.4917448602068, 	R2 score: 0.8175896402821916, 	Model score: 0.8175896402821916
# n_estimators=49:
# 	Mean Squared Error: 1007.9741184606082, 	R2 score: 0.8175023046365979, 	Model score: 0.8175023046365979
# n_estimators=50:
# 	Mean Squared Error: 1009.9505387834652, 	R2 score: 0.8171444659308367, 	Model score: 0.8171444659308367
# Max score: 0.8181158562763406
# Best model score:  0.8181158562763406

# %%
#create and run model: Now with 100 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,80):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 60:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1539.2072776961331, 	R2: 0.7213204429344701, 	Model score: 0.7213204429344701
# n_estimators=3:
# 	Mean Squared Error: 1306.9920129044724, 	R2: 0.7633639338104081, 	Model score: 0.7633639338104081
# n_estimators=4:
# 	Mean Squared Error: 1278.831247780806, 	R2: 0.7684625515632011, 	Model score: 0.7684625515632011
# n_estimators=5:
# 	Mean Squared Error: 1225.311165737731, 	R2: 0.7781525738064687, 	Model score: 0.7781525738064687
# n_estimators=6:
# 	Mean Squared Error: 1185.1273967449172, 	R2: 0.7854280038972767, 	Model score: 0.7854280038972767
# n_estimators=7:
# 	Mean Squared Error: 1151.1202578429943, 	R2: 0.7915851307141658, 	Model score: 0.7915851307141658
# n_estimators=8:
# 	Mean Squared Error: 1127.3878055803898, 	R2: 0.7958819849328652, 	Model score: 0.7958819849328652
# n_estimators=9:
# 	Mean Squared Error: 1111.1175513181831, 	R2: 0.7988277787299957, 	Model score: 0.7988277787299957
# n_estimators=10:
# 	Mean Squared Error: 1101.571798209325, 	R2: 0.8005560750334119, 	Model score: 0.8005560750334119
# n_estimators=11:
# 	Mean Squared Error: 1104.6490144594836, 	R2: 0.7999989328771763, 	Model score: 0.7999989328771763
# n_estimators=12:
# 	Mean Squared Error: 1094.3503014101486, 	R2: 0.8018635555517972, 	Model score: 0.8018635555517972
# n_estimators=13:
# 	Mean Squared Error: 1088.8736759820658, 	R2: 0.8028551202166916, 	Model score: 0.8028551202166916
# n_estimators=14:
# 	Mean Squared Error: 1092.3590251622732, 	R2: 0.8022240839814598, 	Model score: 0.8022240839814598
# n_estimators=15:
# 	Mean Squared Error: 1076.6099724148442, 	R2: 0.8050755121857394, 	Model score: 0.8050755121857394
# n_estimators=16:
# 	Mean Squared Error: 1064.3352581450235, 	R2: 0.8072978976859818, 	Model score: 0.8072978976859818
# n_estimators=17:
# 	Mean Squared Error: 1057.1442445480416, 	R2: 0.8085998591002097, 	Model score: 0.8085998591002097
# n_estimators=18:
# 	Mean Squared Error: 1053.1724974466645, 	R2: 0.8093189596002053, 	Model score: 0.8093189596002053
# n_estimators=19:
# 	Mean Squared Error: 1047.2361851835083, 	R2: 0.8103937523822243, 	Model score: 0.8103937523822243
# n_estimators=20:
# 	Mean Squared Error: 1044.31094922217, 	R2: 0.8109233779068893, 	Model score: 0.8109233779068893
# n_estimators=21:
# 	Mean Squared Error: 1036.5140002144924, 	R2: 0.8123350463204992, 	Model score: 0.8123350463204992
# n_estimators=22:
# 	Mean Squared Error: 1030.0815086707112, 	R2: 0.813499674321045, 	Model score: 0.813499674321045
# n_estimators=23:
# 	Mean Squared Error: 1033.8036541482115, 	R2: 0.812825765180909, 	Model score: 0.812825765180909
# n_estimators=24:
# 	Mean Squared Error: 1031.344105566943, 	R2: 0.8132710761660773, 	Model score: 0.8132710761660773
# n_estimators=25:
# 	Mean Squared Error: 1032.4565045731465, 	R2: 0.8130696719323389, 	Model score: 0.8130696719323389
# n_estimators=26:
# 	Mean Squared Error: 1031.6819382801118, 	R2: 0.8132099102190132, 	Model score: 0.8132099102190132
# n_estimators=27:
# 	Mean Squared Error: 1029.7972444895315, 	R2: 0.8135511414738117, 	Model score: 0.8135511414738117
# n_estimators=28:
# 	Mean Squared Error: 1027.3605086116527, 	R2: 0.8139923221289274, 	Model score: 0.8139923221289274
# n_estimators=29:
# 	Mean Squared Error: 1026.2518328379842, 	R2: 0.8141930522567096, 	Model score: 0.8141930522567096
# n_estimators=30:
# 	Mean Squared Error: 1027.2428500853407, 	R2: 0.8140136246698345, 	Model score: 0.8140136246698345
# n_estimators=31:
# 	Mean Squared Error: 1028.6409812218958, 	R2: 0.8137604875053339, 	Model score: 0.8137604875053339
# n_estimators=32:
# 	Mean Squared Error: 1027.1286149180157, 	R2: 0.8140343073980757, 	Model score: 0.8140343073980757
# n_estimators=33:
# 	Mean Squared Error: 1026.8005573011524, 	R2: 0.8140937035253447, 	Model score: 0.8140937035253447
# n_estimators=34:
# 	Mean Squared Error: 1026.141873585545, 	R2: 0.814212960813672, 	Model score: 0.814212960813672
# n_estimators=35:
# 	Mean Squared Error: 1025.2380209691373, 	R2: 0.8143766068998379, 	Model score: 0.8143766068998379
# n_estimators=36:
# 	Mean Squared Error: 1024.8932229546992, 	R2: 0.8144390339422077, 	Model score: 0.8144390339422077
# n_estimators=37:
# 	Mean Squared Error: 1021.8011968967105, 	R2: 0.8149988574726454, 	Model score: 0.8149988574726454
# n_estimators=38:
# 	Mean Squared Error: 1017.6278857814672, 	R2: 0.8157544519334731, 	Model score: 0.8157544519334731
# n_estimators=39:
# 	Mean Squared Error: 1014.2761963094545, 	R2: 0.8163612885506178, 	Model score: 0.8163612885506178
# n_estimators=40:
# 	Mean Squared Error: 1013.3725694410803, 	R2: 0.8165248937642107, 	Model score: 0.8165248937642107
# n_estimators=41:
# 	Mean Squared Error: 1011.3897302873308, 	R2: 0.8168838946246575, 	Model score: 0.8168838946246575
# n_estimators=42:
# 	Mean Squared Error: 1009.6183676802967, 	R2: 0.8172046068210483, 	Model score: 0.8172046068210483
# n_estimators=43:
# 	Mean Squared Error: 1008.2769357183815, 	R2: 0.8174474783760346, 	Model score: 0.8174474783760346
# n_estimators=44:
# 	Mean Squared Error: 1007.5849280691075, 	R2: 0.8175727690941724, 	Model score: 0.8175727690941724
# n_estimators=45:
# 	Mean Squared Error: 1005.5187628154052, 	R2: 0.8179468564741307, 	Model score: 0.8179468564741307
# n_estimators=46:
# 	Mean Squared Error: 1004.5853404710112, 	R2: 0.8181158562763406, 	Model score: 0.8181158562763406
# n_estimators=47:
# 	Mean Squared Error: 1004.7910706324031, 	R2: 0.818078608018044, 	Model score: 0.818078608018044
# n_estimators=48:
# 	Mean Squared Error: 1007.4917448602068, 	R2: 0.8175896402821916, 	Model score: 0.8175896402821916
# n_estimators=49:
# 	Mean Squared Error: 1007.9741184606082, 	R2: 0.8175023046365979, 	Model score: 0.8175023046365979
# n_estimators=50:
# 	Mean Squared Error: 1009.9505387834652, 	R2: 0.8171444659308367, 	Model score: 0.8171444659308367
# n_estimators=51:
# 	Mean Squared Error: 1009.2940323109253, 	R2: 0.8172633290207072, 	Model score: 0.8172633290207072
# n_estimators=52:
# 	Mean Squared Error: 1007.6448870206158, 	R2: 0.8175619132891807, 	Model score: 0.8175619132891807
# n_estimators=53:
# 	Mean Squared Error: 1005.0476074293031, 	R2: 0.8180321610177166, 	Model score: 0.8180321610177166
# n_estimators=54:
# 	Mean Squared Error: 1004.9993895244094, 	R2: 0.8180408910598448, 	Model score: 0.8180408910598448
# n_estimators=55:
# 	Mean Squared Error: 1003.8500520707132, 	R2: 0.8182489831453983, 	Model score: 0.8182489831453983
# Improvement found!
# n_estimators=56:
# 	Mean Squared Error: 1003.7301411334155, 	R2: 0.8182706934942108, 	Model score: 0.8182706934942108
# Improvement found!
# n_estimators=57:
# 	Mean Squared Error: 1003.2169746086605, 	R2: 0.818363604320382, 	Model score: 0.818363604320382
# Improvement found!
# n_estimators=58:
# 	Mean Squared Error: 1000.2921610688477, 	R2: 0.8188931533639613, 	Model score: 0.8188931533639613
# Improvement found!
# n_estimators=59:
# 	Mean Squared Error: 1001.7942189130287, 	R2: 0.8186211998585635, 	Model score: 0.8186211998585635
# n_estimators=60:
# 	Mean Squared Error: 1000.982416123693, 	R2: 0.818768179959967, 	Model score: 0.818768179959967
# n_estimators=61:
# 	Mean Squared Error: 998.461018451191, 	R2: 0.8192246889673898, 	Model score: 0.8192246889673898
# Improvement found!
# n_estimators=62:
# 	Mean Squared Error: 999.2219982071713, 	R2: 0.8190869105769121, 	Model score: 0.8190869105769121
# n_estimators=63:
# 	Mean Squared Error: 998.0436517043593, 	R2: 0.8193002548653856, 	Model score: 0.8193002548653856
# Improvement found!
# n_estimators=64:
# 	Mean Squared Error: 996.8111824520913, 	R2: 0.8195233982914178, 	Model score: 0.8195233982914178
# Improvement found!
# n_estimators=65:
# 	Mean Squared Error: 995.5977205166, 	R2: 0.8197431003676742, 	Model score: 0.8197431003676742
# Improvement found!
# n_estimators=66:
# 	Mean Squared Error: 995.1871151670999, 	R2: 0.8198174420879776, 	Model score: 0.8198174420879776
# Improvement found!
# n_estimators=67:
# 	Mean Squared Error: 995.6873714264485, 	R2: 0.81972686871635, 	Model score: 0.81972686871635
# n_estimators=68:
# 	Mean Squared Error: 994.0047132946345, 	R2: 0.8200315206171445, 	Model score: 0.8200315206171445
# Improvement found!
# n_estimators=69:
# 	Mean Squared Error: 996.4969832899526, 	R2: 0.819580285290722, 	Model score: 0.819580285290722
# n_estimators=70:
# 	Mean Squared Error: 998.2589128801907, 	R2: 0.8192612809792799, 	Model score: 0.8192612809792799
# n_estimators=71:
# 	Mean Squared Error: 997.981121969821, 	R2: 0.8193115761207987, 	Model score: 0.8193115761207987
# n_estimators=72:
# 	Mean Squared Error: 997.7891430480338, 	R2: 0.8193463346628514, 	Model score: 0.8193463346628514
# n_estimators=73:
# 	Mean Squared Error: 999.3162146495044, 	R2: 0.8190698523178991, 	Model score: 0.8190698523178991
# n_estimators=74:
# 	Mean Squared Error: 998.4458895101676, 	R2: 0.8192274281219171, 	Model score: 0.8192274281219171
# n_estimators=75:
# 	Mean Squared Error: 996.665055841903, 	R2: 0.8195498550913518, 	Model score: 0.8195498550913518
# n_estimators=76:
# 	Mean Squared Error: 995.6794096312206, 	R2: 0.8197283102308229, 	Model score: 0.8197283102308229
# n_estimators=77:
# 	Mean Squared Error: 996.9209796778749, 	R2: 0.8195035190700214, 	Model score: 0.8195035190700214
# n_estimators=78:
# 	Mean Squared Error: 996.0454599401198, 	R2: 0.8196620353766003, 	Model score: 0.8196620353766003
# n_estimators=79:
# 	Mean Squared Error: 996.1017152526382, 	R2: 0.819651850130076, 	Model score: 0.819651850130076
# n_estimators=80:
# 	Mean Squared Error: 995.2571921063509, 	R2: 0.8198047543813418, 	Model score: 0.8198047543813418
# n_estimators=81:
# 	Mean Squared Error: 994.1931334531238, 	R2: 0.8199974064032429, 	Model score: 0.8199974064032429
# n_estimators=82:
# 	Mean Squared Error: 996.6211928446747, 	R2: 0.8195577966602465, 	Model score: 0.8195577966602465
# n_estimators=83:
# 	Mean Squared Error: 997.3906172300894, 	R2: 0.8194184893362558, 	Model score: 0.8194184893362558
# n_estimators=84:
# 	Mean Squared Error: 997.9636140466986, 	R2: 0.8193147459994314, 	Model score: 0.8193147459994314
# n_estimators=85:
# 	Mean Squared Error: 996.2178387293799, 	R2: 0.8196308255159567, 	Model score: 0.8196308255159567
# n_estimators=86:
# 	Mean Squared Error: 997.9939537060034, 	R2: 0.8193092528842811, 	Model score: 0.8193092528842811
# n_estimators=87:
# 	Mean Squared Error: 999.3829655100736, 	R2: 0.8190577668109458, 	Model score: 0.8190577668109458
# n_estimators=88:
# 	Mean Squared Error: 997.937838048276, 	R2: 0.8193194128457539, 	Model score: 0.8193194128457539
# n_estimators=89:
# 	Mean Squared Error: 998.1235495898877, 	R2: 0.8192857890376364, 	Model score: 0.8192857890376364
# n_estimators=90:
# 	Mean Squared Error: 997.7501038989532, 	R2: 0.8193534028549863, 	Model score: 0.8193534028549863
# n_estimators=91:
# 	Mean Squared Error: 996.5461932688579, 	R2: 0.8195713756296755, 	Model score: 0.8195713756296755
# n_estimators=92:
# 	Mean Squared Error: 995.7582878901425, 	R2: 0.8197140290104981, 	Model score: 0.8197140290104981
# n_estimators=93:
# 	Mean Squared Error: 995.3276341653713, 	R2: 0.8197920005683297, 	Model score: 0.8197920005683297
# n_estimators=94:
# 	Mean Squared Error: 994.7786162063732, 	R2: 0.8198914024382739, 	Model score: 0.8198914024382739
# n_estimators=95:
# 	Mean Squared Error: 995.6408530038108, 	R2: 0.8197352910605034, 	Model score: 0.8197352910605034
# n_estimators=96:
# 	Mean Squared Error: 995.6112120980616, 	R2: 0.8197406576635625, 	Model score: 0.8197406576635625
# n_estimators=97:
# 	Mean Squared Error: 994.3385092856828, 	R2: 0.8199710855345642, 	Model score: 0.8199710855345642
# n_estimators=98:
# 	Mean Squared Error: 994.2808651569729, 	R2: 0.8199815222317454, 	Model score: 0.8199815222317454
# n_estimators=99:
# 	Mean Squared Error: 994.1237198280556, 	R2: 0.8200099740142259, 	Model score: 0.8200099740142259
# n_estimators=100:
# 	Mean Squared Error: 993.8953557605392, 	R2: 0.8200513202306241, 	Model score: 0.8200513202306241
# Improvement found!
# Best score found: 0.820.
# Number of estimators: 100.
# Code execution time: 230.715 seconds.

# %%
#visualize gini importance
features_lst = []
gini_score_lst = []
for feature, score in zip(cleaned_df_dropped[['mag', 'latitude', 'depth', 'Unix Time']],best_model.feature_importances_):
    features_lst.append(feature)
    gini_score_lst.append(score)
feature_lst = [feature.capitalize() for feature in features_lst]
d = {'Names': feature_lst, 'Scores': gini_score_lst}
gini_df = pd.DataFrame(d)

sns.set()

p = sns.catplot(y='Names', x="Scores", data=gini_df, kind='bar', height=10, aspect=1, legend=False)
p.set_ylabels(fontsize=14)
p.set_yticklabels(fontsize=12)
p.set_xticklabels(fontsize=12)
p.set_xlabels(fontsize=14)
plt.show()

# %% [markdown]
# Cross-Validation

# %%
#define number of splits fro cross-validation
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 4490  4491  4492 ... 44888 44889 44890] | test: [   0    1    2 ... 4487 4488 4489]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [4490 4491 4492 ... 8976 8977 8978]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [ 8979  8980  8981 ... 13465 13466 13467]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [13468 13469 13470 ... 17954 17955 17956]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [17957 17958 17959 ... 22443 22444 22445]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [22446 22447 22448 ... 26932 26933 26934]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [26935 26936 26937 ... 31421 31422 31423]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [31424 31425 31426 ... 35910 35911 35912]
# Train: [    0     1     2 ... 44888 44889 44890] | test: [35913 35914 35915 ... 40399 40400 40401]
# Train: [    0     1     2 ... 40399 40400 40401] | test: [40402 40403 40404 ... 44888 44889 44890]

# %%
#calculate cross-validation score
from numpy import mean
from numpy import std

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y.values.ravel(), scoring='neg_mean_absolute_error', cv=k_fold, n_jobs=-1)
    print(cv_score)

# report performance
print('MAE: %.3f (%.3f)' % (mean(cv_score), std(cv_score)))
# Out:
# [ -7.37066051 -16.11303829  -6.82589375  -9.05935811 -11.22087798
#  -11.20019471 -10.19108965  -9.60942529  -9.22029093  -9.62341332]
# MAE: -10.043 (2.431)

# %%
#define tree for plot validation curve
reg_etrees = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
#create elements for plot validation curve
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 100, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y.values.ravel(),
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
#plot validation curve
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
#use the best model to make predictions
testpred = best_model.predict(X_test)
actual_lon = y_test
lons = actual_lon['longitude'].tolist()
testpredict = []
abs_error = []
for item in testpred:
    testpredict.append(item)

maerr=mean_absolute_error(lons, testpredict)
test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %.3f' % rmse)
print('MAE: %.3f' % maerr)
# Out:
# RMSE: 31.526
# MAE: 8.701

# %%
#make dataframe with actual test values and ML predicted ones
lon_pred = actual_lon
lon_pred['Predicted'] = testpredict

# %%
lon_pred_all = lon_pred.rename(columns={'longitude': 'Actual'})

# %%
lon_pred_all.head(5)
# Out:
#            Actual   Predicted
# 20932  126.210700  102.894328
# 2503  -119.381667 -115.548507
# 6320  -112.521833 -113.294067
# 4336  -151.932500 -152.677324
# 4139  -116.837833 -116.999888

# %%
#join dataframes for actual and predicted with original dataframe
lon_pred_all = lon_pred.merge(model_df, how='inner', left_index=True, right_index=True)
lon_pred_all = lon_pred_all.rename(columns={'longitude_x': 'Actual', 'longitude_y': 'longitude'})
lon_pred_all.head(5)
# Out:
#            Actual   Predicted                             time   latitude  \
# 20932  126.210700  102.894328 2022-02-13 15:00:15.296000+00:00  23.440600
# 2503  -119.381667 -115.548507 2021-12-26 16:40:12.940000+00:00  37.490333
# 6320  -112.521833 -113.294067 2021-12-14 07:48:24.150000+00:00  46.887833
# 4336  -151.932500 -152.677324 2021-12-20 15:49:33.630000+00:00  58.202900
# 4139  -116.837833 -116.999888 2021-12-21 00:26:38.010000+00:00  33.998333
#
#         longitude  depth   mag magType   nst    gap  ...  \
# 20932  126.210700  10.00  4.10      mb   NaN  142.0  ...
# 2503  -119.381667   8.46  1.86      md  16.0   84.0  ...
# 6320  -112.521833  11.66  1.05      ml   9.0  114.0  ...
# 4336  -151.932500  10.30  1.70      ml   NaN    NaN  ...
# 4139  -116.837833  11.38  0.75      ml  18.0   74.0  ...
#
#                                place        type horizontalError depthError  \
# 20932    176 km SSE of Hirara, Japan  earthquake           11.40       2.00
# 2503         30km NE of Oakhurst, CA  earthquake            0.53       2.42
# 6320   14 km ESE of Lincoln, Montana  earthquake            0.61       0.78
# 4336    45 km NE of Ouzinkie, Alaska  earthquake             NaN       0.30
# 4139          9km NNE of Banning, CA  earthquake            0.22       0.49
#
#       magError magNst     status  locationSource  magSource     Unix Time
# 20932    0.303    3.0   reviewed              us         us  1.644764e+09
# 2503     0.245   14.0   reviewed              nc         nc  1.640537e+09
# 6320     0.058    3.0   reviewed              mb         mb  1.639468e+09
# 4336       NaN    NaN  automatic              ak         ak  1.640015e+09
# 4139     0.155    6.0   reviewed              ci         ci  1.640046e+09
#
# [5 rows x 25 columns]

# %%
#plot actual vs predicted values
x = np.array(lon_pred_all['longitude'])
y = np.array(testpredict)
# r2_score(y_test, y_pred)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle('Earthquake Longitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted longitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(lon_pred_all['longitude'], testpredict)), (0, 150),  fontsize=14)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 140), fontsize=14)

fig.savefig('../static/images/extratrees_lon_linear_sns.png', bbox_inches='tight',dpi=600)
plt.show()

# %%
# make a single prediction
from datetime import datetime
mag = float(input('Enter a magnitude: '))
lat = float(input('Enter a latitude (in decimal form; negative for south hemisphere): '))
depth = float(input('Enter a depth (in km, only numerical value): '))
date_input = input('Enter a date (yyyy/mm/dd): ')
time_input = input('Enter a time in UTC (HH:MM:SS): ')
datetime_str = date_input + ' '+ time_input
date_time_obj = datetime.strptime(datetime_str, '%Y/%m/%d %H:%M:%S')
date_time_unix = (time.mktime(date_time_obj.timetuple()))
single_features = [[mag,lat,depth,date_time_unix]]
y_pred = best_model.predict(single_features)
print('Predicted Longitude: %g' % y_pred)
# Out:
# Predicted Longitude: 72.9617

# %% [markdown]
# Test with new data from USGS

# %%
#obtain USGS data for the day
page_url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.csv"

test_df = pd.read_csv(page_url)
test_df
# Out:
#                          time   latitude   longitude      depth   mag magType  \
# 0    2022-05-13T19:48:10.907Z  61.781300 -149.912900  21.900000  2.00      ml
# 1    2022-05-13T19:47:39.640Z  19.156834 -155.367172  28.040001  2.42      ml
# 2    2022-05-13T19:45:18.120Z  35.695000 -117.609169   7.240000  3.08      ml
# 3    2022-05-13T19:28:35.740Z  33.521500 -116.740500   2.260000  0.52      ml
# 4    2022-05-13T19:13:38.240Z  38.833168 -122.816002   1.730000  0.94      md
# ..                        ...        ...         ...        ...   ...     ...
# 252  2022-05-12T20:22:17.330Z  34.798167 -116.256500   4.010000  1.06      ml
# 253  2022-05-12T20:13:15.340Z  40.726333 -111.804167  -2.000000  1.48      md
# 254  2022-05-12T20:10:22.880Z  37.276200  141.603500  53.280000  4.40      mb
# 255  2022-05-12T20:03:09.400Z  38.823502 -122.802002   3.170000  0.88      md
# 256  2022-05-12T20:02:53.170Z  38.823002 -122.801834   3.210000  1.20      md
#
#       nst    gap      dmin   rms  ...                   updated  \
# 0     NaN    NaN       NaN  0.74  ...  2022-05-13T19:50:29.044Z
# 1    46.0  179.0       NaN  0.15  ...  2022-05-13T19:53:09.760Z
# 2    47.0   42.0  0.062790  0.17  ...  2022-05-13T19:56:19.430Z
# 3    24.0   37.0  0.043870  0.18  ...  2022-05-13T19:32:20.889Z
# 4    17.0   55.0  0.010800  0.03  ...  2022-05-13T19:23:11.005Z
# ..    ...    ...       ...   ...  ...                       ...
# 252  10.0  138.0  0.071710  0.13  ...  2022-05-12T20:44:42.038Z
# 253   6.0  118.0  0.054530  0.16  ...  2022-05-12T22:03:08.150Z
# 254   NaN  126.0  2.820000  0.84  ...  2022-05-12T20:30:55.040Z
# 255  27.0   47.0  0.006306  0.02  ...  2022-05-12T21:24:09.973Z
# 256  29.0   32.0  0.006448  0.02  ...  2022-05-12T21:48:11.107Z
#
#                            place          type horizontalError depthError  \
# 0     7 km ENE of Willow, Alaska    earthquake             NaN       0.40
# 1    12 km ESE of Pāhala, Hawaii    earthquake            0.59       0.83
# 2      10km NE of Ridgecrest, CA    earthquake            0.21       0.50
# 3            7km WSW of Anza, CA    earthquake            0.25       0.35
# 4      8km NW of The Geysers, CA    earthquake            0.23       0.53
# ..                           ...           ...             ...        ...
# 252        12km NW of Ludlow, CA    earthquake            0.34       0.66
# 253  2 km NE of Canyon Rim, Utah  quarry blast            1.04      31.61
# 254    58 km ESE of Namie, Japan    earthquake            7.90       6.30
# 255    6km NW of The Geysers, CA    earthquake            0.21       0.48
# 256    6km NW of The Geysers, CA    earthquake            0.22       0.43
#
#      magError  magNst     status  locationSource magSource
# 0         NaN     NaN  automatic              ak        ak
# 1       3.980    19.0  automatic              hv        hv
# 2       0.260    18.0  automatic              ci        ci
# 3       0.154    16.0  automatic              ci        ci
# 4       0.290     2.0  automatic              nc        nc
# ..        ...     ...        ...             ...       ...
# 252     0.195     4.0   reviewed              ci        ci
# 253     0.462     4.0   reviewed              uu        uu
# 254     0.067    64.0   reviewed              us        us
# 255     0.230     4.0  automatic              nc        nc
# 256     0.070     6.0  automatic              nc        nc
#
# [257 rows x 22 columns]

# %%
#create unix time column and drop columns not needed

test_df['Unix Time'] = pd.to_datetime(test_df['time']).astype(int)/10**9
cleaned_test_df = test_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_test_df
# Out:
#       latitude   longitude      depth   mag     Unix Time
# 0    61.781300 -149.912900  21.900000  2.00  1.652471e+09
# 1    19.156834 -155.367172  28.040001  2.42  1.652471e+09
# 2    35.695000 -117.609169   7.240000  3.08  1.652471e+09
# 3    33.521500 -116.740500   2.260000  0.52  1.652470e+09
# 4    38.833168 -122.816002   1.730000  0.94  1.652469e+09
# ..         ...         ...        ...   ...           ...
# 252  34.798167 -116.256500   4.010000  1.06  1.652387e+09
# 253  40.726333 -111.804167  -2.000000  1.48  1.652386e+09
# 254  37.276200  141.603500  53.280000  4.40  1.652386e+09
# 255  38.823502 -122.802002   3.170000  0.88  1.652386e+09
# 256  38.823002 -122.801834   3.210000  1.20  1.652386e+09
#
# [257 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_test_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X_test_data = cleaned_test_df.drop(['longitude'], axis = 1)

y_test_data = cleaned_test_df[['longitude']]

# %%
#predict values with best model
pred_data_y = best_model.predict(X_test_data)

# %%
#create dataframe with values
test_pred_data = cleaned_test_df
test_pred_data['Predicted'] = pred_data_y
test_pred_data
# Out:
#       latitude   longitude      depth   mag     Unix Time   Predicted
# 0    61.781300 -149.912900  21.900000  2.00  1.652471e+09 -148.666862
# 1    19.156834 -155.367172  28.040001  2.42  1.652471e+09 -155.431839
# 2    35.695000 -117.609169   7.240000  3.08  1.652471e+09 -111.228404
# 3    33.521500 -116.740500   2.260000  0.52  1.652470e+09 -116.816055
# 4    38.833168 -122.816002   1.730000  0.94  1.652469e+09 -122.814612
# ..         ...         ...        ...   ...           ...         ...
# 252  34.798167 -116.256500   4.010000  1.06  1.652387e+09 -106.579025
# 253  40.726333 -111.804167  -2.000000  1.48  1.652386e+09 -113.532034
# 254  37.276200  141.603500  53.280000  4.40  1.652386e+09  125.398725
# 255  38.823502 -122.802002   3.170000  0.88  1.652386e+09 -122.803979
# 256  38.823002 -122.801834   3.210000  1.20  1.652386e+09 -122.591387
#
# [257 rows x 6 columns]

# %%
#create graph for actual vs predicted values
from datetime import date
today = date.today()

x = np.array(test_pred_data['longitude'])
y = np.array(test_pred_data['Predicted'])

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'purple'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=13)
plt.xlabel('Actual Longitude',  fontsize=13)
# Bigger title
plt.suptitle(f'Earthquake Longitude Model Predictions Using Best Model and Daily Data ({today})', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Longitude Values Using Best Model and Data Not Used For Testing Model Split', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(x, y)), (0, 100),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 80), fontsize=12)

fig.savefig('../static/images/extratrees_lon_linear_sns_daily.png', bbox_inches='tight', dpi=600)
plt.show()

# %%
#connection to a PostgreSQL local database
# ===========================================

# user_name_var = input('What is the username of your database? ')
host_var = input('What is the host address of your database?')
pw = input("Enter the database password: ")
# db_name = input("Enter the name of the database: ")

string_output = "postgresql://postgres"+':'+pw+'@'+host_var+":5432"+'/earthquake_db'
engine = create_engine(string_output)
connection = engine.connect()
print("Connected to database...")
#create new database with predicted values for both training and test databases
#=============
#PostgreSQL
lon_pred_all.to_sql('earthquake_etrees_lon', engine, if_exists='replace', index = False)
#=============
#SQLite
cur = conn.cursor()
lon_pred_all.to_sql('earthquake_etrees_lon', conn, if_exists='replace', index=False)
# Close connection to SQLite database
conn.close()
connection.close()
# Out:
# Connected to database...
