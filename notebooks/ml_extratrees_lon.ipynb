# %%
#import dependecies
import pandas as pd
import sqlite3
import warnings
warnings.filterwarnings('ignore')

import datetime
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

#import dependencies for ML models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVR
from sklearn.model_selection import validation_curve
import math
from math import sqrt


#import dependencies for graphs
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats
import seaborn as sns; sns.set_theme(color_codes=True)
sns.set_context("poster")

# %%
#connect to a sqlite3 db
conn = sqlite3.connect(r'/Users/rosaicelaroman/Desktop/portfolio_work/earthquake_modeling/Database/db/earthquake_db')
print("Connected to database...")
# Out:
# Connected to database...

# %%
#create dataframe reading all rows from sqlite database
model_df = pd.read_sql_query("SELECT * FROM earthquake_raw", conn)
model_df
# Out:
#                            time   latitude   longitude   depth   mag magType  \
# 0      2022-01-06T01:42:39.855Z  37.384000 -117.107500    1.10  1.30      ml
# 1      2022-01-06T01:31:33.698Z  38.181000 -117.818000    7.30  1.40      ml
# 2      2022-01-06T01:24:20.083Z  61.340700 -149.885200   30.00  1.50      ml
# 3      2022-01-06T01:15:15.851Z  62.870300 -150.762500  111.30  2.10      ml
# 4      2022-01-06T01:10:44.629Z  64.014500 -148.765700    1.90  1.50      ml
# ...                         ...        ...         ...     ...   ...     ...
# 58103  2022-05-10T18:52:32.159Z -27.668500 -176.934500   25.08  4.60      mb
# 58104  2022-05-10T18:49:23.310Z -59.013100  -25.575000   55.95  4.90      mb
# 58105  2022-05-10T16:40:16.050Z  34.731833 -119.073333   11.19  0.83      ml
# 58106  2022-05-10T08:28:40.129Z   2.945500  128.323100   53.98  4.50      mb
# 58107  2022-05-10T00:19:13.902Z  -4.962200  102.541400   41.84  4.30      mb
#
#         nst     gap     dmin     rms  ...                   updated  \
# 0       8.0  149.46  0.87500  0.2175  ...  2022-01-06T01:47:19.317Z
# 1      11.0  154.64  0.11900  0.1017  ...  2022-01-06T01:47:40.245Z
# 2       NaN     NaN      NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3       NaN     NaN      NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4       NaN     NaN      NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...     ...     ...      ...     ...  ...                       ...
# 58103   NaN   76.00  1.80900  0.7400  ...  2022-05-31T22:12:12.040Z
# 58104   NaN   65.00  7.65300  0.6000  ...  2022-05-31T19:19:19.040Z
# 58105   8.0  168.00  0.02522  0.1500  ...  2022-06-07T17:55:46.520Z
# 58106   NaN  100.00  2.36100  0.8200  ...  2022-06-06T07:24:34.040Z
# 58107   NaN  181.00  0.72600  0.2400  ...  2022-05-29T04:58:02.040Z
#
#                                      place        type horizontalError  \
# 0           37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                 34 km SE of Mina, Nevada  earthquake             NaN
# 2      5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3           41 km N of Petersville, Alaska  earthquake             NaN
# 4                 17 km E of Ferry, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 58103              Kermadec Islands region  earthquake            10.1
# 58104        South Sandwich Islands region  earthquake            11.6
# 58105   14km SSE of Pine Mountain Club, CA  earthquake             0.5
# 58106      139 km NNE of Tobelo, Indonesia  earthquake             7.0
# 58107          southern Sumatra, Indonesia  earthquake             9.0
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           39.1     0.290     4.0  automatic              nn        nn
# 1            2.0     0.460     5.0  automatic              nn        nn
# 2            0.2       NaN     NaN  automatic              ak        ak
# 3            0.8       NaN     NaN  automatic              ak        ak
# 4            0.6       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 58103        3.7     0.100    34.0   reviewed              us        us
# 58104        4.4     0.099    32.0   reviewed              us        us
# 58105        0.9     0.211     2.0   reviewed              ci        ci
# 58106        7.8     0.111    24.0   reviewed              us        us
# 58107        8.2     0.266     4.0   reviewed              us        us
#
# [58108 rows x 22 columns]

# %%
#converting time to datetime
model_df['time'] = pd.to_datetime(model_df['time'])
model_df
# Out:
#                                   time   latitude   longitude   depth   mag  \
# 0     2022-01-06 01:42:39.855000+00:00  37.384000 -117.107500    1.10  1.30
# 1     2022-01-06 01:31:33.698000+00:00  38.181000 -117.818000    7.30  1.40
# 2     2022-01-06 01:24:20.083000+00:00  61.340700 -149.885200   30.00  1.50
# 3     2022-01-06 01:15:15.851000+00:00  62.870300 -150.762500  111.30  2.10
# 4     2022-01-06 01:10:44.629000+00:00  64.014500 -148.765700    1.90  1.50
# ...                                ...        ...         ...     ...   ...
# 58103 2022-05-10 18:52:32.159000+00:00 -27.668500 -176.934500   25.08  4.60
# 58104 2022-05-10 18:49:23.310000+00:00 -59.013100  -25.575000   55.95  4.90
# 58105 2022-05-10 16:40:16.050000+00:00  34.731833 -119.073333   11.19  0.83
# 58106 2022-05-10 08:28:40.129000+00:00   2.945500  128.323100   53.98  4.50
# 58107 2022-05-10 00:19:13.902000+00:00  -4.962200  102.541400   41.84  4.30
#
#       magType   nst     gap     dmin     rms  ...                   updated  \
# 0          ml   8.0  149.46  0.87500  0.2175  ...  2022-01-06T01:47:19.317Z
# 1          ml  11.0  154.64  0.11900  0.1017  ...  2022-01-06T01:47:40.245Z
# 2          ml   NaN     NaN      NaN  0.7500  ...  2022-01-06T01:29:22.015Z
# 3          ml   NaN     NaN      NaN  0.3200  ...  2022-01-06T01:29:21.875Z
# 4          ml   NaN     NaN      NaN  0.7200  ...  2022-01-06T01:15:56.292Z
# ...       ...   ...     ...      ...     ...  ...                       ...
# 58103      mb   NaN   76.00  1.80900  0.7400  ...  2022-05-31T22:12:12.040Z
# 58104      mb   NaN   65.00  7.65300  0.6000  ...  2022-05-31T19:19:19.040Z
# 58105      ml   8.0  168.00  0.02522  0.1500  ...  2022-06-07T17:55:46.520Z
# 58106      mb   NaN  100.00  2.36100  0.8200  ...  2022-06-06T07:24:34.040Z
# 58107      mb   NaN  181.00  0.72600  0.2400  ...  2022-05-29T04:58:02.040Z
#
#                                      place        type horizontalError  \
# 0           37 km SSE of Goldfield, Nevada  earthquake             NaN
# 1                 34 km SE of Mina, Nevada  earthquake             NaN
# 2      5 km ESE of Point MacKenzie, Alaska  earthquake             NaN
# 3           41 km N of Petersville, Alaska  earthquake             NaN
# 4                 17 km E of Ferry, Alaska  earthquake             NaN
# ...                                    ...         ...             ...
# 58103              Kermadec Islands region  earthquake            10.1
# 58104        South Sandwich Islands region  earthquake            11.6
# 58105   14km SSE of Pine Mountain Club, CA  earthquake             0.5
# 58106      139 km NNE of Tobelo, Indonesia  earthquake             7.0
# 58107          southern Sumatra, Indonesia  earthquake             9.0
#
#       depthError  magError  magNst     status  locationSource magSource
# 0           39.1     0.290     4.0  automatic              nn        nn
# 1            2.0     0.460     5.0  automatic              nn        nn
# 2            0.2       NaN     NaN  automatic              ak        ak
# 3            0.8       NaN     NaN  automatic              ak        ak
# 4            0.6       NaN     NaN  automatic              ak        ak
# ...          ...       ...     ...        ...             ...       ...
# 58103        3.7     0.100    34.0   reviewed              us        us
# 58104        4.4     0.099    32.0   reviewed              us        us
# 58105        0.9     0.211     2.0   reviewed              ci        ci
# 58106        7.8     0.111    24.0   reviewed              us        us
# 58107        8.2     0.266     4.0   reviewed              us        us
#
# [58108 rows x 22 columns]

# %%
#adding column of converted time to datetime
model_df['Unix Time'] = pd.to_datetime(model_df['time']).astype(int)/10**9
model_df.head(5)
# Out:
#                               time  latitude  longitude  depth  mag magType  \
# 0 2022-01-06 01:42:39.855000+00:00   37.3840  -117.1075    1.1  1.3      ml
# 1 2022-01-06 01:31:33.698000+00:00   38.1810  -117.8180    7.3  1.4      ml
# 2 2022-01-06 01:24:20.083000+00:00   61.3407  -149.8852   30.0  1.5      ml
# 3 2022-01-06 01:15:15.851000+00:00   62.8703  -150.7625  111.3  2.1      ml
# 4 2022-01-06 01:10:44.629000+00:00   64.0145  -148.7657    1.9  1.5      ml
#
#     nst     gap   dmin     rms  ...                                place  \
# 0   8.0  149.46  0.875  0.2175  ...       37 km SSE of Goldfield, Nevada
# 1  11.0  154.64  0.119  0.1017  ...             34 km SE of Mina, Nevada
# 2   NaN     NaN    NaN  0.7500  ...  5 km ESE of Point MacKenzie, Alaska
# 3   NaN     NaN    NaN  0.3200  ...       41 km N of Petersville, Alaska
# 4   NaN     NaN    NaN  0.7200  ...             17 km E of Ferry, Alaska
#
#          type horizontalError depthError magError  magNst     status  \
# 0  earthquake             NaN       39.1     0.29     4.0  automatic
# 1  earthquake             NaN        2.0     0.46     5.0  automatic
# 2  earthquake             NaN        0.2      NaN     NaN  automatic
# 3  earthquake             NaN        0.8      NaN     NaN  automatic
# 4  earthquake             NaN        0.6      NaN     NaN  automatic
#
#    locationSource  magSource     Unix Time
# 0              nn         nn  1.641433e+09
# 1              nn         nn  1.641433e+09
# 2              ak         ak  1.641432e+09
# 3              ak         ak  1.641432e+09
# 4              ak         ak  1.641431e+09
#
# [5 rows x 23 columns]

# %%
#review names of all columns (features)
for col in model_df.columns:
    print(col)
# Out:
# time
# latitude
# longitude
# depth
# mag
# magType
# nst
# gap
# dmin
# rms
# net
# id
# updated
# place
# type
# horizontalError
# depthError
# magError
# magNst
# status
# locationSource
# magSource
# Unix Time

# %%
#drop columns not needed
cleaned_df = model_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_df
# Out:
#         latitude   longitude   depth   mag     Unix Time
# 0      37.384000 -117.107500    1.10  1.30  1.641433e+09
# 1      38.181000 -117.818000    7.30  1.40  1.641433e+09
# 2      61.340700 -149.885200   30.00  1.50  1.641432e+09
# 3      62.870300 -150.762500  111.30  2.10  1.641432e+09
# 4      64.014500 -148.765700    1.90  1.50  1.641431e+09
# ...          ...         ...     ...   ...           ...
# 58103 -27.668500 -176.934500   25.08  4.60  1.652209e+09
# 58104 -59.013100  -25.575000   55.95  4.90  1.652209e+09
# 58105  34.731833 -119.073333   11.19  0.83  1.652201e+09
# 58106   2.945500  128.323100   53.98  4.50  1.652171e+09
# 58107  -4.962200  102.541400   41.84  4.30  1.652142e+09
#
# [58108 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          6
# Unix Time    0
# dtype: int64

# %%
#drop NaNs
cleaned_df_dropped = cleaned_df.dropna()

# %%
#verify dropped NaNs
cleaned_df_dropped.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: longitude, longitude, depth and unix time. Y will be magnitude
X = cleaned_df_dropped.drop(['longitude'], axis = 1)

y = cleaned_df_dropped[['longitude']]

# %%
#checking number of columns and rows for eacg feature
X.shape, y.shape
# Out:
# ((58102, 4), (58102, 1))

# %%
#scale and transform the data
# sc_X = StandardScaler()
# sc_y = StandardScaler()
# X = X.fit_transform(X)
# y = y.fit_transform(y)

# %%
#split dataset into training set and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# Extra Trees Regressor

# %%
#create and run model: First with 50 estimators
scores = []
estimators_lst=[]

for i in range(1,50):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    scores.append(score)
    estimators_lst.append(score)

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2 score:", r2, end = ", ")
    print("\tModel score:", score)
max_score = max(scores)
print("Max score:", max_score)
index_max_score = scores.index(max_score) #find the position in the list for max score to get the number of estimators
best_score = max_score
best_model = ExtraTreesRegressor(n_estimators=index_max_score+2, random_state=0)
best_model.fit(X_train, y_train)
best_model_score = best_model.score(X_test, y_test)
print("Best model score: ", best_model_score)
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1668.8841743283347, 	R2 score: 0.6856261584200075, 	Model score: 0.6856261584200075
# n_estimators=3:
# 	Mean Squared Error: 1397.390612093982, 	R2 score: 0.7367683979095758, 	Model score: 0.7367683979095758
# n_estimators=4:
# 	Mean Squared Error: 1324.4403027643154, 	R2 score: 0.7505103156179429, 	Model score: 0.7505103156179429
# n_estimators=5:
# 	Mean Squared Error: 1213.61092303531, 	R2 score: 0.7713876529438588, 	Model score: 0.7713876529438588
# n_estimators=6:
# 	Mean Squared Error: 1148.9872888428931, 	R2 score: 0.7835610442734917, 	Model score: 0.7835610442734917
# n_estimators=7:
# 	Mean Squared Error: 1119.6983443709144, 	R2 score: 0.7890783103193423, 	Model score: 0.7890783103193423
# n_estimators=8:
# 	Mean Squared Error: 1090.903135522917, 	R2 score: 0.7945025695722568, 	Model score: 0.7945025695722568
# n_estimators=9:
# 	Mean Squared Error: 1075.1294840401545, 	R2 score: 0.7974739102372708, 	Model score: 0.7974739102372708
# n_estimators=10:
# 	Mean Squared Error: 1062.9336120065386, 	R2 score: 0.7997712914465862, 	Model score: 0.7997712914465862
# n_estimators=11:
# 	Mean Squared Error: 1057.4286931180845, 	R2 score: 0.8008082732366772, 	Model score: 0.8008082732366772
# n_estimators=12:
# 	Mean Squared Error: 1051.5107066399653, 	R2 score: 0.8019230660857937, 	Model score: 0.8019230660857937
# n_estimators=13:
# 	Mean Squared Error: 1045.9926838498138, 	R2 score: 0.8029625163059768, 	Model score: 0.8029625163059768
# n_estimators=14:
# 	Mean Squared Error: 1042.0782234189876, 	R2 score: 0.8036998975947933, 	Model score: 0.8036998975947933
# n_estimators=15:
# 	Mean Squared Error: 1037.416841246852, 	R2 score: 0.8045779792753969, 	Model score: 0.8045779792753969
# n_estimators=16:
# 	Mean Squared Error: 1035.6956329584477, 	R2 score: 0.8049022096025271, 	Model score: 0.8049022096025271
# n_estimators=17:
# 	Mean Squared Error: 1030.3972184457969, 	R2 score: 0.8059002914048761, 	Model score: 0.8059002914048761
# n_estimators=18:
# 	Mean Squared Error: 1030.7139299651749, 	R2 score: 0.8058406312927178, 	Model score: 0.8058406312927178
# n_estimators=19:
# 	Mean Squared Error: 1022.807709607038, 	R2 score: 0.8073299550604177, 	Model score: 0.8073299550604177
# n_estimators=20:
# 	Mean Squared Error: 1022.6557573805483, 	R2 score: 0.8073585788594285, 	Model score: 0.8073585788594285
# n_estimators=21:
# 	Mean Squared Error: 1023.9906393119963, 	R2 score: 0.8071071222471001, 	Model score: 0.8071071222471001
# n_estimators=22:
# 	Mean Squared Error: 1020.0780194587696, 	R2 score: 0.8078441568195539, 	Model score: 0.8078441568195539
# n_estimators=23:
# 	Mean Squared Error: 1019.270212583795, 	R2 score: 0.807996326367595, 	Model score: 0.807996326367595
# n_estimators=24:
# 	Mean Squared Error: 1013.0189182467967, 	R2 score: 0.8091739056422984, 	Model score: 0.8091739056422984
# n_estimators=25:
# 	Mean Squared Error: 1016.029387990455, 	R2 score: 0.8086068123995003, 	Model score: 0.8086068123995003
# n_estimators=26:
# 	Mean Squared Error: 1009.9517036634081, 	R2 score: 0.809751688118975, 	Model score: 0.809751688118975
# n_estimators=27:
# 	Mean Squared Error: 1009.1777070316369, 	R2 score: 0.809897488707322, 	Model score: 0.809897488707322
# n_estimators=28:
# 	Mean Squared Error: 1004.7946692773642, 	R2 score: 0.8107231376275985, 	Model score: 0.8107231376275985
# n_estimators=29:
# 	Mean Squared Error: 1005.0186233978301, 	R2 score: 0.810680950567363, 	Model score: 0.810680950567363
# n_estimators=30:
# 	Mean Squared Error: 1007.1872175826198, 	R2 score: 0.8102724445157223, 	Model score: 0.8102724445157223
# n_estimators=31:
# 	Mean Squared Error: 1004.429143913763, 	R2 score: 0.810791992982882, 	Model score: 0.810791992982882
# n_estimators=32:
# 	Mean Squared Error: 1003.3374883808331, 	R2 score: 0.8109976321451727, 	Model score: 0.8109976321451727
# n_estimators=33:
# 	Mean Squared Error: 1002.8880305679638, 	R2 score: 0.8110822981642012, 	Model score: 0.8110822981642012
# n_estimators=34:
# 	Mean Squared Error: 1001.0478626571772, 	R2 score: 0.8114289373523276, 	Model score: 0.8114289373523276
# n_estimators=35:
# 	Mean Squared Error: 999.297371566773, 	R2 score: 0.8117586837884236, 	Model score: 0.8117586837884236
# n_estimators=36:
# 	Mean Squared Error: 997.0225227435069, 	R2 score: 0.8121872054165777, 	Model score: 0.8121872054165777
# n_estimators=37:
# 	Mean Squared Error: 998.2841157649922, 	R2 score: 0.8119495545054027, 	Model score: 0.8119495545054027
# n_estimators=38:
# 	Mean Squared Error: 996.9044839993036, 	R2 score: 0.8122094408083691, 	Model score: 0.8122094408083691
# n_estimators=39:
# 	Mean Squared Error: 994.0606919989106, 	R2 score: 0.8127451363524758, 	Model score: 0.8127451363524758
# n_estimators=40:
# 	Mean Squared Error: 991.9980489012373, 	R2 score: 0.8131336840086876, 	Model score: 0.8131336840086876
# n_estimators=41:
# 	Mean Squared Error: 988.6924905661051, 	R2 score: 0.8137563641732954, 	Model score: 0.8137563641732954
# n_estimators=42:
# 	Mean Squared Error: 987.1884351635312, 	R2 score: 0.8140396886137388, 	Model score: 0.8140396886137388
# n_estimators=43:
# 	Mean Squared Error: 988.7733955356133, 	R2 score: 0.8137411238070325, 	Model score: 0.8137411238070325
# n_estimators=44:
# 	Mean Squared Error: 986.0920867532463, 	R2 score: 0.8142462117905733, 	Model score: 0.8142462117905733
# n_estimators=45:
# 	Mean Squared Error: 983.946711026513, 	R2 score: 0.8146503440959907, 	Model score: 0.8146503440959907
# n_estimators=46:
# 	Mean Squared Error: 982.3607361134337, 	R2 score: 0.8149491000155109, 	Model score: 0.8149491000155109
# n_estimators=47:
# 	Mean Squared Error: 982.9337827853759, 	R2 score: 0.8148411531091682, 	Model score: 0.8148411531091682
# n_estimators=48:
# 	Mean Squared Error: 982.3817236718318, 	R2 score: 0.81494514651205, 	Model score: 0.81494514651205
# n_estimators=49:
# 	Mean Squared Error: 980.8784898572281, 	R2 score: 0.8152283161869498, 	Model score: 0.8152283161869498
# n_estimators=50:
# 	Mean Squared Error: 980.5936137283051, 	R2 score: 0.8152819793496795, 	Model score: 0.8152819793496795
# Max score: 0.8152819793496795
# Best model score:  0.8152819793496795

# %%
#create and run model: Now with 100 max estimators if no improvement of the score is found
scores = []
counter = 0
import time
start_time = time.perf_counter()
for i in range(1,80):
    model = ExtraTreesRegressor(n_estimators=i+1, random_state=0)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test,y_pred)

    r2 = r2_score(y_test, y_pred)
    score = model.score(X_test, y_test)
    estimators = i+1
    current_score = score
    num_estimators = estimators

    print("n_estimators={}:".format(estimators))
    print("\tMean Squared Error:", mse, end = ", ")
    print("\tR2:", r2, end = ", ")
    print("\tModel score:", score)
    if current_score > best_score:
        best_score = current_score
        best_model = model
        num_estimators=i+1
        print('Improvement found!')
        counter = 0
    else:
        counter += 1
    if counter > 60:
        break

end_time = time.perf_counter()
execution_time = end_time - start_time

print(f'Best score found: {best_score:.3f}.')
print(f'Number of estimators: {num_estimators}.')
print(f'Code execution time: {execution_time:.3f} seconds.')
# Out:
# n_estimators=2:
# 	Mean Squared Error: 1668.8841743283347, 	R2: 0.6856261584200075, 	Model score: 0.6856261584200075
# n_estimators=3:
# 	Mean Squared Error: 1397.390612093982, 	R2: 0.7367683979095758, 	Model score: 0.7367683979095758
# n_estimators=4:
# 	Mean Squared Error: 1324.4403027643154, 	R2: 0.7505103156179429, 	Model score: 0.7505103156179429
# n_estimators=5:
# 	Mean Squared Error: 1213.61092303531, 	R2: 0.7713876529438588, 	Model score: 0.7713876529438588
# n_estimators=6:
# 	Mean Squared Error: 1148.9872888428931, 	R2: 0.7835610442734917, 	Model score: 0.7835610442734917
# n_estimators=7:
# 	Mean Squared Error: 1119.6983443709144, 	R2: 0.7890783103193423, 	Model score: 0.7890783103193423
# n_estimators=8:
# 	Mean Squared Error: 1090.903135522917, 	R2: 0.7945025695722568, 	Model score: 0.7945025695722568
# n_estimators=9:
# 	Mean Squared Error: 1075.1294840401545, 	R2: 0.7974739102372708, 	Model score: 0.7974739102372708
# n_estimators=10:
# 	Mean Squared Error: 1062.9336120065386, 	R2: 0.7997712914465862, 	Model score: 0.7997712914465862
# n_estimators=11:
# 	Mean Squared Error: 1057.4286931180845, 	R2: 0.8008082732366772, 	Model score: 0.8008082732366772
# n_estimators=12:
# 	Mean Squared Error: 1051.5107066399653, 	R2: 0.8019230660857937, 	Model score: 0.8019230660857937
# n_estimators=13:
# 	Mean Squared Error: 1045.9926838498138, 	R2: 0.8029625163059768, 	Model score: 0.8029625163059768
# n_estimators=14:
# 	Mean Squared Error: 1042.0782234189876, 	R2: 0.8036998975947933, 	Model score: 0.8036998975947933
# n_estimators=15:
# 	Mean Squared Error: 1037.416841246852, 	R2: 0.8045779792753969, 	Model score: 0.8045779792753969
# n_estimators=16:
# 	Mean Squared Error: 1035.6956329584477, 	R2: 0.8049022096025271, 	Model score: 0.8049022096025271
# n_estimators=17:
# 	Mean Squared Error: 1030.3972184457969, 	R2: 0.8059002914048761, 	Model score: 0.8059002914048761
# n_estimators=18:
# 	Mean Squared Error: 1030.7139299651749, 	R2: 0.8058406312927178, 	Model score: 0.8058406312927178
# n_estimators=19:
# 	Mean Squared Error: 1022.807709607038, 	R2: 0.8073299550604177, 	Model score: 0.8073299550604177
# n_estimators=20:
# 	Mean Squared Error: 1022.6557573805483, 	R2: 0.8073585788594285, 	Model score: 0.8073585788594285
# n_estimators=21:
# 	Mean Squared Error: 1023.9906393119963, 	R2: 0.8071071222471001, 	Model score: 0.8071071222471001
# n_estimators=22:
# 	Mean Squared Error: 1020.0780194587696, 	R2: 0.8078441568195539, 	Model score: 0.8078441568195539
# n_estimators=23:
# 	Mean Squared Error: 1019.270212583795, 	R2: 0.807996326367595, 	Model score: 0.807996326367595
# n_estimators=24:
# 	Mean Squared Error: 1013.0189182467967, 	R2: 0.8091739056422984, 	Model score: 0.8091739056422984
# n_estimators=25:
# 	Mean Squared Error: 1016.029387990455, 	R2: 0.8086068123995003, 	Model score: 0.8086068123995003
# n_estimators=26:
# 	Mean Squared Error: 1009.9517036634081, 	R2: 0.809751688118975, 	Model score: 0.809751688118975
# n_estimators=27:
# 	Mean Squared Error: 1009.1777070316369, 	R2: 0.809897488707322, 	Model score: 0.809897488707322
# n_estimators=28:
# 	Mean Squared Error: 1004.7946692773642, 	R2: 0.8107231376275985, 	Model score: 0.8107231376275985
# n_estimators=29:
# 	Mean Squared Error: 1005.0186233978301, 	R2: 0.810680950567363, 	Model score: 0.810680950567363
# n_estimators=30:
# 	Mean Squared Error: 1007.1872175826198, 	R2: 0.8102724445157223, 	Model score: 0.8102724445157223
# n_estimators=31:
# 	Mean Squared Error: 1004.429143913763, 	R2: 0.810791992982882, 	Model score: 0.810791992982882
# n_estimators=32:
# 	Mean Squared Error: 1003.3374883808331, 	R2: 0.8109976321451727, 	Model score: 0.8109976321451727
# n_estimators=33:
# 	Mean Squared Error: 1002.8880305679638, 	R2: 0.8110822981642012, 	Model score: 0.8110822981642012
# n_estimators=34:
# 	Mean Squared Error: 1001.0478626571772, 	R2: 0.8114289373523276, 	Model score: 0.8114289373523276
# n_estimators=35:
# 	Mean Squared Error: 999.297371566773, 	R2: 0.8117586837884236, 	Model score: 0.8117586837884236
# n_estimators=36:
# 	Mean Squared Error: 997.0225227435069, 	R2: 0.8121872054165777, 	Model score: 0.8121872054165777
# n_estimators=37:
# 	Mean Squared Error: 998.2841157649922, 	R2: 0.8119495545054027, 	Model score: 0.8119495545054027
# n_estimators=38:
# 	Mean Squared Error: 996.9044839993036, 	R2: 0.8122094408083691, 	Model score: 0.8122094408083691
# n_estimators=39:
# 	Mean Squared Error: 994.0606919989106, 	R2: 0.8127451363524758, 	Model score: 0.8127451363524758
# n_estimators=40:
# 	Mean Squared Error: 991.9980489012373, 	R2: 0.8131336840086876, 	Model score: 0.8131336840086876
# n_estimators=41:
# 	Mean Squared Error: 988.6924905661051, 	R2: 0.8137563641732954, 	Model score: 0.8137563641732954
# n_estimators=42:
# 	Mean Squared Error: 987.1884351635312, 	R2: 0.8140396886137388, 	Model score: 0.8140396886137388
# n_estimators=43:
# 	Mean Squared Error: 988.7733955356133, 	R2: 0.8137411238070325, 	Model score: 0.8137411238070325
# n_estimators=44:
# 	Mean Squared Error: 986.0920867532463, 	R2: 0.8142462117905733, 	Model score: 0.8142462117905733
# n_estimators=45:
# 	Mean Squared Error: 983.946711026513, 	R2: 0.8146503440959907, 	Model score: 0.8146503440959907
# n_estimators=46:
# 	Mean Squared Error: 982.3607361134337, 	R2: 0.8149491000155109, 	Model score: 0.8149491000155109
# n_estimators=47:
# 	Mean Squared Error: 982.9337827853759, 	R2: 0.8148411531091682, 	Model score: 0.8148411531091682
# n_estimators=48:
# 	Mean Squared Error: 982.3817236718318, 	R2: 0.81494514651205, 	Model score: 0.81494514651205
# n_estimators=49:
# 	Mean Squared Error: 980.8784898572281, 	R2: 0.8152283161869498, 	Model score: 0.8152283161869498
# n_estimators=50:
# 	Mean Squared Error: 980.5936137283051, 	R2: 0.8152819793496795, 	Model score: 0.8152819793496795
# n_estimators=51:
# 	Mean Squared Error: 980.9922637856976, 	R2: 0.8152068841741625, 	Model score: 0.8152068841741625
# n_estimators=52:
# 	Mean Squared Error: 978.8343835950208, 	R2: 0.8156133719913805, 	Model score: 0.8156133719913805
# Improvement found!
# n_estimators=53:
# 	Mean Squared Error: 979.3593191193008, 	R2: 0.8155144879586309, 	Model score: 0.8155144879586309
# n_estimators=54:
# 	Mean Squared Error: 979.0940801670109, 	R2: 0.8155644519942726, 	Model score: 0.8155644519942726
# n_estimators=55:
# 	Mean Squared Error: 978.9941448243646, 	R2: 0.8155832771818203, 	Model score: 0.8155832771818203
# n_estimators=56:
# 	Mean Squared Error: 977.4615323376349, 	R2: 0.8158719810250937, 	Model score: 0.8158719810250937
# Improvement found!
# n_estimators=57:
# 	Mean Squared Error: 978.7957783496744, 	R2: 0.8156206442032401, 	Model score: 0.8156206442032401
# n_estimators=58:
# 	Mean Squared Error: 979.5261315857696, 	R2: 0.8154830648816349, 	Model score: 0.8154830648816349
# n_estimators=59:
# 	Mean Squared Error: 979.8878606357239, 	R2: 0.8154149246518967, 	Model score: 0.8154149246518967
# n_estimators=60:
# 	Mean Squared Error: 978.43267808469, 	R2: 0.8156890427337898, 	Model score: 0.8156890427337898
# n_estimators=61:
# 	Mean Squared Error: 979.2956728051811, 	R2: 0.8155264772485888, 	Model score: 0.8155264772485888
# n_estimators=62:
# 	Mean Squared Error: 978.8350790825872, 	R2: 0.8156132409798332, 	Model score: 0.8156132409798332
# n_estimators=63:
# 	Mean Squared Error: 976.8966598502496, 	R2: 0.8159783881302685, 	Model score: 0.8159783881302685
# Improvement found!
# n_estimators=64:
# 	Mean Squared Error: 975.8455961954867, 	R2: 0.8161763808513787, 	Model score: 0.8161763808513787
# Improvement found!
# n_estimators=65:
# 	Mean Squared Error: 975.6440495349384, 	R2: 0.8162143469360889, 	Model score: 0.8162143469360889
# Improvement found!
# n_estimators=66:
# 	Mean Squared Error: 975.4131670248288, 	R2: 0.816257839122529, 	Model score: 0.816257839122529
# Improvement found!
# n_estimators=67:
# 	Mean Squared Error: 975.2176082732559, 	R2: 0.8162946772428326, 	Model score: 0.8162946772428326
# Improvement found!
# n_estimators=68:
# 	Mean Squared Error: 976.1669501473567, 	R2: 0.8161158462271607, 	Model score: 0.8161158462271607
# n_estimators=69:
# 	Mean Squared Error: 975.7141434292643, 	R2: 0.8162011430917662, 	Model score: 0.8162011430917662
# n_estimators=70:
# 	Mean Squared Error: 974.6576265788542, 	R2: 0.8164001630513694, 	Model score: 0.8164001630513694
# Improvement found!
# n_estimators=71:
# 	Mean Squared Error: 974.3272875504064, 	R2: 0.8164623902274638, 	Model score: 0.8164623902274638
# Improvement found!
# n_estimators=72:
# 	Mean Squared Error: 972.4884939713156, 	R2: 0.8168087705276809, 	Model score: 0.8168087705276809
# Improvement found!
# n_estimators=73:
# 	Mean Squared Error: 970.0806777847724, 	R2: 0.8172623397064327, 	Model score: 0.8172623397064327
# Improvement found!
# n_estimators=74:
# 	Mean Squared Error: 968.6861328493201, 	R2: 0.8175250352579622, 	Model score: 0.8175250352579622
# Improvement found!
# n_estimators=75:
# 	Mean Squared Error: 968.1340494829752, 	R2: 0.8176290332294333, 	Model score: 0.8176290332294333
# Improvement found!
# n_estimators=76:
# 	Mean Squared Error: 967.5343583975819, 	R2: 0.8177419992418004, 	Model score: 0.8177419992418004
# Improvement found!
# n_estimators=77:
# 	Mean Squared Error: 967.6187726337456, 	R2: 0.8177260978220883, 	Model score: 0.8177260978220883
# n_estimators=78:
# 	Mean Squared Error: 967.0319154821783, 	R2: 0.8178366462592026, 	Model score: 0.8178366462592026
# Improvement found!
# n_estimators=79:
# 	Mean Squared Error: 968.3817143184096, 	R2: 0.8175823796947318, 	Model score: 0.8175823796947318
# n_estimators=80:
# 	Mean Squared Error: 967.9577847913168, 	R2: 0.8176622368568054, 	Model score: 0.8176622368568054
# Best score found: 0.818.
# Number of estimators: 80.
# Code execution time: 220.059 seconds.

# %%
#visualize gini importance
features_lst = []
gini_score_lst = []
for feature, score in zip(cleaned_df_dropped[['mag', 'latitude', 'depth', 'Unix Time']],best_model.feature_importances_):
    features_lst.append(feature)
    gini_score_lst.append(score)
feature_lst = [feature.capitalize() for feature in features_lst]
d = {'Names': feature_lst, 'Scores': gini_score_lst}
gini_df = pd.DataFrame(d)

sns.set()

p = sns.catplot(y='Names', x="Scores", data=gini_df, kind='bar', height=10, aspect=1, legend=False)
p.set_ylabels(fontsize=14)
p.set_yticklabels(fontsize=12)
p.set_xticklabels(fontsize=12)
p.set_xlabels(fontsize=14)
plt.show()

# %% [markdown]
# Cross-Validation

# %%
#define number of splits fro cross-validation
k_fold = KFold(n_splits=10)
for train_indices, test_indices in k_fold.split(X):
    print('Train: %s | test: %s' % (train_indices, test_indices))
# Out:
# Train: [ 5811  5812  5813 ... 58099 58100 58101] | test: [   0    1    2 ... 5808 5809 5810]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [ 5811  5812  5813 ... 11619 11620 11621]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [11622 11623 11624 ... 17429 17430 17431]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [17432 17433 17434 ... 23239 23240 23241]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [23242 23243 23244 ... 29049 29050 29051]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [29052 29053 29054 ... 34859 34860 34861]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [34862 34863 34864 ... 40669 40670 40671]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [40672 40673 40674 ... 46479 46480 46481]
# Train: [    0     1     2 ... 58099 58100 58101] | test: [46482 46483 46484 ... 52289 52290 52291]
# Train: [    0     1     2 ... 52289 52290 52291] | test: [52292 52293 52294 ... 58099 58100 58101]

# %%
#calculate cross-validation score
from numpy import mean
from numpy import std

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    cv_score=cross_val_score(best_model, X, y.values.ravel(), scoring='neg_mean_absolute_error', cv=k_fold, n_jobs=-1)
    print(cv_score)

# report performance
print('MAE: %.3f (%.3f)' % (mean(cv_score), std(cv_score)))
# Out:
# [ -7.79373961 -11.38784209  -9.69238368 -11.15004705 -10.47441856
#  -10.3213346   -9.13514368  -8.32812535  -9.37105027 -12.46937075]
# MAE: -10.012 (1.363)

# %%
#define tree for plot validation curve
reg_etrees = ExtraTreesRegressor(n_estimators=100, random_state=0)

# %%
#create elements for plot validation curve
#https://scikit-learn.org/stable/auto_examples/model_selection/plot_validation_curve.html
param_range = np.linspace(1, 100, 5, dtype=int)
train_scores, test_scores = validation_curve(
    reg_etrees,
    X,
    y.values.ravel(),
    param_name="n_estimators",
    param_range=param_range,
    n_jobs=2,
    cv=10
)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# %%
#plot validation curve
plt.title("Validation Curve with Extra Trees Regressor")
plt.xlabel("Number of Estimators")
plt.ylabel("Score")
plt.ylim(0.0, 1.1)
lw = 2
plt.plot(
    param_range, train_scores_mean, label="Training score", color="darkorange", lw=lw
)
plt.fill_between(
    param_range,
    train_scores_mean - train_scores_std,
    train_scores_mean + train_scores_std,
    alpha=0.2,
    color="darkorange",
    lw=lw,
)
plt.plot(
    param_range, test_scores_mean, label="Cross-validation score", color="navy", lw=lw
)
plt.fill_between(
    param_range,
    test_scores_mean - test_scores_std,
    test_scores_mean + test_scores_std,
    alpha=0.2,
    color="navy",
    lw=lw,
)
plt.legend(loc="best")
plt.show()

# %%
#use the best model to make predictions
testpred = best_model.predict(X_test)
actual_lon = y_test
lons = actual_lon['longitude'].tolist()
testpredict = []
abs_error = []
for item in testpred:
    testpredict.append(item)

maerr=mean_absolute_error(lons, testpredict)
test_mse = mean_squared_error(y_test, testpred)
rmse = sqrt(test_mse)
print('RMSE: %.3f' % rmse)
print('MAE: %.3f' % maerr)
# Out:
# RMSE: 31.097
# MAE: 8.799

# %%
#make dataframe with actual test values and ML predicted ones
lon_pred = actual_lon
lon_pred['Predicted'] = testpredict

# %%
lon_pred_all = lon_pred.rename(columns={'longitude': 'Actual'})

# %%
lon_pred_all.head(5)
# Out:
#            Actual   Predicted
# 3616  -122.790667 -122.784529
# 13495 -122.763167 -122.790944
# 28367 -117.914700 -117.681971
# 31835  -66.977667  -66.929436
# 27553 -151.285700 -150.971406

# %%
#join dataframes for actual and predicted with original dataframe
lon_pred_all = lon_pred.merge(model_df, how='inner', left_index=True, right_index=True)
lon_pred_all = lon_pred_all.rename(columns={'longitude_x': 'Actual', 'longitude_y': 'longitude'})
lon_pred_all.head(5)
# Out:
#            Actual   Predicted                             time   latitude  \
# 3616  -122.790667 -122.784529 2021-12-22 11:53:28.400000+00:00  38.819833
# 13495 -122.763167 -122.790944 2022-01-07 02:47:48.980000+00:00  38.824000
# 28367 -117.914700 -117.681971 2022-02-18 05:32:12.402000+00:00  38.163800
# 31835  -66.977667  -66.929436 2022-03-13 14:58:22.200000+00:00  17.972500
# 27553 -151.285700 -150.971406 2022-02-20 07:26:28.782000+00:00  62.942500
#
#         longitude   depth   mag magType   nst     gap  ...  \
# 3616  -122.790667    1.25  1.14      md  43.0   26.00  ...
# 13495 -122.763167    0.95  0.08      md  14.0   89.00  ...
# 28367 -117.914700   10.20  2.70      ml  22.0  103.56  ...
# 31835  -66.977667   12.28  2.06      md   3.0  180.00  ...
# 27553 -151.285700  110.80  2.00      ml   NaN     NaN  ...
#
#                                   place        type horizontalError  \
# 3616         6km NNW of The Geysers, CA  earthquake            0.13
# 13495                 4km W of Cobb, CA  earthquake            0.27
# 28367          30 km SE of Mina, Nevada  earthquake             NaN
# 31835     6 km WSW of Fuig, Puerto Rico  earthquake            2.33
# 27553  56 km NNW of Petersville, Alaska  earthquake             NaN
#
#       depthError  magError magNst     status  locationSource  magSource  \
# 3616        0.21  0.209000   10.0   reviewed              nc         nc
# 13495       0.40  0.222000    3.0   reviewed              nc         nc
# 28367       0.70  0.230000    9.0   reviewed              nn         nn
# 31835       1.10  0.038064    3.0   reviewed              pr         pr
# 27553       1.00       NaN    NaN  automatic              ak         ak
#
#           Unix Time
# 3616   1.640174e+09
# 13495  1.641524e+09
# 28367  1.645162e+09
# 31835  1.647184e+09
# 27553  1.645342e+09
#
# [5 rows x 25 columns]

# %%
#plot actual vs predicted values
x = np.array(lon_pred_all['longitude'])
y = np.array(testpredict)
# r2_score(y_test, y_pred)

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'teal'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=14)
plt.xlabel('Actual Longitude',  fontsize=14)
# Bigger title
plt.suptitle('Earthquake Longitude Model Predictions', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted longitude Values Using Extra Trees Regression', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(lon_pred_all['longitude'], testpredict)), (0, 150),  fontsize=14)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 140), fontsize=14)

fig.savefig('../static/images/extratrees_lon_linear_sns.png', bbox_inches='tight',dpi=600)
plt.show()

# %%
# make a single prediction
from datetime import datetime
mag = float(input('Enter a magnitude: '))
lat = float(input('Enter a latitude (in decimal form; negative for south hemisphere): '))
depth = float(input('Enter a depth (in km, only numerical value): '))
date_input = input('Enter a date (yyyy/mm/dd): ')
time_input = input('Enter a time in UTC (HH:MM:SS): ')
datetime_str = date_input + ' '+ time_input
date_time_obj = datetime.strptime(datetime_str, '%Y/%m/%d %H:%M:%S')
date_time_unix = (time.mktime(date_time_obj.timetuple()))
single_features = [[mag,lat,depth,date_time_unix]]
y_pred = best_model.predict(single_features)
print('Predicted Longitude: %g' % y_pred)
# Out:
# Predicted Longitude: 83.8499

# %% [markdown]
# Test with new data from USGS

# %%
#obtain USGS data for the day
page_url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_day.csv"

test_df = pd.read_csv(page_url)
test_df
# Out:
#                          time   latitude   longitude      depth   mag magType  \
# 0    2022-07-09T21:36:07.580Z  38.812832 -122.813500   2.910000  1.20      md
# 1    2022-07-09T21:30:09.750Z  38.836166 -122.799164   2.300000  1.07      md
# 2    2022-07-09T21:20:03.905Z  59.215700 -152.585000  86.300000  1.80      ml
# 3    2022-07-09T20:55:51.774Z  62.596200 -152.653000   0.000000  2.10      ml
# 4    2022-07-09T20:51:23.160Z  36.812332 -121.535835   5.980000  2.05      md
# ..                        ...        ...         ...        ...   ...     ...
# 226  2022-07-08T21:59:22.490Z  37.048167 -113.348000   3.360000  1.40      ml
# 227  2022-07-08T21:59:19.870Z  38.757332 -122.729164   1.930000  0.77      md
# 228  2022-07-08T21:55:32.029Z  37.903100 -118.504300   7.400000  1.10      ml
# 229  2022-07-08T21:46:41.830Z  17.990667  -67.006000   9.790000  2.24      md
# 230  2022-07-08T21:45:03.745Z  35.012260  -97.882591  10.559773  1.52      ml
#
#       nst         gap      dmin     rms  ...                   updated  \
# 0    30.0   50.000000  0.010880  0.0200  ...  2022-07-09T21:39:19.380Z
# 1    20.0   66.000000  0.007243  0.0200  ...  2022-07-09T21:31:43.990Z
# 2     NaN         NaN       NaN  0.2000  ...  2022-07-09T21:21:31.660Z
# 3     NaN         NaN       NaN  0.8300  ...  2022-07-09T20:57:55.393Z
# 4    27.0   63.000000  0.026690  0.1600  ...  2022-07-09T20:58:13.364Z
# ..    ...         ...       ...     ...  ...                       ...
# 226  14.0  115.000000  0.090870  0.1200  ...  2022-07-08T22:35:24.580Z
# 227   9.0  110.000000  0.005424  0.0200  ...  2022-07-08T23:35:11.241Z
# 228   7.0  340.990000  0.348000  0.0513  ...  2022-07-09T02:39:24.432Z
# 229   7.0  143.000000       NaN  0.0700  ...  2022-07-08T22:09:34.260Z
# 230  11.0  202.296871  0.077028  0.8017  ...  2022-07-08T21:47:31.200Z
#
#                                     place        type horizontalError  \
# 0               6km NW of The Geysers, CA  earthquake        0.200000
# 1                     7km WNW of Cobb, CA  earthquake        0.230000
# 2           40 km WSW of Nanwalek, Alaska  earthquake             NaN
# 3            93 km NW of Skwentna, Alaska  earthquake             NaN
# 4          4km S of San Juan Bautista, CA  earthquake        0.400000
# ..                                    ...         ...             ...
# 226          15 km SSW of Hurricane, Utah  earthquake        0.430000
# 227             3km SE of The Geysers, CA  earthquake        0.450000
# 228        9 km NNW of Benton, California  earthquake             NaN
# 229  4 km ENE of La Parguera, Puerto Rico  earthquake        0.440000
# 230        6 km SE of Chickasha, Oklahoma  earthquake        6.781169
#
#     depthError  magError  magNst     status  locationSource magSource
# 0     0.380000  0.050000     6.0  automatic              nc        nc
# 1     0.480000  0.350000     3.0  automatic              nc        nc
# 2     0.700000       NaN     NaN  automatic              ak        ak
# 3     0.300000       NaN     NaN  automatic              ak        ak
# 4     0.660000  0.160000    24.0  automatic              nc        nc
# ..         ...       ...     ...        ...             ...       ...
# 226   2.240000  0.097000     4.0   reviewed              uu        uu
# 227   0.390000  0.130000     3.0  automatic              nc        nc
# 228  13.600000  0.220000     2.0   reviewed              nn        nn
# 229   0.850000  0.025521     4.0   reviewed              pr        pr
# 230   5.027325       NaN     7.0  automatic              ok        ok
#
# [231 rows x 22 columns]

# %%
#create unix time column and drop columns not needed

test_df['Unix Time'] = pd.to_datetime(test_df['time']).astype(int)/10**9
cleaned_test_df = test_df.drop(columns=['id', 'nst','rms','magNst','net', 'time', 'magType', 'gap','dmin', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'status', 'locationSource', 'magSource'])
cleaned_test_df
# Out:
#       latitude   longitude      depth   mag     Unix Time
# 0    38.812832 -122.813500   2.910000  1.20  1.657403e+09
# 1    38.836166 -122.799164   2.300000  1.07  1.657402e+09
# 2    59.215700 -152.585000  86.300000  1.80  1.657402e+09
# 3    62.596200 -152.653000   0.000000  2.10  1.657400e+09
# 4    36.812332 -121.535835   5.980000  2.05  1.657400e+09
# ..         ...         ...        ...   ...           ...
# 226  37.048167 -113.348000   3.360000  1.40  1.657318e+09
# 227  38.757332 -122.729164   1.930000  0.77  1.657318e+09
# 228  37.903100 -118.504300   7.400000  1.10  1.657317e+09
# 229  17.990667  -67.006000   9.790000  2.24  1.657317e+09
# 230  35.012260  -97.882591  10.559773  1.52  1.657317e+09
#
# [231 rows x 5 columns]

# %%
#find if any column has NaNs
cleaned_test_df.isnull().sum()
# Out:
# latitude     0
# longitude    0
# depth        0
# mag          0
# Unix Time    0
# dtype: int64

# %%
#establish features to be used in model. X will use: latitude, longitude, depth and unix time. Y will be magnitude
X_test_data = cleaned_test_df.drop(['longitude'], axis = 1)

y_test_data = cleaned_test_df[['longitude']]

# %%
#predict values with best model
pred_data_y = best_model.predict(X_test_data)

# %%
#create dataframe with values
test_pred_data = cleaned_test_df
test_pred_data['Predicted'] = pred_data_y
test_pred_data
# Out:
#       latitude   longitude      depth   mag     Unix Time   Predicted
# 0    38.812832 -122.813500   2.910000  1.20  1.657403e+09 -122.749594
# 1    38.836166 -122.799164   2.300000  1.07  1.657402e+09 -122.733671
# 2    59.215700 -152.585000  86.300000  1.80  1.657402e+09 -153.099297
# 3    62.596200 -152.653000   0.000000  2.10  1.657400e+09 -150.753490
# 4    36.812332 -121.535835   5.980000  2.05  1.657400e+09 -113.506590
# ..         ...         ...        ...   ...           ...         ...
# 226  37.048167 -113.348000   3.360000  1.40  1.657318e+09 -114.990695
# 227  38.757332 -122.729164   1.930000  0.77  1.657318e+09 -122.534746
# 228  37.903100 -118.504300   7.400000  1.10  1.657317e+09 -120.190092
# 229  17.990667  -67.006000   9.790000  2.24  1.657317e+09  -66.977588
# 230  35.012260  -97.882591  10.559773  1.52  1.657317e+09 -110.486197
#
# [231 rows x 6 columns]

# %%
#create graph for actual vs predicted values
from datetime import date
today = date.today()

x = np.array(test_pred_data['longitude'])
y = np.array(test_pred_data['Predicted'])

sns.set_style('ticks')
x,y = pd.Series(x, name="Actual"), pd.Series(y, name="Prediction")
# sns.lmplot(x ='Actual', y ='Prediction', data = mag_pred_all, markers =['o'],  palette ='coolwarm')
ax = sns.regplot(x=x, y=y, ci=95, truncate=False, scatter_kws={"s": 30, "color":'purple'}, line_kws={"color": "red"})
ax.set_axisbelow(True)

fig = plt.gcf()
fig.set_size_inches(18.5, 10.5, forward=True)
plt.ylabel('Predicted Longitude', fontsize=14)
plt.xlabel('Actual Longitude',  fontsize=14)
# Bigger title
plt.suptitle(f'Earthquake Longitude Model Predictions Using Best Model and Daily Data ({today})', x=0.125, y=0.94, ha='left', fontsize=18)
# Subtitle
plt.title('Linear Regression for Actual vs Predicted Longitude Values Using Best Model and Data Not Used For Testing Model Split', loc='left', fontsize=14)
plt.annotate("R-squared = {:.3f}".format(r2_score(x, y)), (0, 100),  fontsize=12)
plt.annotate("RMSE = {:.3f}".format(rmse), (0, 80), fontsize=14)

fig.savefig('../static/images/extratrees_lon_linear_sns_daily.png', bbox_inches='tight', dpi=600)
plt.show()

# %%
#connection to a PostgreSQL local database
# ===========================================

# user_name_var = input('What is the username of your database? ')
host_var = input('What is the host address of your database?')
pw = input("Enter the database password: ")
# db_name = input("Enter the name of the database: ")

string_output = "postgresql://postgres"+':'+pw+'@'+host_var+":5432"+'/earthquake_db'
engine = create_engine(string_output)
connection = engine.connect()
print("Connected to database...")
#create new database with predicted values for both training and test databases
#=============
#PostgreSQL
lon_pred_all.to_sql('earthquake_etrees_lon', engine, if_exists='replace', index = False)
#=============
#SQLite
cur = conn.cursor()
lon_pred_all.to_sql('earthquake_etrees_lon', conn, if_exists='replace', index=False)
# Close connection to SQLite database
conn.close()
connection.close()
# Out:
# Connected to database...
